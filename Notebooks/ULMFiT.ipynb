# %%
from fastai import *
from fastai.text import *

# %%
# !unzip -qq '/content/drive/My Drive/Analytics Vidhya/input/train.zip'

# %%
train_df = pd.read_csv('/content/train.csv')

# %%
train_df.head()
# Out:
#    ID  ... Quantitative Finance
# 0   1  ...                    0
# 1   2  ...                    0
# 2   3  ...                    0
# 3   4  ...                    0
# 4   5  ...                    0
#
# [5 rows x 9 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20972 entries, 0 to 20971
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    20972 non-null  int64
#  1   TITLE                 20972 non-null  object
#  2   ABSTRACT              20972 non-null  object
#  3   Computer Science      20972 non-null  int64
#  4   Physics               20972 non-null  int64
#  5   Mathematics           20972 non-null  int64
#  6   Statistics            20972 non-null  int64
#  7   Quantitative Biology  20972 non-null  int64
#  8   Quantitative Finance  20972 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 1.4+ MB

# %%
# !unzip -qq '/content/drive/My Drive/Analytics Vidhya/input/test.zip'

# %%
test_df = pd.read_csv('/content/test.csv')

# %%
test_df.head()
# Out:
#       ID  ...                                           ABSTRACT
# 0  20973  ...    We present novel understandings of the Gamma...
# 1  20974  ...    Meteorites contain minerals from Solar Syste...
# 2  20975  ...    Frame aggregation is a mechanism by which mu...
# 3  20976  ...    Milky Way open clusters are very diverse in ...
# 4  20977  ...    Proving that a cryptographic protocol is cor...
#
# [5 rows x 3 columns]

# %%
test_id = test_df['ID']

# %%
train_df['text'] = train_df['TITLE'] + train_df['ABSTRACT']
test_df['text'] = test_df['TITLE'] + test_df['ABSTRACT']

# %%
train_df.head()
# Out:
#    ID  ...                                               text
# 0   1  ...  Reconstructing Subject-Specific Effect Maps  P...
# 1   2  ...  Rotation Invariance Neural Network  Rotation i...
# 2   3  ...  Spherical polyharmonics and Poisson kernels fo...
# 3   4  ...  A finite element approximation for the stochas...
# 4   5  ...  Comparative study of Discrete Wavelet Transfor...
#
# [5 rows x 10 columns]

# %%
data = (TextList.from_df(train_df, cols='text')
                .split_by_rand_pct(0.1, seed=42)
                .label_for_lm()  
                .databunch(bs=128))
data.show_batch()
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/text/data.py:339: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   idx_min = (t != self.pad_idx).nonzero().min()
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>idx</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>from the subject 's data . xxmaj while global inference is widely \n  used , local inference , which can be used to form subject - specific effect maps , \n  is rarely used because existing models often yield noisy detections composed of \n  dispersed isolated islands . xxmaj in this article , we propose a reconstruction \n  method , named xxup rsm , to improve</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>xxunk image of this code . xxmaj when the dimension of the subspaces \n  is greater than one , we obtain codes whose alphabet is no longer a finite \n  field , but a set of r - xxunk . xxmaj we explain why these codes are practically as \n  efficient for applications as the codes defined on an extension of degree r. xxmaj in \n</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>. \n  xxbos xxmaj deep xxmaj multimodal xxmaj image - xxmaj repurposing xxmaj detection xxmaj nefarious actors on social media and other platforms often spread rumors and \n  xxunk through images whose metadata ( e.g. , captions ) have been modified to \n  provide visual xxunk of the rumor / xxunk . xxmaj this type of modification \n  is referred to as image repurposing , in</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>$ \ delta \ in \n  [ xxunk there exist positive integers $ k , d$ such that for sufficiently large \n  $ x$ , the interval $ [ x - x^ \ delta , x]$ contains $ \ xxunk } \ xxunk \ delta } { ( \ log \n  xxunk pairs of consecutive primes differing by at most $ d$. xxmaj this confirms a \n</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>- to - cable \n  ratios . xxmaj this work provides progress in both directions . xxmaj to address the first \n  limitation , the objective function for the inverse kinematics optimization \n  problem is modified to produce cable tensions as low or lower than before , thus \n  reducing the load on the robots ' motors . xxmaj for the second , a reformulation of</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn = language_model_learner(data, AWD_LSTM, drop_mult=0.3)
# Out:
# Downloading https://s3.amazonaws.com/fast-ai-modelzoo/wt103-fwd.tgz

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='99' class='' max='464' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       21.34% [99/464 01:29<05:29 10.5778]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(5, 1e-2, moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.260345</td>
#       <td>4.060698</td>
#       <td>0.297792</td>
#       <td>07:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.031631</td>
#       <td>3.936010</td>
#       <td>0.306432</td>
#       <td>07:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.804734</td>
#       <td>3.864421</td>
#       <td>0.313170</td>
#       <td>07:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.603993</td>
#       <td>3.820260</td>
#       <td>0.318383</td>
#       <td>07:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.466613</td>
#       <td>3.812860</td>
#       <td>0.319063</td>
#       <td>07:23</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.predict("The performance of this model is ", n_words=10)
# Out:
# 'The performance of this model is  investigated using this task . This is studied by'

# %%
learn.save('/content/drive/My Drive/Analytics Vidhya/models/fit-head')

# %%
learn.load('/content/drive/My Drive/Analytics Vidhya/models/fit-head')
# Out:
# LanguageLearner(data=TextLMDataBunch;
#
# Train: LabelList (18875 items)
# x: LMTextList
# xxbos xxmaj reconstructing xxmaj subject - xxmaj specific xxmaj effect xxmaj maps xxmaj predictive models allow subject - specific inference when analyzing disease
#   related alterations in neuroimaging data . xxmaj given a subject 's data , inference can
#   be made at two levels : global , i.e. xxunk condition presence for the
#   subject , and local , i.e. detecting condition effect on each individual
#   measurement extracted from the subject 's data . xxmaj while global inference is widely
#   used , local inference , which can be used to form subject - specific effect maps ,
#   is rarely used because existing models often yield noisy detections composed of
#   dispersed isolated islands . xxmaj in this article , we propose a reconstruction
#   method , named xxup rsm , to improve subject - specific detections of predictive
#   modeling approaches and in particular , binary classifiers . xxup rsm specifically
#   aims to reduce noise due to sampling error associated with using a finite
#   sample of examples to train classifiers . xxmaj the proposed method is a wrapper - type
#   algorithm that can be used with different binary classifiers in a diagnostic
#   manner , i.e. without information on condition presence . xxmaj reconstruction is posed
#   as a xxmaj maximum - a - xxmaj posteriori problem with a prior model whose parameters are
#   estimated from training data in a classifier - specific fashion . xxmaj experimental
#   evaluation is performed on synthetically generated data and data from the
#   xxmaj alzheimer 's xxmaj disease xxmaj neuroimaging xxmaj initiative ( xxup adni ) database . xxmaj results on
#   synthetic data demonstrate that using xxup rsm yields higher detection accuracy
#   compared to using models directly or with bootstrap averaging . xxmaj analyses on the
#   xxup adni dataset show that xxup rsm can also improve correlation between
#   subject - specific detections in cortical thickness data and non - imaging markers
#   of xxmaj alzheimer 's xxmaj disease ( xxup ad ) , such as the xxmaj mini xxmaj mental xxmaj state xxmaj examination xxmaj score
#   and xxmaj xxunk xxmaj fluid xxunk \ beta$ levels . xxmaj further reliability studies on
#   the longitudinal xxup adni dataset show improvement on detection reliability when
#   xxup rsm is used .
#  ,xxbos xxmaj rotation xxmaj invariance xxmaj neural xxmaj network xxmaj rotation invariance and translation invariance have great values in image
#   recognition tasks . xxmaj in this paper , we bring a new architecture in convolutional
#   neural network ( xxup cnn ) named cyclic convolutional layer to achieve rotation
#   invariance in xxup 2-d symbol recognition . xxmaj we can also get the position and
#   orientation of the xxup 2-d symbol by the network to achieve detection purpose for
#   multiple non - overlap target . xxmaj last but not least , this architecture can achieve
#   one - shot learning in some cases using those invariance .
#  ,xxbos xxmaj spherical polyharmonics and xxmaj poisson kernels for polyharmonic functions xxmaj we introduce and develop the notion of spherical polyharmonics , which are a
#   natural generalisation of spherical harmonics . xxmaj in particular we study the
#   theory of zonal polyharmonics , which allows us , analogously to zonal harmonics ,
#   to construct xxmaj poisson kernels for polyharmonic functions on the union of rotated
#   balls . xxmaj we find the representation of xxmaj poisson kernels and zonal polyharmonics in
#   terms of the xxmaj gegenbauer polynomials . xxmaj we show the connection between the
#   classical xxmaj poisson kernel for harmonic functions on the ball , xxmaj poisson kernels
#   for polyharmonic functions on the union of rotated balls , and the xxmaj cauchy - xxmaj xxunk
#   kernel for holomorphic functions on the xxmaj lie ball .
#  ,xxbos a finite element approximation for the stochastic xxmaj maxwell -- xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert system xxmaj the stochastic xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert ( xxup llg ) equation coupled with the
#   xxmaj maxwell equations ( the so called stochastic xxup xxunk system ) describes the creation
#   of domain walls and vortices ( fundamental objects for the novel nanostructured
#   magnetic memories ) . xxmaj we first reformulate the stochastic xxup llg equation into an
#   equation with time - differentiable solutions . xxmaj we then propose a convergent
#   $ \ xxunk scheme to approximate the solutions of the reformulated system .
#   xxmaj as a consequence , we prove convergence of the approximate solutions , with no or
#   minor conditions on time and space steps ( depending on the value of $ \ theta$ ) .
#   xxmaj hence , we prove the existence of weak martingale solutions of the stochastic
#   xxup xxunk system . xxmaj numerical results are presented to show applicability of the
#   method .
#  ,xxbos xxmaj comparative study of xxmaj discrete xxmaj wavelet xxmaj transforms and xxmaj wavelet xxmaj tensor xxmaj train decomposition to feature extraction of xxup ftir data of medicinal plants xxmaj fourier - transform infra - red ( xxup ftir ) spectra of samples from 7 plant species
#   were used to explore the influence of preprocessing and feature extraction on
#   efficiency of machine learning algorithms . xxmaj wavelet xxmaj tensor xxmaj train ( xxup wtt ) and
#   xxmaj discrete xxmaj wavelet xxmaj transforms ( xxup dwt ) were compared as feature extraction
#   techniques for xxup ftir data of medicinal plants . xxmaj various combinations of signal
#   processing steps showed different behavior when applied to classification and
#   clustering tasks . xxmaj best results for xxup wtt and xxup dwt found through grid search were
#   similar , significantly improving quality of clustering as well as
#   classification accuracy for tuned logistic regression in comparison to original
#   spectra . xxmaj unlike xxup dwt , xxup wtt has only one parameter to be tuned ( rank ) , making it a
#   more versatile and easier to use as a data processing tool in various signal
#   processing applications .
#
# y: LMLabelList
# ,,,,
# Path: .;
#
# Valid: LabelList (2097 items)
# x: LMTextList
# xxbos xxmaj dynamic xxmaj layer xxmaj normalization for xxmaj adaptive xxmaj neural xxmaj acoustic xxmaj modeling in xxmaj speech xxmaj recognition xxmaj layer normalization is a recently introduced technique for normalizing the
#   activities of neurons in deep neural networks to improve the training speed and
#   stability . xxmaj in this paper , we introduce a new layer normalization technique
#   called xxmaj dynamic xxmaj layer xxmaj normalization ( xxup xxunk ) for adaptive neural acoustic modeling
#   in speech recognition . xxmaj by dynamically generating the scaling and shifting
#   parameters in layer normalization , xxup xxunk adapts neural acoustic models to the
#   acoustic variability arising from various factors such as speakers , channel
#   noises , and environments . xxmaj unlike other adaptive acoustic models , our proposed
#   approach does not require additional adaptation data or speaker information
#   such as i - vectors . xxmaj moreover , the model size is fixed as it dynamically
#   generates adaptation parameters . xxmaj we apply our proposed xxup xxunk to deep
#   bidirectional xxup lstm acoustic models and evaluate them on two benchmark datasets
#   for large vocabulary xxup asr experiments : xxup xxunk and xxup ted - xxup xxunk release 2 . xxmaj the
#   experimental results show that our xxup xxunk improves neural acoustic models in terms
#   of transcription accuracy by dynamically adapting to various speakers and
#   environments .
#  ,xxbos xxmaj susceptibility xxmaj propagation by xxmaj using xxmaj diagonal xxmaj consistency a susceptibility propagation that is constructed by combining a belief
#   propagation and a linear response method is used for approximate computation
#   for xxmaj markov random fields . xxmaj herein , we formulate a new , improved susceptibility
#   propagation by using the concept of a diagonal matching method that is based on
#   mean - field approaches to inverse xxmaj ising problems . xxmaj the proposed susceptibility
#   propagation is robust for various network structures , and it is reduced to the
#   ordinary susceptibility propagation and to the adaptive
#   xxmaj thouless - xxmaj anderson - xxmaj palmer equation in special cases .
#  ,xxbos xxmaj the xxmaj robot xxmaj routing xxmaj problem for xxmaj collecting xxmaj aggregate xxmaj stochastic xxmaj rewards xxmaj we propose a new model for formalizing reward collection problems on graphs
#   with dynamically generated rewards which may appear and disappear based on a
#   stochastic model . xxmaj the * robot routing problem * is modeled as a graph whose nodes
#   are stochastic processes generating potential rewards over discrete time . xxmaj the
#   rewards are generated according to the stochastic process , but at each step , an
#   existing reward disappears with a given probability . xxmaj the edges in the graph
#   encode the ( unit - distance ) paths between the rewards ' locations . xxmaj on visiting a
#   node , the robot collects the accumulated reward at the node at that time , but
#   traveling between the nodes takes time . xxmaj the optimization question asks to
#   compute an optimal ( or epsilon - optimal ) path that maximizes the expected
#   collected rewards .
#   xxmaj we consider the finite and infinite - horizon robot routing problems . xxmaj for
#   finite - horizon , the goal is to maximize the total expected reward , while for
#   infinite horizon we consider limit - average objectives . xxmaj we study the
#   computational and strategy complexity of these problems , establish xxup np - lower
#   bounds and show that optimal strategies require memory in general . xxmaj we also
#   provide an algorithm for computing epsilon - optimal infinite paths for arbitrary
#   epsilon > 0 .
#  ,xxbos xxmaj probability , xxmaj statistics and xxmaj planet xxmaj earth , i : xxmaj xxunk covariances xxmaj the study of covariances ( or positive definite functions ) on the sphere ( the
#   xxmaj earth , in our motivation ) goes back to xxmaj bochner and xxmaj xxunk ( xxunk - xxunk ) and to
#   the first author ( 1969 , 1973 ) , among others . xxmaj extending to the xxunk case
#   ( sphere cross line , for position and time ) was for a long time an obstacle to
#   geostatistical modelling . xxmaj the characterisation question here was raised by the
#   authors and xxmaj xxunk in 2016 , and answered by xxmaj xxunk and xxmaj xxunk in 2017 .
#   xxmaj extensions to multiple products ( of spheres and lines ) follows similarly
#   ( xxmaj xxunk , xxmaj xxunk and xxmaj xxunk , 2016 ) . xxmaj we survey results of this type , and
#   related applications e.g. in numerical weather prediction .
#  ,xxbos xxmaj counting the number of metastable states in the modularity landscape : xxmaj algorithmic detectability limit of greedy algorithms in community detection xxmaj modularity maximization using greedy algorithms continues to be a popular
#   approach toward community detection in graphs , even after various better
#   forming algorithms have been proposed . xxmaj apart from its clear mechanism and ease
#   of implementation , this approach is persistently popular because , presumably ,
#   its risk of algorithmic failure is not well understood . xxmaj this xxmaj rapid
#   xxmaj communication provides insight into this issue by estimating the algorithmic
#   performance limit of modularity maximization . xxmaj this is achieved by counting the
#   number of metastable states under a local update rule . xxmaj our results offer a
#   quantitative insight into the level of sparsity at which a greedy algorithm
#   typically fails .
#
# y: LMLabelList
# ,,,,
# Path: .;
#
# Test: None, model=SequentialRNN(
#   (0): AWD_LSTM(
#     (encoder): Embedding(28720, 400, padding_idx=1)
#     (encoder_dp): EmbeddingDropout(
#       (emb): Embedding(28720, 400, padding_idx=1)
#     )
#     (rnns): ModuleList(
#       (0): WeightDropout(
#         (module): LSTM(400, 1152, batch_first=True)
#       )
#       (1): WeightDropout(
#         (module): LSTM(1152, 1152, batch_first=True)
#       )
#       (2): WeightDropout(
#         (module): LSTM(1152, 400, batch_first=True)
#       )
#     )
#     (input_dp): RNNDropout()
#     (hidden_dps): ModuleList(
#       (0): RNNDropout()
#       (1): RNNDropout()
#       (2): RNNDropout()
#     )
#   )
#   (1): LinearDecoder(
#     (decoder): Linear(in_features=400, out_features=28720, bias=True)
#     (output_dp): RNNDropout()
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x7f73e35fbd90>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[RNNTrainer
# learn: LanguageLearner(data=TextLMDataBunch;
#
# Train: LabelList (18875 items)
# x: LMTextList
# xxbos xxmaj reconstructing xxmaj subject - xxmaj specific xxmaj effect xxmaj maps xxmaj predictive models allow subject - specific inference when analyzing disease
#   related alterations in neuroimaging data . xxmaj given a subject 's data , inference can
#   be made at two levels : global , i.e. xxunk condition presence for the
#   subject , and local , i.e. detecting condition effect on each individual
#   measurement extracted from the subject 's data . xxmaj while global inference is widely
#   used , local inference , which can be used to form subject - specific effect maps ,
#   is rarely used because existing models often yield noisy detections composed of
#   dispersed isolated islands . xxmaj in this article , we propose a reconstruction
#   method , named xxup rsm , to improve subject - specific detections of predictive
#   modeling approaches and in particular , binary classifiers . xxup rsm specifically
#   aims to reduce noise due to sampling error associated with using a finite
#   sample of examples to train classifiers . xxmaj the proposed method is a wrapper - type
#   algorithm that can be used with different binary classifiers in a diagnostic
#   manner , i.e. without information on condition presence . xxmaj reconstruction is posed
#   as a xxmaj maximum - a - xxmaj posteriori problem with a prior model whose parameters are
#   estimated from training data in a classifier - specific fashion . xxmaj experimental
#   evaluation is performed on synthetically generated data and data from the
#   xxmaj alzheimer 's xxmaj disease xxmaj neuroimaging xxmaj initiative ( xxup adni ) database . xxmaj results on
#   synthetic data demonstrate that using xxup rsm yields higher detection accuracy
#   compared to using models directly or with bootstrap averaging . xxmaj analyses on the
#   xxup adni dataset show that xxup rsm can also improve correlation between
#   subject - specific detections in cortical thickness data and non - imaging markers
#   of xxmaj alzheimer 's xxmaj disease ( xxup ad ) , such as the xxmaj mini xxmaj mental xxmaj state xxmaj examination xxmaj score
#   and xxmaj xxunk xxmaj fluid xxunk \ beta$ levels . xxmaj further reliability studies on
#   the longitudinal xxup adni dataset show improvement on detection reliability when
#   xxup rsm is used .
#  ,xxbos xxmaj rotation xxmaj invariance xxmaj neural xxmaj network xxmaj rotation invariance and translation invariance have great values in image
#   recognition tasks . xxmaj in this paper , we bring a new architecture in convolutional
#   neural network ( xxup cnn ) named cyclic convolutional layer to achieve rotation
#   invariance in xxup 2-d symbol recognition . xxmaj we can also get the position and
#   orientation of the xxup 2-d symbol by the network to achieve detection purpose for
#   multiple non - overlap target . xxmaj last but not least , this architecture can achieve
#   one - shot learning in some cases using those invariance .
#  ,xxbos xxmaj spherical polyharmonics and xxmaj poisson kernels for polyharmonic functions xxmaj we introduce and develop the notion of spherical polyharmonics , which are a
#   natural generalisation of spherical harmonics . xxmaj in particular we study the
#   theory of zonal polyharmonics , which allows us , analogously to zonal harmonics ,
#   to construct xxmaj poisson kernels for polyharmonic functions on the union of rotated
#   balls . xxmaj we find the representation of xxmaj poisson kernels and zonal polyharmonics in
#   terms of the xxmaj gegenbauer polynomials . xxmaj we show the connection between the
#   classical xxmaj poisson kernel for harmonic functions on the ball , xxmaj poisson kernels
#   for polyharmonic functions on the union of rotated balls , and the xxmaj cauchy - xxmaj xxunk
#   kernel for holomorphic functions on the xxmaj lie ball .
#  ,xxbos a finite element approximation for the stochastic xxmaj maxwell -- xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert system xxmaj the stochastic xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert ( xxup llg ) equation coupled with the
#   xxmaj maxwell equations ( the so called stochastic xxup xxunk system ) describes the creation
#   of domain walls and vortices ( fundamental objects for the novel nanostructured
#   magnetic memories ) . xxmaj we first reformulate the stochastic xxup llg equation into an
#   equation with time - differentiable solutions . xxmaj we then propose a convergent
#   $ \ xxunk scheme to approximate the solutions of the reformulated system .
#   xxmaj as a consequence , we prove convergence of the approximate solutions , with no or
#   minor conditions on time and space steps ( depending on the value of $ \ theta$ ) .
#   xxmaj hence , we prove the existence of weak martingale solutions of the stochastic
#   xxup xxunk system . xxmaj numerical results are presented to show applicability of the
#   method .
#  ,xxbos xxmaj comparative study of xxmaj discrete xxmaj wavelet xxmaj transforms and xxmaj wavelet xxmaj tensor xxmaj train decomposition to feature extraction of xxup ftir data of medicinal plants xxmaj fourier - transform infra - red ( xxup ftir ) spectra of samples from 7 plant species
#   were used to explore the influence of preprocessing and feature extraction on
#   efficiency of machine learning algorithms . xxmaj wavelet xxmaj tensor xxmaj train ( xxup wtt ) and
#   xxmaj discrete xxmaj wavelet xxmaj transforms ( xxup dwt ) were compared as feature extraction
#   techniques for xxup ftir data of medicinal plants . xxmaj various combinations of signal
#   processing steps showed different behavior when applied to classification and
#   clustering tasks . xxmaj best results for xxup wtt and xxup dwt found through grid search were
#   similar , significantly improving quality of clustering as well as
#   classification accuracy for tuned logistic regression in comparison to original
#   spectra . xxmaj unlike xxup dwt , xxup wtt has only one parameter to be tuned ( rank ) , making it a
#   more versatile and easier to use as a data processing tool in various signal
#   processing applications .
#
# y: LMLabelList
# ,,,,
# Path: .;
#
# Valid: LabelList (2097 items)
# x: LMTextList
# xxbos xxmaj dynamic xxmaj layer xxmaj normalization for xxmaj adaptive xxmaj neural xxmaj acoustic xxmaj modeling in xxmaj speech xxmaj recognition xxmaj layer normalization is a recently introduced technique for normalizing the
#   activities of neurons in deep neural networks to improve the training speed and
#   stability . xxmaj in this paper , we introduce a new layer normalization technique
#   called xxmaj dynamic xxmaj layer xxmaj normalization ( xxup xxunk ) for adaptive neural acoustic modeling
#   in speech recognition . xxmaj by dynamically generating the scaling and shifting
#   parameters in layer normalization , xxup xxunk adapts neural acoustic models to the
#   acoustic variability arising from various factors such as speakers , channel
#   noises , and environments . xxmaj unlike other adaptive acoustic models , our proposed
#   approach does not require additional adaptation data or speaker information
#   such as i - vectors . xxmaj moreover , the model size is fixed as it dynamically
#   generates adaptation parameters . xxmaj we apply our proposed xxup xxunk to deep
#   bidirectional xxup lstm acoustic models and evaluate them on two benchmark datasets
#   for large vocabulary xxup asr experiments : xxup xxunk and xxup ted - xxup xxunk release 2 . xxmaj the
#   experimental results show that our xxup xxunk improves neural acoustic models in terms
#   of transcription accuracy by dynamically adapting to various speakers and
#   environments .
#  ,xxbos xxmaj susceptibility xxmaj propagation by xxmaj using xxmaj diagonal xxmaj consistency a susceptibility propagation that is constructed by combining a belief
#   propagation and a linear response method is used for approximate computation
#   for xxmaj markov random fields . xxmaj herein , we formulate a new , improved susceptibility
#   propagation by using the concept of a diagonal matching method that is based on
#   mean - field approaches to inverse xxmaj ising problems . xxmaj the proposed susceptibility
#   propagation is robust for various network structures , and it is reduced to the
#   ordinary susceptibility propagation and to the adaptive
#   xxmaj thouless - xxmaj anderson - xxmaj palmer equation in special cases .
#  ,xxbos xxmaj the xxmaj robot xxmaj routing xxmaj problem for xxmaj collecting xxmaj aggregate xxmaj stochastic xxmaj rewards xxmaj we propose a new model for formalizing reward collection problems on graphs
#   with dynamically generated rewards which may appear and disappear based on a
#   stochastic model . xxmaj the * robot routing problem * is modeled as a graph whose nodes
#   are stochastic processes generating potential rewards over discrete time . xxmaj the
#   rewards are generated according to the stochastic process , but at each step , an
#   existing reward disappears with a given probability . xxmaj the edges in the graph
#   encode the ( unit - distance ) paths between the rewards ' locations . xxmaj on visiting a
#   node , the robot collects the accumulated reward at the node at that time , but
#   traveling between the nodes takes time . xxmaj the optimization question asks to
#   compute an optimal ( or epsilon - optimal ) path that maximizes the expected
#   collected rewards .
#   xxmaj we consider the finite and infinite - horizon robot routing problems . xxmaj for
#   finite - horizon , the goal is to maximize the total expected reward , while for
#   infinite horizon we consider limit - average objectives . xxmaj we study the
#   computational and strategy complexity of these problems , establish xxup np - lower
#   bounds and show that optimal strategies require memory in general . xxmaj we also
#   provide an algorithm for computing epsilon - optimal infinite paths for arbitrary
#   epsilon > 0 .
#  ,xxbos xxmaj probability , xxmaj statistics and xxmaj planet xxmaj earth , i : xxmaj xxunk covariances xxmaj the study of covariances ( or positive definite functions ) on the sphere ( the
#   xxmaj earth , in our motivation ) goes back to xxmaj bochner and xxmaj xxunk ( xxunk - xxunk ) and to
#   the first author ( 1969 , 1973 ) , among others . xxmaj extending to the xxunk case
#   ( sphere cross line , for position and time ) was for a long time an obstacle to
#   geostatistical modelling . xxmaj the characterisation question here was raised by the
#   authors and xxmaj xxunk in 2016 , and answered by xxmaj xxunk and xxmaj xxunk in 2017 .
#   xxmaj extensions to multiple products ( of spheres and lines ) follows similarly
#   ( xxmaj xxunk , xxmaj xxunk and xxmaj xxunk , 2016 ) . xxmaj we survey results of this type , and
#   related applications e.g. in numerical weather prediction .
#  ,xxbos xxmaj counting the number of metastable states in the modularity landscape : xxmaj algorithmic detectability limit of greedy algorithms in community detection xxmaj modularity maximization using greedy algorithms continues to be a popular
#   approach toward community detection in graphs , even after various better
#   forming algorithms have been proposed . xxmaj apart from its clear mechanism and ease
#   of implementation , this approach is persistently popular because , presumably ,
#   its risk of algorithmic failure is not well understood . xxmaj this xxmaj rapid
#   xxmaj communication provides insight into this issue by estimating the algorithmic
#   performance limit of modularity maximization . xxmaj this is achieved by counting the
#   number of metastable states under a local update rule . xxmaj our results offer a
#   quantitative insight into the level of sparsity at which a greedy algorithm
#   typically fails .
#
# y: LMLabelList
# ,,,,
# Path: .;
#
# Test: None, model=SequentialRNN(
#   (0): AWD_LSTM(
#     (encoder): Embedding(28720, 400, padding_idx=1)
#     (encoder_dp): EmbeddingDropout(
#       (emb): Embedding(28720, 400, padding_idx=1)
#     )
#     (rnns): ModuleList(
#       (0): WeightDropout(
#         (module): LSTM(400, 1152, batch_first=True)
#       )
#       (1): WeightDropout(
#         (module): LSTM(1152, 1152, batch_first=True)
#       )
#       (2): WeightDropout(
#         (module): LSTM(1152, 400, batch_first=True)
#       )
#     )
#     (input_dp): RNNDropout()
#     (hidden_dps): ModuleList(
#       (0): RNNDropout()
#       (1): RNNDropout()
#       (2): RNNDropout()
#     )
#   )
#   (1): LinearDecoder(
#     (decoder): Linear(in_features=400, out_features=28720, bias=True)
#     (output_dp): RNNDropout()
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x7f73e35fbd90>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[...], layer_groups=[Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): Embedding(28720, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(28720, 400, padding_idx=1)
#   )
#   (2): LinearDecoder(
#     (decoder): Linear(in_features=400, out_features=28720, bias=True)
#     (output_dp): RNNDropout()
#   )
# )], add_time=True, silent=False)
# alpha: 2.0
# beta: 1.0], layer_groups=[Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): Embedding(28720, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(28720, 400, padding_idx=1)
#   )
#   (2): LinearDecoder(
#     (decoder): Linear(in_features=400, out_features=28720, bias=True)
#     (output_dp): RNNDropout()
#   )
# )], add_time=True, silent=False)

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='96' class='' max='464' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.69% [96/464 01:44<06:40 12.8827]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 6.31E-07
# Min loss divided by 10: 1.00E-04

# %%
learn.fit_one_cycle(7, 1e-4, moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.363427</td>
#       <td>3.759415</td>
#       <td>0.330016</td>
#       <td>08:49</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.307372</td>
#       <td>3.692589</td>
#       <td>0.342889</td>
#       <td>08:47</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.255648</td>
#       <td>3.661201</td>
#       <td>0.348343</td>
#       <td>08:47</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.210071</td>
#       <td>3.640923</td>
#       <td>0.352284</td>
#       <td>08:44</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.200590</td>
#       <td>3.644109</td>
#       <td>0.349891</td>
#       <td>08:47</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.158555</td>
#       <td>3.633756</td>
#       <td>0.353159</td>
#       <td>08:48</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.146856</td>
#       <td>3.633995</td>
#       <td>0.353022</td>
#       <td>08:44</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.predict("The performance of this model is ", n_words=10)
# Out:
# 'The performance of this model is  assessed on several application to principled data structures driven by'

# %%
learn.save_encoder('/content/drive/My Drive/Analytics Vidhya/models/fine_tuned_enc')

# %%
label_cols = ['Computer Science', 'Physics' , 'Mathematics' , 'Statistics' , 'Quantitative Biology' , 'Quantitative Finance']

# %%
test_datalist = TextList.from_df(test_df, cols='text', vocab=data.vocab)

# %%
data_clas = (TextList.from_df(train_df, cols='text', vocab=data.vocab)
             .split_by_rand_pct(0.1, seed=42)
             .label_from_df(cols= label_cols , classes=label_cols)
             .add_test(test_datalist)
             .databunch(bs=64))
data_clas.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxmaj on the zeros of xxmaj riemann $ xxmaj xxunk function xxmaj the xxmaj riemann $ \ xxmaj xi(z)$ function ( even in $ z$ ) admits a xxmaj fourier transform of an \n  even kernel $ \ xxmaj xxunk t / 2 } \ xxunk t / 2 } \ xxunk xxmaj here \n  $ \ xxunk \ xxunk and $ \ xxunk is a xxmaj</td>
#       <td>Mathematics</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj an introduction to xxmaj topological xxmaj data xxmaj analysis : fundamental and practical aspects for data scientists xxmaj topological xxmaj data xxmaj analysis ( tda ) is a recent and fast growing eld providing a \n  set of new topological and geometric tools to infer relevant features for \n  possibly complex data . xxmaj this paper is a brief introduction , through a few \n</td>
#       <td>Computer Science;Mathematics;Statistics</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj on the xxmaj power of xxmaj truncated xxup svd for xxmaj general xxmaj high - rank xxmaj matrix xxmaj estimation xxmaj problems xxmaj we show that given an estimate $ \ widehat{a}$ that is close to a general \n  high - rank positive semi - definite ( xxup psd ) matrix $ xxup a$ in spectral norm ( i.e. , \n  $ \ | \ xxunk</td>
#       <td>Mathematics;Statistics</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj centroidal localization game xxmaj one important problem in a network is to locate an ( invisible ) moving entity \n  by using distance - detectors placed at xxunk locations . xxmaj for instance , the \n  metric dimension of a graph $ xxup g$ is the minimum number $ k$ of detectors placed \n  in some vertices $ \ { v_1 , \ cdots ,</td>
#       <td>Computer Science</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj the x - ray and xxmaj mid - xxmaj infrared luminosities in xxmaj luminous xxmaj type 1 xxmaj quasars xxmaj several recent studies have reported different intrinsic correlations between \n  the xxup agn mid - xxup ir luminosity ( $ xxup xxunk ) and the rest - frame 2 - 10 kev luminosity \n  ( $ xxup xxunk ) for luminous quasars . xxmaj to understand</td>
#       <td>Physics</td>
#     </tr>
#   </tbody>
# </table>

# %%
acc_02 = partial(accuracy_thresh, thresh=0.2)
f1_score = partial(fbeta, thresh=0.2, beta=1)

# %%
learn_classifier = text_classifier_learner(data_clas, AWD_LSTM, drop_mult=0.5, metrics=[acc_02, f1_score])

# %%
learn_classifier.load_encoder('/content/drive/My Drive/Analytics Vidhya/models/fine_tuned_enc')
# Out:
# RNNLearner(data=TextClasDataBunch;
#
# Train: LabelList (18875 items)
# x: TextList
# xxbos xxmaj reconstructing xxmaj subject - xxmaj specific xxmaj effect xxmaj maps xxmaj predictive models allow subject - specific inference when analyzing disease
#   related alterations in neuroimaging data . xxmaj given a subject 's data , inference can
#   be made at two levels : global , i.e. xxunk condition presence for the
#   subject , and local , i.e. detecting condition effect on each individual
#   measurement extracted from the subject 's data . xxmaj while global inference is widely
#   used , local inference , which can be used to form subject - specific effect maps ,
#   is rarely used because existing models often yield noisy detections composed of
#   dispersed isolated islands . xxmaj in this article , we propose a reconstruction
#   method , named xxup rsm , to improve subject - specific detections of predictive
#   modeling approaches and in particular , binary classifiers . xxup rsm specifically
#   aims to reduce noise due to sampling error associated with using a finite
#   sample of examples to train classifiers . xxmaj the proposed method is a wrapper - type
#   algorithm that can be used with different binary classifiers in a diagnostic
#   manner , i.e. without information on condition presence . xxmaj reconstruction is posed
#   as a xxmaj maximum - a - xxmaj posteriori problem with a prior model whose parameters are
#   estimated from training data in a classifier - specific fashion . xxmaj experimental
#   evaluation is performed on synthetically generated data and data from the
#   xxmaj alzheimer 's xxmaj disease xxmaj neuroimaging xxmaj initiative ( xxup adni ) database . xxmaj results on
#   synthetic data demonstrate that using xxup rsm yields higher detection accuracy
#   compared to using models directly or with bootstrap averaging . xxmaj analyses on the
#   xxup adni dataset show that xxup rsm can also improve correlation between
#   subject - specific detections in cortical thickness data and non - imaging markers
#   of xxmaj alzheimer 's xxmaj disease ( xxup ad ) , such as the xxmaj mini xxmaj mental xxmaj state xxmaj examination xxmaj score
#   and xxmaj xxunk xxmaj fluid xxunk \ beta$ levels . xxmaj further reliability studies on
#   the longitudinal xxup adni dataset show improvement on detection reliability when
#   xxup rsm is used .
#  ,xxbos xxmaj rotation xxmaj invariance xxmaj neural xxmaj network xxmaj rotation invariance and translation invariance have great values in image
#   recognition tasks . xxmaj in this paper , we bring a new architecture in convolutional
#   neural network ( xxup cnn ) named cyclic convolutional layer to achieve rotation
#   invariance in xxup 2-d symbol recognition . xxmaj we can also get the position and
#   orientation of the xxup 2-d symbol by the network to achieve detection purpose for
#   multiple non - overlap target . xxmaj last but not least , this architecture can achieve
#   one - shot learning in some cases using those invariance .
#  ,xxbos xxmaj spherical polyharmonics and xxmaj poisson kernels for polyharmonic functions xxmaj we introduce and develop the notion of spherical polyharmonics , which are a
#   natural generalisation of spherical harmonics . xxmaj in particular we study the
#   theory of zonal polyharmonics , which allows us , analogously to zonal harmonics ,
#   to construct xxmaj poisson kernels for polyharmonic functions on the union of rotated
#   balls . xxmaj we find the representation of xxmaj poisson kernels and zonal polyharmonics in
#   terms of the xxmaj gegenbauer polynomials . xxmaj we show the connection between the
#   classical xxmaj poisson kernel for harmonic functions on the ball , xxmaj poisson kernels
#   for polyharmonic functions on the union of rotated balls , and the xxmaj cauchy - xxmaj xxunk
#   kernel for holomorphic functions on the xxmaj lie ball .
#  ,xxbos a finite element approximation for the stochastic xxmaj maxwell -- xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert system xxmaj the stochastic xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert ( xxup llg ) equation coupled with the
#   xxmaj maxwell equations ( the so called stochastic xxup xxunk system ) describes the creation
#   of domain walls and vortices ( fundamental objects for the novel nanostructured
#   magnetic memories ) . xxmaj we first reformulate the stochastic xxup llg equation into an
#   equation with time - differentiable solutions . xxmaj we then propose a convergent
#   $ \ xxunk scheme to approximate the solutions of the reformulated system .
#   xxmaj as a consequence , we prove convergence of the approximate solutions , with no or
#   minor conditions on time and space steps ( depending on the value of $ \ theta$ ) .
#   xxmaj hence , we prove the existence of weak martingale solutions of the stochastic
#   xxup xxunk system . xxmaj numerical results are presented to show applicability of the
#   method .
#  ,xxbos xxmaj comparative study of xxmaj discrete xxmaj wavelet xxmaj transforms and xxmaj wavelet xxmaj tensor xxmaj train decomposition to feature extraction of xxup ftir data of medicinal plants xxmaj fourier - transform infra - red ( xxup ftir ) spectra of samples from 7 plant species
#   were used to explore the influence of preprocessing and feature extraction on
#   efficiency of machine learning algorithms . xxmaj wavelet xxmaj tensor xxmaj train ( xxup wtt ) and
#   xxmaj discrete xxmaj wavelet xxmaj transforms ( xxup dwt ) were compared as feature extraction
#   techniques for xxup ftir data of medicinal plants . xxmaj various combinations of signal
#   processing steps showed different behavior when applied to classification and
#   clustering tasks . xxmaj best results for xxup wtt and xxup dwt found through grid search were
#   similar , significantly improving quality of clustering as well as
#   classification accuracy for tuned logistic regression in comparison to original
#   spectra . xxmaj unlike xxup dwt , xxup wtt has only one parameter to be tuned ( rank ) , making it a
#   more versatile and easier to use as a data processing tool in various signal
#   processing applications .
#
# y: MultiCategoryList
# Computer Science,Computer Science,Mathematics,Mathematics,Computer Science;Statistics
# Path: .;
#
# Valid: LabelList (2097 items)
# x: TextList
# xxbos xxmaj dynamic xxmaj layer xxmaj normalization for xxmaj adaptive xxmaj neural xxmaj acoustic xxmaj modeling in xxmaj speech xxmaj recognition xxmaj layer normalization is a recently introduced technique for normalizing the
#   activities of neurons in deep neural networks to improve the training speed and
#   stability . xxmaj in this paper , we introduce a new layer normalization technique
#   called xxmaj dynamic xxmaj layer xxmaj normalization ( xxup xxunk ) for adaptive neural acoustic modeling
#   in speech recognition . xxmaj by dynamically generating the scaling and shifting
#   parameters in layer normalization , xxup xxunk adapts neural acoustic models to the
#   acoustic variability arising from various factors such as speakers , channel
#   noises , and environments . xxmaj unlike other adaptive acoustic models , our proposed
#   approach does not require additional adaptation data or speaker information
#   such as i - vectors . xxmaj moreover , the model size is fixed as it dynamically
#   generates adaptation parameters . xxmaj we apply our proposed xxup xxunk to deep
#   bidirectional xxup lstm acoustic models and evaluate them on two benchmark datasets
#   for large vocabulary xxup asr experiments : xxup xxunk and xxup ted - xxup xxunk release 2 . xxmaj the
#   experimental results show that our xxup xxunk improves neural acoustic models in terms
#   of transcription accuracy by dynamically adapting to various speakers and
#   environments .
#  ,xxbos xxmaj susceptibility xxmaj propagation by xxmaj using xxmaj diagonal xxmaj consistency a susceptibility propagation that is constructed by combining a belief
#   propagation and a linear response method is used for approximate computation
#   for xxmaj markov random fields . xxmaj herein , we formulate a new , improved susceptibility
#   propagation by using the concept of a diagonal matching method that is based on
#   mean - field approaches to inverse xxmaj ising problems . xxmaj the proposed susceptibility
#   propagation is robust for various network structures , and it is reduced to the
#   ordinary susceptibility propagation and to the adaptive
#   xxmaj thouless - xxmaj anderson - xxmaj palmer equation in special cases .
#  ,xxbos xxmaj the xxmaj robot xxmaj routing xxmaj problem for xxmaj collecting xxmaj aggregate xxmaj stochastic xxmaj rewards xxmaj we propose a new model for formalizing reward collection problems on graphs
#   with dynamically generated rewards which may appear and disappear based on a
#   stochastic model . xxmaj the * robot routing problem * is modeled as a graph whose nodes
#   are stochastic processes generating potential rewards over discrete time . xxmaj the
#   rewards are generated according to the stochastic process , but at each step , an
#   existing reward disappears with a given probability . xxmaj the edges in the graph
#   encode the ( unit - distance ) paths between the rewards ' locations . xxmaj on visiting a
#   node , the robot collects the accumulated reward at the node at that time , but
#   traveling between the nodes takes time . xxmaj the optimization question asks to
#   compute an optimal ( or epsilon - optimal ) path that maximizes the expected
#   collected rewards .
#   xxmaj we consider the finite and infinite - horizon robot routing problems . xxmaj for
#   finite - horizon , the goal is to maximize the total expected reward , while for
#   infinite horizon we consider limit - average objectives . xxmaj we study the
#   computational and strategy complexity of these problems , establish xxup np - lower
#   bounds and show that optimal strategies require memory in general . xxmaj we also
#   provide an algorithm for computing epsilon - optimal infinite paths for arbitrary
#   epsilon > 0 .
#  ,xxbos xxmaj probability , xxmaj statistics and xxmaj planet xxmaj earth , i : xxmaj xxunk covariances xxmaj the study of covariances ( or positive definite functions ) on the sphere ( the
#   xxmaj earth , in our motivation ) goes back to xxmaj bochner and xxmaj xxunk ( xxunk - xxunk ) and to
#   the first author ( 1969 , 1973 ) , among others . xxmaj extending to the xxunk case
#   ( sphere cross line , for position and time ) was for a long time an obstacle to
#   geostatistical modelling . xxmaj the characterisation question here was raised by the
#   authors and xxmaj xxunk in 2016 , and answered by xxmaj xxunk and xxmaj xxunk in 2017 .
#   xxmaj extensions to multiple products ( of spheres and lines ) follows similarly
#   ( xxmaj xxunk , xxmaj xxunk and xxmaj xxunk , 2016 ) . xxmaj we survey results of this type , and
#   related applications e.g. in numerical weather prediction .
#  ,xxbos xxmaj counting the number of metastable states in the modularity landscape : xxmaj algorithmic detectability limit of greedy algorithms in community detection xxmaj modularity maximization using greedy algorithms continues to be a popular
#   approach toward community detection in graphs , even after various better
#   forming algorithms have been proposed . xxmaj apart from its clear mechanism and ease
#   of implementation , this approach is persistently popular because , presumably ,
#   its risk of algorithmic failure is not well understood . xxmaj this xxmaj rapid
#   xxmaj communication provides insight into this issue by estimating the algorithmic
#   performance limit of modularity maximization . xxmaj this is achieved by counting the
#   number of metastable states under a local update rule . xxmaj our results offer a
#   quantitative insight into the level of sparsity at which a greedy algorithm
#   typically fails .
#
# y: MultiCategoryList
# Computer Science,Mathematics;Statistics,Computer Science;Mathematics,Physics;Statistics,Computer Science
# Path: .;
#
# Test: LabelList (8989 items)
# x: TextList
# xxbos xxmaj closed - form xxmaj marginal xxmaj likelihood in xxmaj gamma - xxmaj poisson xxmaj matrix xxmaj factorization xxmaj we present novel understandings of the xxmaj gamma - xxmaj poisson ( gap ) model , a
#   probabilistic matrix factorization model for count data . xxmaj we show that gap can
#   be rewritten free of the score / activation matrix . xxmaj this gives us new insights
#   about the estimation of the topic / dictionary matrix by maximum marginal
#   likelihood estimation . xxmaj in particular , this explains the robustness of this
#   estimator to over - specified values of the factorization rank , especially its
#   ability to automatically prune irrelevant dictionary columns , as empirically
#   observed in previous work . xxmaj the marginalization of the activation matrix leads
#   in turn to a new xxmaj monte xxmaj carlo xxmaj expectation - xxmaj maximization algorithm with favorable
#   properties .
#  ,xxbos xxmaj laboratory mid - xxup ir spectra of xxunk and xxunk meteorites . xxmaj searching for observables of planetesimal debris xxmaj meteorites contain minerals from xxmaj solar xxmaj system asteroids with different
#   properties ( like size , presence of water , core formation ) . xxmaj we provide new
#   mid - xxup ir transmission spectra of xxunk meteorites to obtain templates of how
#   mid - xxup ir spectra of asteroidal debris would look like . xxmaj this is essential for
#   interpreting mid - xxup ir spectra of past and future space observatories , like the
#   xxmaj james xxmaj webb xxmaj space xxmaj telescope . xxmaj we show that the transmission spectra of wet and
#   dry chondrites , carbonaceous and ordinary chondrites and xxunk and
#   xxunk meteorites are distinctly different in a way one can distinguish in
#   astronomical mid - xxup ir spectra . xxmaj the two observables that spectroscopically
#   separate the different meteorites groups ( and thus the different types of
#   parent bodies ) are the xxunk - olivine feature strength ratio and the peak
#   shift of the olivine spectral features due to an increase in the iron
#   concentration of the olivine .
#  ,xxbos xxmaj case xxmaj for xxmaj static xxup xxunk xxmaj aggregation in wlans xxmaj frame aggregation is a mechanism by which multiple frames are combined into a
#   single transmission unit over the air . xxmaj frames aggregated at the xxup xxunk level use
#   a common xxup crc check to enforce integrity . xxmaj for longer aggregated xxup xxunk frames ,
#   the packet error rate increases significantly for the same bit error rate .
#   xxmaj hence , multiple studies have proposed doing xxup xxunk aggregation adaptively based
#   on the error rate . xxmaj this study evaluates if there is a \ xxunk }
#   advantage in doing adaptive xxup xxunk aggregation based on the link bit error rate .
#   xxmaj evaluations on a model show that instead of implementing a complex adaptive
#   xxup xxunk frame aggregation mechanism which impact queuing and other implementation
#   aspects , it is easier to influence packet error rate with traditional
#   mechanisms while keeping the xxup xxunk aggregation logic simple .
#  ,xxbos xxmaj the $ xxunk xxmaj survey : the inner disk intermediate - age open cluster xxup ngc xxunk xxmaj milky xxmaj way open clusters are very diverse in terms of age , chemical
#   composition , and kinematic properties . xxmaj intermediate - age and old open clusters
#   are less common , and it is even harder to find them inside the solar
#   xxmaj galactocentric radius , due to the high mortality rate and strong extinction
#   inside this region . xxup ngc xxunk is one of the inner disk open clusters ( xxunk )
#   observed by the $ xxunk survey ( xxup xxunk ) . xxmaj this cluster is an important target
#   for calibrating the abundances derived in the survey due to the kinematic and
#   chemical homogeneity of the members in open clusters . xxmaj using the measurements
#   from $ xxunk internal data release 4 ( xxunk ) , we identify 95 main - sequence
#   dwarfs as cluster members from the xxup xxunk target list , and eight giants as
#   cluster members from the xxup uves target list . xxmaj the dwarf cluster members have a
#   median radial velocity of $ xxunk \ xxunk $ km s$^{-1}$ , while the giant cluster
#   members have a median radial velocity of $ 12.0 \ xxunk $ km s$^{-1}$ and a median
#   [ xxmaj fe / h ] of $ 0.10 \ pm0.02 $ dex . xxmaj the color - magnitude diagram of these cluster
#   members suggests an age of $ 0.9 \ xxunk $ xxmaj gyr , with $ ( m - xxup xxunk $ and
#   $ xxup e(b - xxup xxunk xxmaj we perform the first detailed chemical abundance analysis of xxup ngc
#   xxunk , including 27 elemental species . xxmaj to gain a more general picture about
#   xxunk , the measurements of xxup ngc xxunk are compared with those of other xxunk
#   previously studied by xxup xxunk , that is , xxup ngc xxunk , xxmaj xxunk 20 , xxup ngc xxunk , and
#   xxmaj berkeley 81 . xxup ngc xxunk shows similar c , n , xxmaj na , and xxmaj al abundances as other xxunk .
#   xxmaj these elements are compared with xxunk models as a function of
#   cluster turn - off mass . xxmaj the $ \ alpha$ , iron - peak , and neutron - capture elements
#   are also explored in a self - consistent way .
#  ,xxbos xxmaj witness - xxmaj functions versus xxmaj interpretation - xxmaj functions for xxmaj secrecy in xxmaj cryptographic xxmaj protocols : xxmaj what to xxmaj choose ? xxmaj proving that a cryptographic protocol is correct for secrecy is a hard task .
#   xxmaj one of the strongest strategies to reach this goal is to show that it is
#   increasing , which means that the security level of every single atomic message
#   exchanged in the protocol , safely evaluated , never xxunk . xxmaj recently , two
#   families of functions have been proposed to measure the security level of
#   atomic messages . xxmaj the first one is the family of interpretation - functions . xxmaj the
#   second is the family of witness - functions . xxmaj in this paper , we show that the
#   witness - functions are more efficient than interpretation - functions . xxmaj we give a
#   detailed analysis of an ad - hoc protocol on which the witness - functions succeed
#   in proving its correctness for secrecy while the interpretation - functions fail
#   to do so .
#
# y: EmptyLabelList
# ,,,,
# Path: ., model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(28720, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(28720, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1152, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1152, 1152, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1152, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=6, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of BCEWithLogitsLoss(), metrics=[functools.partial(<function accuracy_thresh at 0x7f73e35fbe18>, thresh=0.2), functools.partial(<function fbeta at 0x7f73e35fba60>, thresh=0.2, beta=1)], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[RNNTrainer
# learn: RNNLearner(data=TextClasDataBunch;
#
# Train: LabelList (18875 items)
# x: TextList
# xxbos xxmaj reconstructing xxmaj subject - xxmaj specific xxmaj effect xxmaj maps xxmaj predictive models allow subject - specific inference when analyzing disease
#   related alterations in neuroimaging data . xxmaj given a subject 's data , inference can
#   be made at two levels : global , i.e. xxunk condition presence for the
#   subject , and local , i.e. detecting condition effect on each individual
#   measurement extracted from the subject 's data . xxmaj while global inference is widely
#   used , local inference , which can be used to form subject - specific effect maps ,
#   is rarely used because existing models often yield noisy detections composed of
#   dispersed isolated islands . xxmaj in this article , we propose a reconstruction
#   method , named xxup rsm , to improve subject - specific detections of predictive
#   modeling approaches and in particular , binary classifiers . xxup rsm specifically
#   aims to reduce noise due to sampling error associated with using a finite
#   sample of examples to train classifiers . xxmaj the proposed method is a wrapper - type
#   algorithm that can be used with different binary classifiers in a diagnostic
#   manner , i.e. without information on condition presence . xxmaj reconstruction is posed
#   as a xxmaj maximum - a - xxmaj posteriori problem with a prior model whose parameters are
#   estimated from training data in a classifier - specific fashion . xxmaj experimental
#   evaluation is performed on synthetically generated data and data from the
#   xxmaj alzheimer 's xxmaj disease xxmaj neuroimaging xxmaj initiative ( xxup adni ) database . xxmaj results on
#   synthetic data demonstrate that using xxup rsm yields higher detection accuracy
#   compared to using models directly or with bootstrap averaging . xxmaj analyses on the
#   xxup adni dataset show that xxup rsm can also improve correlation between
#   subject - specific detections in cortical thickness data and non - imaging markers
#   of xxmaj alzheimer 's xxmaj disease ( xxup ad ) , such as the xxmaj mini xxmaj mental xxmaj state xxmaj examination xxmaj score
#   and xxmaj xxunk xxmaj fluid xxunk \ beta$ levels . xxmaj further reliability studies on
#   the longitudinal xxup adni dataset show improvement on detection reliability when
#   xxup rsm is used .
#  ,xxbos xxmaj rotation xxmaj invariance xxmaj neural xxmaj network xxmaj rotation invariance and translation invariance have great values in image
#   recognition tasks . xxmaj in this paper , we bring a new architecture in convolutional
#   neural network ( xxup cnn ) named cyclic convolutional layer to achieve rotation
#   invariance in xxup 2-d symbol recognition . xxmaj we can also get the position and
#   orientation of the xxup 2-d symbol by the network to achieve detection purpose for
#   multiple non - overlap target . xxmaj last but not least , this architecture can achieve
#   one - shot learning in some cases using those invariance .
#  ,xxbos xxmaj spherical polyharmonics and xxmaj poisson kernels for polyharmonic functions xxmaj we introduce and develop the notion of spherical polyharmonics , which are a
#   natural generalisation of spherical harmonics . xxmaj in particular we study the
#   theory of zonal polyharmonics , which allows us , analogously to zonal harmonics ,
#   to construct xxmaj poisson kernels for polyharmonic functions on the union of rotated
#   balls . xxmaj we find the representation of xxmaj poisson kernels and zonal polyharmonics in
#   terms of the xxmaj gegenbauer polynomials . xxmaj we show the connection between the
#   classical xxmaj poisson kernel for harmonic functions on the ball , xxmaj poisson kernels
#   for polyharmonic functions on the union of rotated balls , and the xxmaj cauchy - xxmaj xxunk
#   kernel for holomorphic functions on the xxmaj lie ball .
#  ,xxbos a finite element approximation for the stochastic xxmaj maxwell -- xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert system xxmaj the stochastic xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert ( xxup llg ) equation coupled with the
#   xxmaj maxwell equations ( the so called stochastic xxup xxunk system ) describes the creation
#   of domain walls and vortices ( fundamental objects for the novel nanostructured
#   magnetic memories ) . xxmaj we first reformulate the stochastic xxup llg equation into an
#   equation with time - differentiable solutions . xxmaj we then propose a convergent
#   $ \ xxunk scheme to approximate the solutions of the reformulated system .
#   xxmaj as a consequence , we prove convergence of the approximate solutions , with no or
#   minor conditions on time and space steps ( depending on the value of $ \ theta$ ) .
#   xxmaj hence , we prove the existence of weak martingale solutions of the stochastic
#   xxup xxunk system . xxmaj numerical results are presented to show applicability of the
#   method .
#  ,xxbos xxmaj comparative study of xxmaj discrete xxmaj wavelet xxmaj transforms and xxmaj wavelet xxmaj tensor xxmaj train decomposition to feature extraction of xxup ftir data of medicinal plants xxmaj fourier - transform infra - red ( xxup ftir ) spectra of samples from 7 plant species
#   were used to explore the influence of preprocessing and feature extraction on
#   efficiency of machine learning algorithms . xxmaj wavelet xxmaj tensor xxmaj train ( xxup wtt ) and
#   xxmaj discrete xxmaj wavelet xxmaj transforms ( xxup dwt ) were compared as feature extraction
#   techniques for xxup ftir data of medicinal plants . xxmaj various combinations of signal
#   processing steps showed different behavior when applied to classification and
#   clustering tasks . xxmaj best results for xxup wtt and xxup dwt found through grid search were
#   similar , significantly improving quality of clustering as well as
#   classification accuracy for tuned logistic regression in comparison to original
#   spectra . xxmaj unlike xxup dwt , xxup wtt has only one parameter to be tuned ( rank ) , making it a
#   more versatile and easier to use as a data processing tool in various signal
#   processing applications .
#
# y: MultiCategoryList
# Computer Science,Computer Science,Mathematics,Mathematics,Computer Science;Statistics
# Path: .;
#
# Valid: LabelList (2097 items)
# x: TextList
# xxbos xxmaj dynamic xxmaj layer xxmaj normalization for xxmaj adaptive xxmaj neural xxmaj acoustic xxmaj modeling in xxmaj speech xxmaj recognition xxmaj layer normalization is a recently introduced technique for normalizing the
#   activities of neurons in deep neural networks to improve the training speed and
#   stability . xxmaj in this paper , we introduce a new layer normalization technique
#   called xxmaj dynamic xxmaj layer xxmaj normalization ( xxup xxunk ) for adaptive neural acoustic modeling
#   in speech recognition . xxmaj by dynamically generating the scaling and shifting
#   parameters in layer normalization , xxup xxunk adapts neural acoustic models to the
#   acoustic variability arising from various factors such as speakers , channel
#   noises , and environments . xxmaj unlike other adaptive acoustic models , our proposed
#   approach does not require additional adaptation data or speaker information
#   such as i - vectors . xxmaj moreover , the model size is fixed as it dynamically
#   generates adaptation parameters . xxmaj we apply our proposed xxup xxunk to deep
#   bidirectional xxup lstm acoustic models and evaluate them on two benchmark datasets
#   for large vocabulary xxup asr experiments : xxup xxunk and xxup ted - xxup xxunk release 2 . xxmaj the
#   experimental results show that our xxup xxunk improves neural acoustic models in terms
#   of transcription accuracy by dynamically adapting to various speakers and
#   environments .
#  ,xxbos xxmaj susceptibility xxmaj propagation by xxmaj using xxmaj diagonal xxmaj consistency a susceptibility propagation that is constructed by combining a belief
#   propagation and a linear response method is used for approximate computation
#   for xxmaj markov random fields . xxmaj herein , we formulate a new , improved susceptibility
#   propagation by using the concept of a diagonal matching method that is based on
#   mean - field approaches to inverse xxmaj ising problems . xxmaj the proposed susceptibility
#   propagation is robust for various network structures , and it is reduced to the
#   ordinary susceptibility propagation and to the adaptive
#   xxmaj thouless - xxmaj anderson - xxmaj palmer equation in special cases .
#  ,xxbos xxmaj the xxmaj robot xxmaj routing xxmaj problem for xxmaj collecting xxmaj aggregate xxmaj stochastic xxmaj rewards xxmaj we propose a new model for formalizing reward collection problems on graphs
#   with dynamically generated rewards which may appear and disappear based on a
#   stochastic model . xxmaj the * robot routing problem * is modeled as a graph whose nodes
#   are stochastic processes generating potential rewards over discrete time . xxmaj the
#   rewards are generated according to the stochastic process , but at each step , an
#   existing reward disappears with a given probability . xxmaj the edges in the graph
#   encode the ( unit - distance ) paths between the rewards ' locations . xxmaj on visiting a
#   node , the robot collects the accumulated reward at the node at that time , but
#   traveling between the nodes takes time . xxmaj the optimization question asks to
#   compute an optimal ( or epsilon - optimal ) path that maximizes the expected
#   collected rewards .
#   xxmaj we consider the finite and infinite - horizon robot routing problems . xxmaj for
#   finite - horizon , the goal is to maximize the total expected reward , while for
#   infinite horizon we consider limit - average objectives . xxmaj we study the
#   computational and strategy complexity of these problems , establish xxup np - lower
#   bounds and show that optimal strategies require memory in general . xxmaj we also
#   provide an algorithm for computing epsilon - optimal infinite paths for arbitrary
#   epsilon > 0 .
#  ,xxbos xxmaj probability , xxmaj statistics and xxmaj planet xxmaj earth , i : xxmaj xxunk covariances xxmaj the study of covariances ( or positive definite functions ) on the sphere ( the
#   xxmaj earth , in our motivation ) goes back to xxmaj bochner and xxmaj xxunk ( xxunk - xxunk ) and to
#   the first author ( 1969 , 1973 ) , among others . xxmaj extending to the xxunk case
#   ( sphere cross line , for position and time ) was for a long time an obstacle to
#   geostatistical modelling . xxmaj the characterisation question here was raised by the
#   authors and xxmaj xxunk in 2016 , and answered by xxmaj xxunk and xxmaj xxunk in 2017 .
#   xxmaj extensions to multiple products ( of spheres and lines ) follows similarly
#   ( xxmaj xxunk , xxmaj xxunk and xxmaj xxunk , 2016 ) . xxmaj we survey results of this type , and
#   related applications e.g. in numerical weather prediction .
#  ,xxbos xxmaj counting the number of metastable states in the modularity landscape : xxmaj algorithmic detectability limit of greedy algorithms in community detection xxmaj modularity maximization using greedy algorithms continues to be a popular
#   approach toward community detection in graphs , even after various better
#   forming algorithms have been proposed . xxmaj apart from its clear mechanism and ease
#   of implementation , this approach is persistently popular because , presumably ,
#   its risk of algorithmic failure is not well understood . xxmaj this xxmaj rapid
#   xxmaj communication provides insight into this issue by estimating the algorithmic
#   performance limit of modularity maximization . xxmaj this is achieved by counting the
#   number of metastable states under a local update rule . xxmaj our results offer a
#   quantitative insight into the level of sparsity at which a greedy algorithm
#   typically fails .
#
# y: MultiCategoryList
# Computer Science,Mathematics;Statistics,Computer Science;Mathematics,Physics;Statistics,Computer Science
# Path: .;
#
# Test: LabelList (8989 items)
# x: TextList
# xxbos xxmaj closed - form xxmaj marginal xxmaj likelihood in xxmaj gamma - xxmaj poisson xxmaj matrix xxmaj factorization xxmaj we present novel understandings of the xxmaj gamma - xxmaj poisson ( gap ) model , a
#   probabilistic matrix factorization model for count data . xxmaj we show that gap can
#   be rewritten free of the score / activation matrix . xxmaj this gives us new insights
#   about the estimation of the topic / dictionary matrix by maximum marginal
#   likelihood estimation . xxmaj in particular , this explains the robustness of this
#   estimator to over - specified values of the factorization rank , especially its
#   ability to automatically prune irrelevant dictionary columns , as empirically
#   observed in previous work . xxmaj the marginalization of the activation matrix leads
#   in turn to a new xxmaj monte xxmaj carlo xxmaj expectation - xxmaj maximization algorithm with favorable
#   properties .
#  ,xxbos xxmaj laboratory mid - xxup ir spectra of xxunk and xxunk meteorites . xxmaj searching for observables of planetesimal debris xxmaj meteorites contain minerals from xxmaj solar xxmaj system asteroids with different
#   properties ( like size , presence of water , core formation ) . xxmaj we provide new
#   mid - xxup ir transmission spectra of xxunk meteorites to obtain templates of how
#   mid - xxup ir spectra of asteroidal debris would look like . xxmaj this is essential for
#   interpreting mid - xxup ir spectra of past and future space observatories , like the
#   xxmaj james xxmaj webb xxmaj space xxmaj telescope . xxmaj we show that the transmission spectra of wet and
#   dry chondrites , carbonaceous and ordinary chondrites and xxunk and
#   xxunk meteorites are distinctly different in a way one can distinguish in
#   astronomical mid - xxup ir spectra . xxmaj the two observables that spectroscopically
#   separate the different meteorites groups ( and thus the different types of
#   parent bodies ) are the xxunk - olivine feature strength ratio and the peak
#   shift of the olivine spectral features due to an increase in the iron
#   concentration of the olivine .
#  ,xxbos xxmaj case xxmaj for xxmaj static xxup xxunk xxmaj aggregation in wlans xxmaj frame aggregation is a mechanism by which multiple frames are combined into a
#   single transmission unit over the air . xxmaj frames aggregated at the xxup xxunk level use
#   a common xxup crc check to enforce integrity . xxmaj for longer aggregated xxup xxunk frames ,
#   the packet error rate increases significantly for the same bit error rate .
#   xxmaj hence , multiple studies have proposed doing xxup xxunk aggregation adaptively based
#   on the error rate . xxmaj this study evaluates if there is a \ xxunk }
#   advantage in doing adaptive xxup xxunk aggregation based on the link bit error rate .
#   xxmaj evaluations on a model show that instead of implementing a complex adaptive
#   xxup xxunk frame aggregation mechanism which impact queuing and other implementation
#   aspects , it is easier to influence packet error rate with traditional
#   mechanisms while keeping the xxup xxunk aggregation logic simple .
#  ,xxbos xxmaj the $ xxunk xxmaj survey : the inner disk intermediate - age open cluster xxup ngc xxunk xxmaj milky xxmaj way open clusters are very diverse in terms of age , chemical
#   composition , and kinematic properties . xxmaj intermediate - age and old open clusters
#   are less common , and it is even harder to find them inside the solar
#   xxmaj galactocentric radius , due to the high mortality rate and strong extinction
#   inside this region . xxup ngc xxunk is one of the inner disk open clusters ( xxunk )
#   observed by the $ xxunk survey ( xxup xxunk ) . xxmaj this cluster is an important target
#   for calibrating the abundances derived in the survey due to the kinematic and
#   chemical homogeneity of the members in open clusters . xxmaj using the measurements
#   from $ xxunk internal data release 4 ( xxunk ) , we identify 95 main - sequence
#   dwarfs as cluster members from the xxup xxunk target list , and eight giants as
#   cluster members from the xxup uves target list . xxmaj the dwarf cluster members have a
#   median radial velocity of $ xxunk \ xxunk $ km s$^{-1}$ , while the giant cluster
#   members have a median radial velocity of $ 12.0 \ xxunk $ km s$^{-1}$ and a median
#   [ xxmaj fe / h ] of $ 0.10 \ pm0.02 $ dex . xxmaj the color - magnitude diagram of these cluster
#   members suggests an age of $ 0.9 \ xxunk $ xxmaj gyr , with $ ( m - xxup xxunk $ and
#   $ xxup e(b - xxup xxunk xxmaj we perform the first detailed chemical abundance analysis of xxup ngc
#   xxunk , including 27 elemental species . xxmaj to gain a more general picture about
#   xxunk , the measurements of xxup ngc xxunk are compared with those of other xxunk
#   previously studied by xxup xxunk , that is , xxup ngc xxunk , xxmaj xxunk 20 , xxup ngc xxunk , and
#   xxmaj berkeley 81 . xxup ngc xxunk shows similar c , n , xxmaj na , and xxmaj al abundances as other xxunk .
#   xxmaj these elements are compared with xxunk models as a function of
#   cluster turn - off mass . xxmaj the $ \ alpha$ , iron - peak , and neutron - capture elements
#   are also explored in a self - consistent way .
#  ,xxbos xxmaj witness - xxmaj functions versus xxmaj interpretation - xxmaj functions for xxmaj secrecy in xxmaj cryptographic xxmaj protocols : xxmaj what to xxmaj choose ? xxmaj proving that a cryptographic protocol is correct for secrecy is a hard task .
#   xxmaj one of the strongest strategies to reach this goal is to show that it is
#   increasing , which means that the security level of every single atomic message
#   exchanged in the protocol , safely evaluated , never xxunk . xxmaj recently , two
#   families of functions have been proposed to measure the security level of
#   atomic messages . xxmaj the first one is the family of interpretation - functions . xxmaj the
#   second is the family of witness - functions . xxmaj in this paper , we show that the
#   witness - functions are more efficient than interpretation - functions . xxmaj we give a
#   detailed analysis of an ad - hoc protocol on which the witness - functions succeed
#   in proving its correctness for secrecy while the interpretation - functions fail
#   to do so .
#
# y: EmptyLabelList
# ,,,,
# Path: ., model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(28720, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(28720, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1152, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1152, 1152, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1152, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=6, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of BCEWithLogitsLoss(), metrics=[functools.partial(<function accuracy_thresh at 0x7f73e35fbe18>, thresh=0.2), functools.partial(<function fbeta at 0x7f73e35fba60>, thresh=0.2, beta=1)], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[...], layer_groups=[Sequential(
#   (0): Embedding(28720, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(28720, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=6, bias=True)
#     )
#   )
# )], add_time=True, silent=False)
# alpha: 2.0
# beta: 1.0], layer_groups=[Sequential(
#   (0): Embedding(28720, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(28720, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=6, bias=True)
#     )
#   )
# )], add_time=True, silent=False)

# %%
learn_classifier.freeze()

# %%
learn_classifier.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='96' class='' max='294' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       32.65% [96/294 00:48<01:39 1.9868]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn_classifier.recorder.plot(suggestion=True)
# Out:
# Min numerical gradient: 6.92E-02
# Min loss divided by 10: 7.59E-02

# %%
learn_classifier.fit_one_cycle(5, 3e-2, moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.245378</td>
#       <td>0.202913</td>
#       <td>0.890320</td>
#       <td>0.804930</td>
#       <td>02:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.229162</td>
#       <td>0.193884</td>
#       <td>0.888253</td>
#       <td>0.805166</td>
#       <td>02:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.226848</td>
#       <td>0.188359</td>
#       <td>0.898108</td>
#       <td>0.817222</td>
#       <td>02:31</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.218086</td>
#       <td>0.181304</td>
#       <td>0.895009</td>
#       <td>0.814656</td>
#       <td>02:47</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.207304</td>
#       <td>0.178634</td>
#       <td>0.900175</td>
#       <td>0.820696</td>
#       <td>02:38</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_classifier.save('/content/drive/My Drive/Analytics Vidhya/models/first')

# %%
learn_classifier.load('/content/drive/My Drive/Analytics Vidhya/models/first')
# Out:
# RNNLearner(data=TextClasDataBunch;
#
# Train: LabelList (18875 items)
# x: TextList
# xxbos xxmaj reconstructing xxmaj subject - xxmaj specific xxmaj effect xxmaj maps xxmaj predictive models allow subject - specific inference when analyzing disease
#   related alterations in neuroimaging data . xxmaj given a subject 's data , inference can
#   be made at two levels : global , i.e. xxunk condition presence for the
#   subject , and local , i.e. detecting condition effect on each individual
#   measurement extracted from the subject 's data . xxmaj while global inference is widely
#   used , local inference , which can be used to form subject - specific effect maps ,
#   is rarely used because existing models often yield noisy detections composed of
#   dispersed isolated islands . xxmaj in this article , we propose a reconstruction
#   method , named xxup rsm , to improve subject - specific detections of predictive
#   modeling approaches and in particular , binary classifiers . xxup rsm specifically
#   aims to reduce noise due to sampling error associated with using a finite
#   sample of examples to train classifiers . xxmaj the proposed method is a wrapper - type
#   algorithm that can be used with different binary classifiers in a diagnostic
#   manner , i.e. without information on condition presence . xxmaj reconstruction is posed
#   as a xxmaj maximum - a - xxmaj posteriori problem with a prior model whose parameters are
#   estimated from training data in a classifier - specific fashion . xxmaj experimental
#   evaluation is performed on synthetically generated data and data from the
#   xxmaj alzheimer 's xxmaj disease xxmaj neuroimaging xxmaj initiative ( xxup adni ) database . xxmaj results on
#   synthetic data demonstrate that using xxup rsm yields higher detection accuracy
#   compared to using models directly or with bootstrap averaging . xxmaj analyses on the
#   xxup adni dataset show that xxup rsm can also improve correlation between
#   subject - specific detections in cortical thickness data and non - imaging markers
#   of xxmaj alzheimer 's xxmaj disease ( xxup ad ) , such as the xxmaj mini xxmaj mental xxmaj state xxmaj examination xxmaj score
#   and xxmaj xxunk xxmaj fluid xxunk \ beta$ levels . xxmaj further reliability studies on
#   the longitudinal xxup adni dataset show improvement on detection reliability when
#   xxup rsm is used .
#  ,xxbos xxmaj rotation xxmaj invariance xxmaj neural xxmaj network xxmaj rotation invariance and translation invariance have great values in image
#   recognition tasks . xxmaj in this paper , we bring a new architecture in convolutional
#   neural network ( xxup cnn ) named cyclic convolutional layer to achieve rotation
#   invariance in xxup 2-d symbol recognition . xxmaj we can also get the position and
#   orientation of the xxup 2-d symbol by the network to achieve detection purpose for
#   multiple non - overlap target . xxmaj last but not least , this architecture can achieve
#   one - shot learning in some cases using those invariance .
#  ,xxbos xxmaj spherical polyharmonics and xxmaj poisson kernels for polyharmonic functions xxmaj we introduce and develop the notion of spherical polyharmonics , which are a
#   natural generalisation of spherical harmonics . xxmaj in particular we study the
#   theory of zonal polyharmonics , which allows us , analogously to zonal harmonics ,
#   to construct xxmaj poisson kernels for polyharmonic functions on the union of rotated
#   balls . xxmaj we find the representation of xxmaj poisson kernels and zonal polyharmonics in
#   terms of the xxmaj gegenbauer polynomials . xxmaj we show the connection between the
#   classical xxmaj poisson kernel for harmonic functions on the ball , xxmaj poisson kernels
#   for polyharmonic functions on the union of rotated balls , and the xxmaj cauchy - xxmaj xxunk
#   kernel for holomorphic functions on the xxmaj lie ball .
#  ,xxbos a finite element approximation for the stochastic xxmaj maxwell -- xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert system xxmaj the stochastic xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert ( xxup llg ) equation coupled with the
#   xxmaj maxwell equations ( the so called stochastic xxup xxunk system ) describes the creation
#   of domain walls and vortices ( fundamental objects for the novel nanostructured
#   magnetic memories ) . xxmaj we first reformulate the stochastic xxup llg equation into an
#   equation with time - differentiable solutions . xxmaj we then propose a convergent
#   $ \ xxunk scheme to approximate the solutions of the reformulated system .
#   xxmaj as a consequence , we prove convergence of the approximate solutions , with no or
#   minor conditions on time and space steps ( depending on the value of $ \ theta$ ) .
#   xxmaj hence , we prove the existence of weak martingale solutions of the stochastic
#   xxup xxunk system . xxmaj numerical results are presented to show applicability of the
#   method .
#  ,xxbos xxmaj comparative study of xxmaj discrete xxmaj wavelet xxmaj transforms and xxmaj wavelet xxmaj tensor xxmaj train decomposition to feature extraction of xxup ftir data of medicinal plants xxmaj fourier - transform infra - red ( xxup ftir ) spectra of samples from 7 plant species
#   were used to explore the influence of preprocessing and feature extraction on
#   efficiency of machine learning algorithms . xxmaj wavelet xxmaj tensor xxmaj train ( xxup wtt ) and
#   xxmaj discrete xxmaj wavelet xxmaj transforms ( xxup dwt ) were compared as feature extraction
#   techniques for xxup ftir data of medicinal plants . xxmaj various combinations of signal
#   processing steps showed different behavior when applied to classification and
#   clustering tasks . xxmaj best results for xxup wtt and xxup dwt found through grid search were
#   similar , significantly improving quality of clustering as well as
#   classification accuracy for tuned logistic regression in comparison to original
#   spectra . xxmaj unlike xxup dwt , xxup wtt has only one parameter to be tuned ( rank ) , making it a
#   more versatile and easier to use as a data processing tool in various signal
#   processing applications .
#
# y: MultiCategoryList
# Computer Science,Computer Science,Mathematics,Mathematics,Computer Science;Statistics
# Path: .;
#
# Valid: LabelList (2097 items)
# x: TextList
# xxbos xxmaj dynamic xxmaj layer xxmaj normalization for xxmaj adaptive xxmaj neural xxmaj acoustic xxmaj modeling in xxmaj speech xxmaj recognition xxmaj layer normalization is a recently introduced technique for normalizing the
#   activities of neurons in deep neural networks to improve the training speed and
#   stability . xxmaj in this paper , we introduce a new layer normalization technique
#   called xxmaj dynamic xxmaj layer xxmaj normalization ( xxup xxunk ) for adaptive neural acoustic modeling
#   in speech recognition . xxmaj by dynamically generating the scaling and shifting
#   parameters in layer normalization , xxup xxunk adapts neural acoustic models to the
#   acoustic variability arising from various factors such as speakers , channel
#   noises , and environments . xxmaj unlike other adaptive acoustic models , our proposed
#   approach does not require additional adaptation data or speaker information
#   such as i - vectors . xxmaj moreover , the model size is fixed as it dynamically
#   generates adaptation parameters . xxmaj we apply our proposed xxup xxunk to deep
#   bidirectional xxup lstm acoustic models and evaluate them on two benchmark datasets
#   for large vocabulary xxup asr experiments : xxup xxunk and xxup ted - xxup xxunk release 2 . xxmaj the
#   experimental results show that our xxup xxunk improves neural acoustic models in terms
#   of transcription accuracy by dynamically adapting to various speakers and
#   environments .
#  ,xxbos xxmaj susceptibility xxmaj propagation by xxmaj using xxmaj diagonal xxmaj consistency a susceptibility propagation that is constructed by combining a belief
#   propagation and a linear response method is used for approximate computation
#   for xxmaj markov random fields . xxmaj herein , we formulate a new , improved susceptibility
#   propagation by using the concept of a diagonal matching method that is based on
#   mean - field approaches to inverse xxmaj ising problems . xxmaj the proposed susceptibility
#   propagation is robust for various network structures , and it is reduced to the
#   ordinary susceptibility propagation and to the adaptive
#   xxmaj thouless - xxmaj anderson - xxmaj palmer equation in special cases .
#  ,xxbos xxmaj the xxmaj robot xxmaj routing xxmaj problem for xxmaj collecting xxmaj aggregate xxmaj stochastic xxmaj rewards xxmaj we propose a new model for formalizing reward collection problems on graphs
#   with dynamically generated rewards which may appear and disappear based on a
#   stochastic model . xxmaj the * robot routing problem * is modeled as a graph whose nodes
#   are stochastic processes generating potential rewards over discrete time . xxmaj the
#   rewards are generated according to the stochastic process , but at each step , an
#   existing reward disappears with a given probability . xxmaj the edges in the graph
#   encode the ( unit - distance ) paths between the rewards ' locations . xxmaj on visiting a
#   node , the robot collects the accumulated reward at the node at that time , but
#   traveling between the nodes takes time . xxmaj the optimization question asks to
#   compute an optimal ( or epsilon - optimal ) path that maximizes the expected
#   collected rewards .
#   xxmaj we consider the finite and infinite - horizon robot routing problems . xxmaj for
#   finite - horizon , the goal is to maximize the total expected reward , while for
#   infinite horizon we consider limit - average objectives . xxmaj we study the
#   computational and strategy complexity of these problems , establish xxup np - lower
#   bounds and show that optimal strategies require memory in general . xxmaj we also
#   provide an algorithm for computing epsilon - optimal infinite paths for arbitrary
#   epsilon > 0 .
#  ,xxbos xxmaj probability , xxmaj statistics and xxmaj planet xxmaj earth , i : xxmaj xxunk covariances xxmaj the study of covariances ( or positive definite functions ) on the sphere ( the
#   xxmaj earth , in our motivation ) goes back to xxmaj bochner and xxmaj xxunk ( xxunk - xxunk ) and to
#   the first author ( 1969 , 1973 ) , among others . xxmaj extending to the xxunk case
#   ( sphere cross line , for position and time ) was for a long time an obstacle to
#   geostatistical modelling . xxmaj the characterisation question here was raised by the
#   authors and xxmaj xxunk in 2016 , and answered by xxmaj xxunk and xxmaj xxunk in 2017 .
#   xxmaj extensions to multiple products ( of spheres and lines ) follows similarly
#   ( xxmaj xxunk , xxmaj xxunk and xxmaj xxunk , 2016 ) . xxmaj we survey results of this type , and
#   related applications e.g. in numerical weather prediction .
#  ,xxbos xxmaj counting the number of metastable states in the modularity landscape : xxmaj algorithmic detectability limit of greedy algorithms in community detection xxmaj modularity maximization using greedy algorithms continues to be a popular
#   approach toward community detection in graphs , even after various better
#   forming algorithms have been proposed . xxmaj apart from its clear mechanism and ease
#   of implementation , this approach is persistently popular because , presumably ,
#   its risk of algorithmic failure is not well understood . xxmaj this xxmaj rapid
#   xxmaj communication provides insight into this issue by estimating the algorithmic
#   performance limit of modularity maximization . xxmaj this is achieved by counting the
#   number of metastable states under a local update rule . xxmaj our results offer a
#   quantitative insight into the level of sparsity at which a greedy algorithm
#   typically fails .
#
# y: MultiCategoryList
# Computer Science,Mathematics;Statistics,Computer Science;Mathematics,Physics;Statistics,Computer Science
# Path: .;
#
# Test: LabelList (8989 items)
# x: TextList
# xxbos xxmaj closed - form xxmaj marginal xxmaj likelihood in xxmaj gamma - xxmaj poisson xxmaj matrix xxmaj factorization xxmaj we present novel understandings of the xxmaj gamma - xxmaj poisson ( gap ) model , a
#   probabilistic matrix factorization model for count data . xxmaj we show that gap can
#   be rewritten free of the score / activation matrix . xxmaj this gives us new insights
#   about the estimation of the topic / dictionary matrix by maximum marginal
#   likelihood estimation . xxmaj in particular , this explains the robustness of this
#   estimator to over - specified values of the factorization rank , especially its
#   ability to automatically prune irrelevant dictionary columns , as empirically
#   observed in previous work . xxmaj the marginalization of the activation matrix leads
#   in turn to a new xxmaj monte xxmaj carlo xxmaj expectation - xxmaj maximization algorithm with favorable
#   properties .
#  ,xxbos xxmaj laboratory mid - xxup ir spectra of xxunk and xxunk meteorites . xxmaj searching for observables of planetesimal debris xxmaj meteorites contain minerals from xxmaj solar xxmaj system asteroids with different
#   properties ( like size , presence of water , core formation ) . xxmaj we provide new
#   mid - xxup ir transmission spectra of xxunk meteorites to obtain templates of how
#   mid - xxup ir spectra of asteroidal debris would look like . xxmaj this is essential for
#   interpreting mid - xxup ir spectra of past and future space observatories , like the
#   xxmaj james xxmaj webb xxmaj space xxmaj telescope . xxmaj we show that the transmission spectra of wet and
#   dry chondrites , carbonaceous and ordinary chondrites and xxunk and
#   xxunk meteorites are distinctly different in a way one can distinguish in
#   astronomical mid - xxup ir spectra . xxmaj the two observables that spectroscopically
#   separate the different meteorites groups ( and thus the different types of
#   parent bodies ) are the xxunk - olivine feature strength ratio and the peak
#   shift of the olivine spectral features due to an increase in the iron
#   concentration of the olivine .
#  ,xxbos xxmaj case xxmaj for xxmaj static xxup xxunk xxmaj aggregation in wlans xxmaj frame aggregation is a mechanism by which multiple frames are combined into a
#   single transmission unit over the air . xxmaj frames aggregated at the xxup xxunk level use
#   a common xxup crc check to enforce integrity . xxmaj for longer aggregated xxup xxunk frames ,
#   the packet error rate increases significantly for the same bit error rate .
#   xxmaj hence , multiple studies have proposed doing xxup xxunk aggregation adaptively based
#   on the error rate . xxmaj this study evaluates if there is a \ xxunk }
#   advantage in doing adaptive xxup xxunk aggregation based on the link bit error rate .
#   xxmaj evaluations on a model show that instead of implementing a complex adaptive
#   xxup xxunk frame aggregation mechanism which impact queuing and other implementation
#   aspects , it is easier to influence packet error rate with traditional
#   mechanisms while keeping the xxup xxunk aggregation logic simple .
#  ,xxbos xxmaj the $ xxunk xxmaj survey : the inner disk intermediate - age open cluster xxup ngc xxunk xxmaj milky xxmaj way open clusters are very diverse in terms of age , chemical
#   composition , and kinematic properties . xxmaj intermediate - age and old open clusters
#   are less common , and it is even harder to find them inside the solar
#   xxmaj galactocentric radius , due to the high mortality rate and strong extinction
#   inside this region . xxup ngc xxunk is one of the inner disk open clusters ( xxunk )
#   observed by the $ xxunk survey ( xxup xxunk ) . xxmaj this cluster is an important target
#   for calibrating the abundances derived in the survey due to the kinematic and
#   chemical homogeneity of the members in open clusters . xxmaj using the measurements
#   from $ xxunk internal data release 4 ( xxunk ) , we identify 95 main - sequence
#   dwarfs as cluster members from the xxup xxunk target list , and eight giants as
#   cluster members from the xxup uves target list . xxmaj the dwarf cluster members have a
#   median radial velocity of $ xxunk \ xxunk $ km s$^{-1}$ , while the giant cluster
#   members have a median radial velocity of $ 12.0 \ xxunk $ km s$^{-1}$ and a median
#   [ xxmaj fe / h ] of $ 0.10 \ pm0.02 $ dex . xxmaj the color - magnitude diagram of these cluster
#   members suggests an age of $ 0.9 \ xxunk $ xxmaj gyr , with $ ( m - xxup xxunk $ and
#   $ xxup e(b - xxup xxunk xxmaj we perform the first detailed chemical abundance analysis of xxup ngc
#   xxunk , including 27 elemental species . xxmaj to gain a more general picture about
#   xxunk , the measurements of xxup ngc xxunk are compared with those of other xxunk
#   previously studied by xxup xxunk , that is , xxup ngc xxunk , xxmaj xxunk 20 , xxup ngc xxunk , and
#   xxmaj berkeley 81 . xxup ngc xxunk shows similar c , n , xxmaj na , and xxmaj al abundances as other xxunk .
#   xxmaj these elements are compared with xxunk models as a function of
#   cluster turn - off mass . xxmaj the $ \ alpha$ , iron - peak , and neutron - capture elements
#   are also explored in a self - consistent way .
#  ,xxbos xxmaj witness - xxmaj functions versus xxmaj interpretation - xxmaj functions for xxmaj secrecy in xxmaj cryptographic xxmaj protocols : xxmaj what to xxmaj choose ? xxmaj proving that a cryptographic protocol is correct for secrecy is a hard task .
#   xxmaj one of the strongest strategies to reach this goal is to show that it is
#   increasing , which means that the security level of every single atomic message
#   exchanged in the protocol , safely evaluated , never xxunk . xxmaj recently , two
#   families of functions have been proposed to measure the security level of
#   atomic messages . xxmaj the first one is the family of interpretation - functions . xxmaj the
#   second is the family of witness - functions . xxmaj in this paper , we show that the
#   witness - functions are more efficient than interpretation - functions . xxmaj we give a
#   detailed analysis of an ad - hoc protocol on which the witness - functions succeed
#   in proving its correctness for secrecy while the interpretation - functions fail
#   to do so .
#
# y: EmptyLabelList
# ,,,,
# Path: ., model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(28720, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(28720, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1152, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1152, 1152, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1152, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=6, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of BCEWithLogitsLoss(), metrics=[functools.partial(<function accuracy_thresh at 0x7f73e35fbe18>, thresh=0.2), functools.partial(<function fbeta at 0x7f73e35fba60>, thresh=0.2, beta=1)], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[RNNTrainer
# learn: RNNLearner(data=TextClasDataBunch;
#
# Train: LabelList (18875 items)
# x: TextList
# xxbos xxmaj reconstructing xxmaj subject - xxmaj specific xxmaj effect xxmaj maps xxmaj predictive models allow subject - specific inference when analyzing disease
#   related alterations in neuroimaging data . xxmaj given a subject 's data , inference can
#   be made at two levels : global , i.e. xxunk condition presence for the
#   subject , and local , i.e. detecting condition effect on each individual
#   measurement extracted from the subject 's data . xxmaj while global inference is widely
#   used , local inference , which can be used to form subject - specific effect maps ,
#   is rarely used because existing models often yield noisy detections composed of
#   dispersed isolated islands . xxmaj in this article , we propose a reconstruction
#   method , named xxup rsm , to improve subject - specific detections of predictive
#   modeling approaches and in particular , binary classifiers . xxup rsm specifically
#   aims to reduce noise due to sampling error associated with using a finite
#   sample of examples to train classifiers . xxmaj the proposed method is a wrapper - type
#   algorithm that can be used with different binary classifiers in a diagnostic
#   manner , i.e. without information on condition presence . xxmaj reconstruction is posed
#   as a xxmaj maximum - a - xxmaj posteriori problem with a prior model whose parameters are
#   estimated from training data in a classifier - specific fashion . xxmaj experimental
#   evaluation is performed on synthetically generated data and data from the
#   xxmaj alzheimer 's xxmaj disease xxmaj neuroimaging xxmaj initiative ( xxup adni ) database . xxmaj results on
#   synthetic data demonstrate that using xxup rsm yields higher detection accuracy
#   compared to using models directly or with bootstrap averaging . xxmaj analyses on the
#   xxup adni dataset show that xxup rsm can also improve correlation between
#   subject - specific detections in cortical thickness data and non - imaging markers
#   of xxmaj alzheimer 's xxmaj disease ( xxup ad ) , such as the xxmaj mini xxmaj mental xxmaj state xxmaj examination xxmaj score
#   and xxmaj xxunk xxmaj fluid xxunk \ beta$ levels . xxmaj further reliability studies on
#   the longitudinal xxup adni dataset show improvement on detection reliability when
#   xxup rsm is used .
#  ,xxbos xxmaj rotation xxmaj invariance xxmaj neural xxmaj network xxmaj rotation invariance and translation invariance have great values in image
#   recognition tasks . xxmaj in this paper , we bring a new architecture in convolutional
#   neural network ( xxup cnn ) named cyclic convolutional layer to achieve rotation
#   invariance in xxup 2-d symbol recognition . xxmaj we can also get the position and
#   orientation of the xxup 2-d symbol by the network to achieve detection purpose for
#   multiple non - overlap target . xxmaj last but not least , this architecture can achieve
#   one - shot learning in some cases using those invariance .
#  ,xxbos xxmaj spherical polyharmonics and xxmaj poisson kernels for polyharmonic functions xxmaj we introduce and develop the notion of spherical polyharmonics , which are a
#   natural generalisation of spherical harmonics . xxmaj in particular we study the
#   theory of zonal polyharmonics , which allows us , analogously to zonal harmonics ,
#   to construct xxmaj poisson kernels for polyharmonic functions on the union of rotated
#   balls . xxmaj we find the representation of xxmaj poisson kernels and zonal polyharmonics in
#   terms of the xxmaj gegenbauer polynomials . xxmaj we show the connection between the
#   classical xxmaj poisson kernel for harmonic functions on the ball , xxmaj poisson kernels
#   for polyharmonic functions on the union of rotated balls , and the xxmaj cauchy - xxmaj xxunk
#   kernel for holomorphic functions on the xxmaj lie ball .
#  ,xxbos a finite element approximation for the stochastic xxmaj maxwell -- xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert system xxmaj the stochastic xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert ( xxup llg ) equation coupled with the
#   xxmaj maxwell equations ( the so called stochastic xxup xxunk system ) describes the creation
#   of domain walls and vortices ( fundamental objects for the novel nanostructured
#   magnetic memories ) . xxmaj we first reformulate the stochastic xxup llg equation into an
#   equation with time - differentiable solutions . xxmaj we then propose a convergent
#   $ \ xxunk scheme to approximate the solutions of the reformulated system .
#   xxmaj as a consequence , we prove convergence of the approximate solutions , with no or
#   minor conditions on time and space steps ( depending on the value of $ \ theta$ ) .
#   xxmaj hence , we prove the existence of weak martingale solutions of the stochastic
#   xxup xxunk system . xxmaj numerical results are presented to show applicability of the
#   method .
#  ,xxbos xxmaj comparative study of xxmaj discrete xxmaj wavelet xxmaj transforms and xxmaj wavelet xxmaj tensor xxmaj train decomposition to feature extraction of xxup ftir data of medicinal plants xxmaj fourier - transform infra - red ( xxup ftir ) spectra of samples from 7 plant species
#   were used to explore the influence of preprocessing and feature extraction on
#   efficiency of machine learning algorithms . xxmaj wavelet xxmaj tensor xxmaj train ( xxup wtt ) and
#   xxmaj discrete xxmaj wavelet xxmaj transforms ( xxup dwt ) were compared as feature extraction
#   techniques for xxup ftir data of medicinal plants . xxmaj various combinations of signal
#   processing steps showed different behavior when applied to classification and
#   clustering tasks . xxmaj best results for xxup wtt and xxup dwt found through grid search were
#   similar , significantly improving quality of clustering as well as
#   classification accuracy for tuned logistic regression in comparison to original
#   spectra . xxmaj unlike xxup dwt , xxup wtt has only one parameter to be tuned ( rank ) , making it a
#   more versatile and easier to use as a data processing tool in various signal
#   processing applications .
#
# y: MultiCategoryList
# Computer Science,Computer Science,Mathematics,Mathematics,Computer Science;Statistics
# Path: .;
#
# Valid: LabelList (2097 items)
# x: TextList
# xxbos xxmaj dynamic xxmaj layer xxmaj normalization for xxmaj adaptive xxmaj neural xxmaj acoustic xxmaj modeling in xxmaj speech xxmaj recognition xxmaj layer normalization is a recently introduced technique for normalizing the
#   activities of neurons in deep neural networks to improve the training speed and
#   stability . xxmaj in this paper , we introduce a new layer normalization technique
#   called xxmaj dynamic xxmaj layer xxmaj normalization ( xxup xxunk ) for adaptive neural acoustic modeling
#   in speech recognition . xxmaj by dynamically generating the scaling and shifting
#   parameters in layer normalization , xxup xxunk adapts neural acoustic models to the
#   acoustic variability arising from various factors such as speakers , channel
#   noises , and environments . xxmaj unlike other adaptive acoustic models , our proposed
#   approach does not require additional adaptation data or speaker information
#   such as i - vectors . xxmaj moreover , the model size is fixed as it dynamically
#   generates adaptation parameters . xxmaj we apply our proposed xxup xxunk to deep
#   bidirectional xxup lstm acoustic models and evaluate them on two benchmark datasets
#   for large vocabulary xxup asr experiments : xxup xxunk and xxup ted - xxup xxunk release 2 . xxmaj the
#   experimental results show that our xxup xxunk improves neural acoustic models in terms
#   of transcription accuracy by dynamically adapting to various speakers and
#   environments .
#  ,xxbos xxmaj susceptibility xxmaj propagation by xxmaj using xxmaj diagonal xxmaj consistency a susceptibility propagation that is constructed by combining a belief
#   propagation and a linear response method is used for approximate computation
#   for xxmaj markov random fields . xxmaj herein , we formulate a new , improved susceptibility
#   propagation by using the concept of a diagonal matching method that is based on
#   mean - field approaches to inverse xxmaj ising problems . xxmaj the proposed susceptibility
#   propagation is robust for various network structures , and it is reduced to the
#   ordinary susceptibility propagation and to the adaptive
#   xxmaj thouless - xxmaj anderson - xxmaj palmer equation in special cases .
#  ,xxbos xxmaj the xxmaj robot xxmaj routing xxmaj problem for xxmaj collecting xxmaj aggregate xxmaj stochastic xxmaj rewards xxmaj we propose a new model for formalizing reward collection problems on graphs
#   with dynamically generated rewards which may appear and disappear based on a
#   stochastic model . xxmaj the * robot routing problem * is modeled as a graph whose nodes
#   are stochastic processes generating potential rewards over discrete time . xxmaj the
#   rewards are generated according to the stochastic process , but at each step , an
#   existing reward disappears with a given probability . xxmaj the edges in the graph
#   encode the ( unit - distance ) paths between the rewards ' locations . xxmaj on visiting a
#   node , the robot collects the accumulated reward at the node at that time , but
#   traveling between the nodes takes time . xxmaj the optimization question asks to
#   compute an optimal ( or epsilon - optimal ) path that maximizes the expected
#   collected rewards .
#   xxmaj we consider the finite and infinite - horizon robot routing problems . xxmaj for
#   finite - horizon , the goal is to maximize the total expected reward , while for
#   infinite horizon we consider limit - average objectives . xxmaj we study the
#   computational and strategy complexity of these problems , establish xxup np - lower
#   bounds and show that optimal strategies require memory in general . xxmaj we also
#   provide an algorithm for computing epsilon - optimal infinite paths for arbitrary
#   epsilon > 0 .
#  ,xxbos xxmaj probability , xxmaj statistics and xxmaj planet xxmaj earth , i : xxmaj xxunk covariances xxmaj the study of covariances ( or positive definite functions ) on the sphere ( the
#   xxmaj earth , in our motivation ) goes back to xxmaj bochner and xxmaj xxunk ( xxunk - xxunk ) and to
#   the first author ( 1969 , 1973 ) , among others . xxmaj extending to the xxunk case
#   ( sphere cross line , for position and time ) was for a long time an obstacle to
#   geostatistical modelling . xxmaj the characterisation question here was raised by the
#   authors and xxmaj xxunk in 2016 , and answered by xxmaj xxunk and xxmaj xxunk in 2017 .
#   xxmaj extensions to multiple products ( of spheres and lines ) follows similarly
#   ( xxmaj xxunk , xxmaj xxunk and xxmaj xxunk , 2016 ) . xxmaj we survey results of this type , and
#   related applications e.g. in numerical weather prediction .
#  ,xxbos xxmaj counting the number of metastable states in the modularity landscape : xxmaj algorithmic detectability limit of greedy algorithms in community detection xxmaj modularity maximization using greedy algorithms continues to be a popular
#   approach toward community detection in graphs , even after various better
#   forming algorithms have been proposed . xxmaj apart from its clear mechanism and ease
#   of implementation , this approach is persistently popular because , presumably ,
#   its risk of algorithmic failure is not well understood . xxmaj this xxmaj rapid
#   xxmaj communication provides insight into this issue by estimating the algorithmic
#   performance limit of modularity maximization . xxmaj this is achieved by counting the
#   number of metastable states under a local update rule . xxmaj our results offer a
#   quantitative insight into the level of sparsity at which a greedy algorithm
#   typically fails .
#
# y: MultiCategoryList
# Computer Science,Mathematics;Statistics,Computer Science;Mathematics,Physics;Statistics,Computer Science
# Path: .;
#
# Test: LabelList (8989 items)
# x: TextList
# xxbos xxmaj closed - form xxmaj marginal xxmaj likelihood in xxmaj gamma - xxmaj poisson xxmaj matrix xxmaj factorization xxmaj we present novel understandings of the xxmaj gamma - xxmaj poisson ( gap ) model , a
#   probabilistic matrix factorization model for count data . xxmaj we show that gap can
#   be rewritten free of the score / activation matrix . xxmaj this gives us new insights
#   about the estimation of the topic / dictionary matrix by maximum marginal
#   likelihood estimation . xxmaj in particular , this explains the robustness of this
#   estimator to over - specified values of the factorization rank , especially its
#   ability to automatically prune irrelevant dictionary columns , as empirically
#   observed in previous work . xxmaj the marginalization of the activation matrix leads
#   in turn to a new xxmaj monte xxmaj carlo xxmaj expectation - xxmaj maximization algorithm with favorable
#   properties .
#  ,xxbos xxmaj laboratory mid - xxup ir spectra of xxunk and xxunk meteorites . xxmaj searching for observables of planetesimal debris xxmaj meteorites contain minerals from xxmaj solar xxmaj system asteroids with different
#   properties ( like size , presence of water , core formation ) . xxmaj we provide new
#   mid - xxup ir transmission spectra of xxunk meteorites to obtain templates of how
#   mid - xxup ir spectra of asteroidal debris would look like . xxmaj this is essential for
#   interpreting mid - xxup ir spectra of past and future space observatories , like the
#   xxmaj james xxmaj webb xxmaj space xxmaj telescope . xxmaj we show that the transmission spectra of wet and
#   dry chondrites , carbonaceous and ordinary chondrites and xxunk and
#   xxunk meteorites are distinctly different in a way one can distinguish in
#   astronomical mid - xxup ir spectra . xxmaj the two observables that spectroscopically
#   separate the different meteorites groups ( and thus the different types of
#   parent bodies ) are the xxunk - olivine feature strength ratio and the peak
#   shift of the olivine spectral features due to an increase in the iron
#   concentration of the olivine .
#  ,xxbos xxmaj case xxmaj for xxmaj static xxup xxunk xxmaj aggregation in wlans xxmaj frame aggregation is a mechanism by which multiple frames are combined into a
#   single transmission unit over the air . xxmaj frames aggregated at the xxup xxunk level use
#   a common xxup crc check to enforce integrity . xxmaj for longer aggregated xxup xxunk frames ,
#   the packet error rate increases significantly for the same bit error rate .
#   xxmaj hence , multiple studies have proposed doing xxup xxunk aggregation adaptively based
#   on the error rate . xxmaj this study evaluates if there is a \ xxunk }
#   advantage in doing adaptive xxup xxunk aggregation based on the link bit error rate .
#   xxmaj evaluations on a model show that instead of implementing a complex adaptive
#   xxup xxunk frame aggregation mechanism which impact queuing and other implementation
#   aspects , it is easier to influence packet error rate with traditional
#   mechanisms while keeping the xxup xxunk aggregation logic simple .
#  ,xxbos xxmaj the $ xxunk xxmaj survey : the inner disk intermediate - age open cluster xxup ngc xxunk xxmaj milky xxmaj way open clusters are very diverse in terms of age , chemical
#   composition , and kinematic properties . xxmaj intermediate - age and old open clusters
#   are less common , and it is even harder to find them inside the solar
#   xxmaj galactocentric radius , due to the high mortality rate and strong extinction
#   inside this region . xxup ngc xxunk is one of the inner disk open clusters ( xxunk )
#   observed by the $ xxunk survey ( xxup xxunk ) . xxmaj this cluster is an important target
#   for calibrating the abundances derived in the survey due to the kinematic and
#   chemical homogeneity of the members in open clusters . xxmaj using the measurements
#   from $ xxunk internal data release 4 ( xxunk ) , we identify 95 main - sequence
#   dwarfs as cluster members from the xxup xxunk target list , and eight giants as
#   cluster members from the xxup uves target list . xxmaj the dwarf cluster members have a
#   median radial velocity of $ xxunk \ xxunk $ km s$^{-1}$ , while the giant cluster
#   members have a median radial velocity of $ 12.0 \ xxunk $ km s$^{-1}$ and a median
#   [ xxmaj fe / h ] of $ 0.10 \ pm0.02 $ dex . xxmaj the color - magnitude diagram of these cluster
#   members suggests an age of $ 0.9 \ xxunk $ xxmaj gyr , with $ ( m - xxup xxunk $ and
#   $ xxup e(b - xxup xxunk xxmaj we perform the first detailed chemical abundance analysis of xxup ngc
#   xxunk , including 27 elemental species . xxmaj to gain a more general picture about
#   xxunk , the measurements of xxup ngc xxunk are compared with those of other xxunk
#   previously studied by xxup xxunk , that is , xxup ngc xxunk , xxmaj xxunk 20 , xxup ngc xxunk , and
#   xxmaj berkeley 81 . xxup ngc xxunk shows similar c , n , xxmaj na , and xxmaj al abundances as other xxunk .
#   xxmaj these elements are compared with xxunk models as a function of
#   cluster turn - off mass . xxmaj the $ \ alpha$ , iron - peak , and neutron - capture elements
#   are also explored in a self - consistent way .
#  ,xxbos xxmaj witness - xxmaj functions versus xxmaj interpretation - xxmaj functions for xxmaj secrecy in xxmaj cryptographic xxmaj protocols : xxmaj what to xxmaj choose ? xxmaj proving that a cryptographic protocol is correct for secrecy is a hard task .
#   xxmaj one of the strongest strategies to reach this goal is to show that it is
#   increasing , which means that the security level of every single atomic message
#   exchanged in the protocol , safely evaluated , never xxunk . xxmaj recently , two
#   families of functions have been proposed to measure the security level of
#   atomic messages . xxmaj the first one is the family of interpretation - functions . xxmaj the
#   second is the family of witness - functions . xxmaj in this paper , we show that the
#   witness - functions are more efficient than interpretation - functions . xxmaj we give a
#   detailed analysis of an ad - hoc protocol on which the witness - functions succeed
#   in proving its correctness for secrecy while the interpretation - functions fail
#   to do so .
#
# y: EmptyLabelList
# ,,,,
# Path: ., model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(28720, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(28720, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1152, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1152, 1152, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1152, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=6, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of BCEWithLogitsLoss(), metrics=[functools.partial(<function accuracy_thresh at 0x7f73e35fbe18>, thresh=0.2), functools.partial(<function fbeta at 0x7f73e35fba60>, thresh=0.2, beta=1)], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[...], layer_groups=[Sequential(
#   (0): Embedding(28720, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(28720, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=6, bias=True)
#     )
#   )
# )], add_time=True, silent=False)
# alpha: 2.0
# beta: 1.0], layer_groups=[Sequential(
#   (0): Embedding(28720, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(28720, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=6, bias=True)
#     )
#   )
# )], add_time=True, silent=False)

# %%
learn_classifier.freeze_to(-2)

# %%
learn_classifier.fit_one_cycle(3, slice(2e-2/(2.6**4), 2e-2), moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.229513</td>
#       <td>0.199074</td>
#       <td>0.903036</td>
#       <td>0.816102</td>
#       <td>03:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.198353</td>
#       <td>0.178980</td>
#       <td>0.906215</td>
#       <td>0.831632</td>
#       <td>03:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.176955</td>
#       <td>0.171487</td>
#       <td>0.912415</td>
#       <td>0.840614</td>
#       <td>03:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_classifier.save('/content/drive/My Drive/Analytics Vidhya/models/second')
learn_classifier.load('/content/drive/My Drive/Analytics Vidhya/models/second')
# Out:
# RNNLearner(data=TextClasDataBunch;
#
# Train: LabelList (18875 items)
# x: TextList
# xxbos xxmaj reconstructing xxmaj subject - xxmaj specific xxmaj effect xxmaj maps xxmaj predictive models allow subject - specific inference when analyzing disease
#   related alterations in neuroimaging data . xxmaj given a subject 's data , inference can
#   be made at two levels : global , i.e. xxunk condition presence for the
#   subject , and local , i.e. detecting condition effect on each individual
#   measurement extracted from the subject 's data . xxmaj while global inference is widely
#   used , local inference , which can be used to form subject - specific effect maps ,
#   is rarely used because existing models often yield noisy detections composed of
#   dispersed isolated islands . xxmaj in this article , we propose a reconstruction
#   method , named xxup rsm , to improve subject - specific detections of predictive
#   modeling approaches and in particular , binary classifiers . xxup rsm specifically
#   aims to reduce noise due to sampling error associated with using a finite
#   sample of examples to train classifiers . xxmaj the proposed method is a wrapper - type
#   algorithm that can be used with different binary classifiers in a diagnostic
#   manner , i.e. without information on condition presence . xxmaj reconstruction is posed
#   as a xxmaj maximum - a - xxmaj posteriori problem with a prior model whose parameters are
#   estimated from training data in a classifier - specific fashion . xxmaj experimental
#   evaluation is performed on synthetically generated data and data from the
#   xxmaj alzheimer 's xxmaj disease xxmaj neuroimaging xxmaj initiative ( xxup adni ) database . xxmaj results on
#   synthetic data demonstrate that using xxup rsm yields higher detection accuracy
#   compared to using models directly or with bootstrap averaging . xxmaj analyses on the
#   xxup adni dataset show that xxup rsm can also improve correlation between
#   subject - specific detections in cortical thickness data and non - imaging markers
#   of xxmaj alzheimer 's xxmaj disease ( xxup ad ) , such as the xxmaj mini xxmaj mental xxmaj state xxmaj examination xxmaj score
#   and xxmaj xxunk xxmaj fluid xxunk \ beta$ levels . xxmaj further reliability studies on
#   the longitudinal xxup adni dataset show improvement on detection reliability when
#   xxup rsm is used .
#  ,xxbos xxmaj rotation xxmaj invariance xxmaj neural xxmaj network xxmaj rotation invariance and translation invariance have great values in image
#   recognition tasks . xxmaj in this paper , we bring a new architecture in convolutional
#   neural network ( xxup cnn ) named cyclic convolutional layer to achieve rotation
#   invariance in xxup 2-d symbol recognition . xxmaj we can also get the position and
#   orientation of the xxup 2-d symbol by the network to achieve detection purpose for
#   multiple non - overlap target . xxmaj last but not least , this architecture can achieve
#   one - shot learning in some cases using those invariance .
#  ,xxbos xxmaj spherical polyharmonics and xxmaj poisson kernels for polyharmonic functions xxmaj we introduce and develop the notion of spherical polyharmonics , which are a
#   natural generalisation of spherical harmonics . xxmaj in particular we study the
#   theory of zonal polyharmonics , which allows us , analogously to zonal harmonics ,
#   to construct xxmaj poisson kernels for polyharmonic functions on the union of rotated
#   balls . xxmaj we find the representation of xxmaj poisson kernels and zonal polyharmonics in
#   terms of the xxmaj gegenbauer polynomials . xxmaj we show the connection between the
#   classical xxmaj poisson kernel for harmonic functions on the ball , xxmaj poisson kernels
#   for polyharmonic functions on the union of rotated balls , and the xxmaj cauchy - xxmaj xxunk
#   kernel for holomorphic functions on the xxmaj lie ball .
#  ,xxbos a finite element approximation for the stochastic xxmaj maxwell -- xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert system xxmaj the stochastic xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert ( xxup llg ) equation coupled with the
#   xxmaj maxwell equations ( the so called stochastic xxup xxunk system ) describes the creation
#   of domain walls and vortices ( fundamental objects for the novel nanostructured
#   magnetic memories ) . xxmaj we first reformulate the stochastic xxup llg equation into an
#   equation with time - differentiable solutions . xxmaj we then propose a convergent
#   $ \ xxunk scheme to approximate the solutions of the reformulated system .
#   xxmaj as a consequence , we prove convergence of the approximate solutions , with no or
#   minor conditions on time and space steps ( depending on the value of $ \ theta$ ) .
#   xxmaj hence , we prove the existence of weak martingale solutions of the stochastic
#   xxup xxunk system . xxmaj numerical results are presented to show applicability of the
#   method .
#  ,xxbos xxmaj comparative study of xxmaj discrete xxmaj wavelet xxmaj transforms and xxmaj wavelet xxmaj tensor xxmaj train decomposition to feature extraction of xxup ftir data of medicinal plants xxmaj fourier - transform infra - red ( xxup ftir ) spectra of samples from 7 plant species
#   were used to explore the influence of preprocessing and feature extraction on
#   efficiency of machine learning algorithms . xxmaj wavelet xxmaj tensor xxmaj train ( xxup wtt ) and
#   xxmaj discrete xxmaj wavelet xxmaj transforms ( xxup dwt ) were compared as feature extraction
#   techniques for xxup ftir data of medicinal plants . xxmaj various combinations of signal
#   processing steps showed different behavior when applied to classification and
#   clustering tasks . xxmaj best results for xxup wtt and xxup dwt found through grid search were
#   similar , significantly improving quality of clustering as well as
#   classification accuracy for tuned logistic regression in comparison to original
#   spectra . xxmaj unlike xxup dwt , xxup wtt has only one parameter to be tuned ( rank ) , making it a
#   more versatile and easier to use as a data processing tool in various signal
#   processing applications .
#
# y: MultiCategoryList
# Computer Science,Computer Science,Mathematics,Mathematics,Computer Science;Statistics
# Path: .;
#
# Valid: LabelList (2097 items)
# x: TextList
# xxbos xxmaj dynamic xxmaj layer xxmaj normalization for xxmaj adaptive xxmaj neural xxmaj acoustic xxmaj modeling in xxmaj speech xxmaj recognition xxmaj layer normalization is a recently introduced technique for normalizing the
#   activities of neurons in deep neural networks to improve the training speed and
#   stability . xxmaj in this paper , we introduce a new layer normalization technique
#   called xxmaj dynamic xxmaj layer xxmaj normalization ( xxup xxunk ) for adaptive neural acoustic modeling
#   in speech recognition . xxmaj by dynamically generating the scaling and shifting
#   parameters in layer normalization , xxup xxunk adapts neural acoustic models to the
#   acoustic variability arising from various factors such as speakers , channel
#   noises , and environments . xxmaj unlike other adaptive acoustic models , our proposed
#   approach does not require additional adaptation data or speaker information
#   such as i - vectors . xxmaj moreover , the model size is fixed as it dynamically
#   generates adaptation parameters . xxmaj we apply our proposed xxup xxunk to deep
#   bidirectional xxup lstm acoustic models and evaluate them on two benchmark datasets
#   for large vocabulary xxup asr experiments : xxup xxunk and xxup ted - xxup xxunk release 2 . xxmaj the
#   experimental results show that our xxup xxunk improves neural acoustic models in terms
#   of transcription accuracy by dynamically adapting to various speakers and
#   environments .
#  ,xxbos xxmaj susceptibility xxmaj propagation by xxmaj using xxmaj diagonal xxmaj consistency a susceptibility propagation that is constructed by combining a belief
#   propagation and a linear response method is used for approximate computation
#   for xxmaj markov random fields . xxmaj herein , we formulate a new , improved susceptibility
#   propagation by using the concept of a diagonal matching method that is based on
#   mean - field approaches to inverse xxmaj ising problems . xxmaj the proposed susceptibility
#   propagation is robust for various network structures , and it is reduced to the
#   ordinary susceptibility propagation and to the adaptive
#   xxmaj thouless - xxmaj anderson - xxmaj palmer equation in special cases .
#  ,xxbos xxmaj the xxmaj robot xxmaj routing xxmaj problem for xxmaj collecting xxmaj aggregate xxmaj stochastic xxmaj rewards xxmaj we propose a new model for formalizing reward collection problems on graphs
#   with dynamically generated rewards which may appear and disappear based on a
#   stochastic model . xxmaj the * robot routing problem * is modeled as a graph whose nodes
#   are stochastic processes generating potential rewards over discrete time . xxmaj the
#   rewards are generated according to the stochastic process , but at each step , an
#   existing reward disappears with a given probability . xxmaj the edges in the graph
#   encode the ( unit - distance ) paths between the rewards ' locations . xxmaj on visiting a
#   node , the robot collects the accumulated reward at the node at that time , but
#   traveling between the nodes takes time . xxmaj the optimization question asks to
#   compute an optimal ( or epsilon - optimal ) path that maximizes the expected
#   collected rewards .
#   xxmaj we consider the finite and infinite - horizon robot routing problems . xxmaj for
#   finite - horizon , the goal is to maximize the total expected reward , while for
#   infinite horizon we consider limit - average objectives . xxmaj we study the
#   computational and strategy complexity of these problems , establish xxup np - lower
#   bounds and show that optimal strategies require memory in general . xxmaj we also
#   provide an algorithm for computing epsilon - optimal infinite paths for arbitrary
#   epsilon > 0 .
#  ,xxbos xxmaj probability , xxmaj statistics and xxmaj planet xxmaj earth , i : xxmaj xxunk covariances xxmaj the study of covariances ( or positive definite functions ) on the sphere ( the
#   xxmaj earth , in our motivation ) goes back to xxmaj bochner and xxmaj xxunk ( xxunk - xxunk ) and to
#   the first author ( 1969 , 1973 ) , among others . xxmaj extending to the xxunk case
#   ( sphere cross line , for position and time ) was for a long time an obstacle to
#   geostatistical modelling . xxmaj the characterisation question here was raised by the
#   authors and xxmaj xxunk in 2016 , and answered by xxmaj xxunk and xxmaj xxunk in 2017 .
#   xxmaj extensions to multiple products ( of spheres and lines ) follows similarly
#   ( xxmaj xxunk , xxmaj xxunk and xxmaj xxunk , 2016 ) . xxmaj we survey results of this type , and
#   related applications e.g. in numerical weather prediction .
#  ,xxbos xxmaj counting the number of metastable states in the modularity landscape : xxmaj algorithmic detectability limit of greedy algorithms in community detection xxmaj modularity maximization using greedy algorithms continues to be a popular
#   approach toward community detection in graphs , even after various better
#   forming algorithms have been proposed . xxmaj apart from its clear mechanism and ease
#   of implementation , this approach is persistently popular because , presumably ,
#   its risk of algorithmic failure is not well understood . xxmaj this xxmaj rapid
#   xxmaj communication provides insight into this issue by estimating the algorithmic
#   performance limit of modularity maximization . xxmaj this is achieved by counting the
#   number of metastable states under a local update rule . xxmaj our results offer a
#   quantitative insight into the level of sparsity at which a greedy algorithm
#   typically fails .
#
# y: MultiCategoryList
# Computer Science,Mathematics;Statistics,Computer Science;Mathematics,Physics;Statistics,Computer Science
# Path: .;
#
# Test: LabelList (8989 items)
# x: TextList
# xxbos xxmaj closed - form xxmaj marginal xxmaj likelihood in xxmaj gamma - xxmaj poisson xxmaj matrix xxmaj factorization xxmaj we present novel understandings of the xxmaj gamma - xxmaj poisson ( gap ) model , a
#   probabilistic matrix factorization model for count data . xxmaj we show that gap can
#   be rewritten free of the score / activation matrix . xxmaj this gives us new insights
#   about the estimation of the topic / dictionary matrix by maximum marginal
#   likelihood estimation . xxmaj in particular , this explains the robustness of this
#   estimator to over - specified values of the factorization rank , especially its
#   ability to automatically prune irrelevant dictionary columns , as empirically
#   observed in previous work . xxmaj the marginalization of the activation matrix leads
#   in turn to a new xxmaj monte xxmaj carlo xxmaj expectation - xxmaj maximization algorithm with favorable
#   properties .
#  ,xxbos xxmaj laboratory mid - xxup ir spectra of xxunk and xxunk meteorites . xxmaj searching for observables of planetesimal debris xxmaj meteorites contain minerals from xxmaj solar xxmaj system asteroids with different
#   properties ( like size , presence of water , core formation ) . xxmaj we provide new
#   mid - xxup ir transmission spectra of xxunk meteorites to obtain templates of how
#   mid - xxup ir spectra of asteroidal debris would look like . xxmaj this is essential for
#   interpreting mid - xxup ir spectra of past and future space observatories , like the
#   xxmaj james xxmaj webb xxmaj space xxmaj telescope . xxmaj we show that the transmission spectra of wet and
#   dry chondrites , carbonaceous and ordinary chondrites and xxunk and
#   xxunk meteorites are distinctly different in a way one can distinguish in
#   astronomical mid - xxup ir spectra . xxmaj the two observables that spectroscopically
#   separate the different meteorites groups ( and thus the different types of
#   parent bodies ) are the xxunk - olivine feature strength ratio and the peak
#   shift of the olivine spectral features due to an increase in the iron
#   concentration of the olivine .
#  ,xxbos xxmaj case xxmaj for xxmaj static xxup xxunk xxmaj aggregation in wlans xxmaj frame aggregation is a mechanism by which multiple frames are combined into a
#   single transmission unit over the air . xxmaj frames aggregated at the xxup xxunk level use
#   a common xxup crc check to enforce integrity . xxmaj for longer aggregated xxup xxunk frames ,
#   the packet error rate increases significantly for the same bit error rate .
#   xxmaj hence , multiple studies have proposed doing xxup xxunk aggregation adaptively based
#   on the error rate . xxmaj this study evaluates if there is a \ xxunk }
#   advantage in doing adaptive xxup xxunk aggregation based on the link bit error rate .
#   xxmaj evaluations on a model show that instead of implementing a complex adaptive
#   xxup xxunk frame aggregation mechanism which impact queuing and other implementation
#   aspects , it is easier to influence packet error rate with traditional
#   mechanisms while keeping the xxup xxunk aggregation logic simple .
#  ,xxbos xxmaj the $ xxunk xxmaj survey : the inner disk intermediate - age open cluster xxup ngc xxunk xxmaj milky xxmaj way open clusters are very diverse in terms of age , chemical
#   composition , and kinematic properties . xxmaj intermediate - age and old open clusters
#   are less common , and it is even harder to find them inside the solar
#   xxmaj galactocentric radius , due to the high mortality rate and strong extinction
#   inside this region . xxup ngc xxunk is one of the inner disk open clusters ( xxunk )
#   observed by the $ xxunk survey ( xxup xxunk ) . xxmaj this cluster is an important target
#   for calibrating the abundances derived in the survey due to the kinematic and
#   chemical homogeneity of the members in open clusters . xxmaj using the measurements
#   from $ xxunk internal data release 4 ( xxunk ) , we identify 95 main - sequence
#   dwarfs as cluster members from the xxup xxunk target list , and eight giants as
#   cluster members from the xxup uves target list . xxmaj the dwarf cluster members have a
#   median radial velocity of $ xxunk \ xxunk $ km s$^{-1}$ , while the giant cluster
#   members have a median radial velocity of $ 12.0 \ xxunk $ km s$^{-1}$ and a median
#   [ xxmaj fe / h ] of $ 0.10 \ pm0.02 $ dex . xxmaj the color - magnitude diagram of these cluster
#   members suggests an age of $ 0.9 \ xxunk $ xxmaj gyr , with $ ( m - xxup xxunk $ and
#   $ xxup e(b - xxup xxunk xxmaj we perform the first detailed chemical abundance analysis of xxup ngc
#   xxunk , including 27 elemental species . xxmaj to gain a more general picture about
#   xxunk , the measurements of xxup ngc xxunk are compared with those of other xxunk
#   previously studied by xxup xxunk , that is , xxup ngc xxunk , xxmaj xxunk 20 , xxup ngc xxunk , and
#   xxmaj berkeley 81 . xxup ngc xxunk shows similar c , n , xxmaj na , and xxmaj al abundances as other xxunk .
#   xxmaj these elements are compared with xxunk models as a function of
#   cluster turn - off mass . xxmaj the $ \ alpha$ , iron - peak , and neutron - capture elements
#   are also explored in a self - consistent way .
#  ,xxbos xxmaj witness - xxmaj functions versus xxmaj interpretation - xxmaj functions for xxmaj secrecy in xxmaj cryptographic xxmaj protocols : xxmaj what to xxmaj choose ? xxmaj proving that a cryptographic protocol is correct for secrecy is a hard task .
#   xxmaj one of the strongest strategies to reach this goal is to show that it is
#   increasing , which means that the security level of every single atomic message
#   exchanged in the protocol , safely evaluated , never xxunk . xxmaj recently , two
#   families of functions have been proposed to measure the security level of
#   atomic messages . xxmaj the first one is the family of interpretation - functions . xxmaj the
#   second is the family of witness - functions . xxmaj in this paper , we show that the
#   witness - functions are more efficient than interpretation - functions . xxmaj we give a
#   detailed analysis of an ad - hoc protocol on which the witness - functions succeed
#   in proving its correctness for secrecy while the interpretation - functions fail
#   to do so .
#
# y: EmptyLabelList
# ,,,,
# Path: ., model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(28720, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(28720, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1152, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1152, 1152, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1152, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=6, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of BCEWithLogitsLoss(), metrics=[functools.partial(<function accuracy_thresh at 0x7f73e35fbe18>, thresh=0.2), functools.partial(<function fbeta at 0x7f73e35fba60>, thresh=0.2, beta=1)], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[RNNTrainer
# learn: RNNLearner(data=TextClasDataBunch;
#
# Train: LabelList (18875 items)
# x: TextList
# xxbos xxmaj reconstructing xxmaj subject - xxmaj specific xxmaj effect xxmaj maps xxmaj predictive models allow subject - specific inference when analyzing disease
#   related alterations in neuroimaging data . xxmaj given a subject 's data , inference can
#   be made at two levels : global , i.e. xxunk condition presence for the
#   subject , and local , i.e. detecting condition effect on each individual
#   measurement extracted from the subject 's data . xxmaj while global inference is widely
#   used , local inference , which can be used to form subject - specific effect maps ,
#   is rarely used because existing models often yield noisy detections composed of
#   dispersed isolated islands . xxmaj in this article , we propose a reconstruction
#   method , named xxup rsm , to improve subject - specific detections of predictive
#   modeling approaches and in particular , binary classifiers . xxup rsm specifically
#   aims to reduce noise due to sampling error associated with using a finite
#   sample of examples to train classifiers . xxmaj the proposed method is a wrapper - type
#   algorithm that can be used with different binary classifiers in a diagnostic
#   manner , i.e. without information on condition presence . xxmaj reconstruction is posed
#   as a xxmaj maximum - a - xxmaj posteriori problem with a prior model whose parameters are
#   estimated from training data in a classifier - specific fashion . xxmaj experimental
#   evaluation is performed on synthetically generated data and data from the
#   xxmaj alzheimer 's xxmaj disease xxmaj neuroimaging xxmaj initiative ( xxup adni ) database . xxmaj results on
#   synthetic data demonstrate that using xxup rsm yields higher detection accuracy
#   compared to using models directly or with bootstrap averaging . xxmaj analyses on the
#   xxup adni dataset show that xxup rsm can also improve correlation between
#   subject - specific detections in cortical thickness data and non - imaging markers
#   of xxmaj alzheimer 's xxmaj disease ( xxup ad ) , such as the xxmaj mini xxmaj mental xxmaj state xxmaj examination xxmaj score
#   and xxmaj xxunk xxmaj fluid xxunk \ beta$ levels . xxmaj further reliability studies on
#   the longitudinal xxup adni dataset show improvement on detection reliability when
#   xxup rsm is used .
#  ,xxbos xxmaj rotation xxmaj invariance xxmaj neural xxmaj network xxmaj rotation invariance and translation invariance have great values in image
#   recognition tasks . xxmaj in this paper , we bring a new architecture in convolutional
#   neural network ( xxup cnn ) named cyclic convolutional layer to achieve rotation
#   invariance in xxup 2-d symbol recognition . xxmaj we can also get the position and
#   orientation of the xxup 2-d symbol by the network to achieve detection purpose for
#   multiple non - overlap target . xxmaj last but not least , this architecture can achieve
#   one - shot learning in some cases using those invariance .
#  ,xxbos xxmaj spherical polyharmonics and xxmaj poisson kernels for polyharmonic functions xxmaj we introduce and develop the notion of spherical polyharmonics , which are a
#   natural generalisation of spherical harmonics . xxmaj in particular we study the
#   theory of zonal polyharmonics , which allows us , analogously to zonal harmonics ,
#   to construct xxmaj poisson kernels for polyharmonic functions on the union of rotated
#   balls . xxmaj we find the representation of xxmaj poisson kernels and zonal polyharmonics in
#   terms of the xxmaj gegenbauer polynomials . xxmaj we show the connection between the
#   classical xxmaj poisson kernel for harmonic functions on the ball , xxmaj poisson kernels
#   for polyharmonic functions on the union of rotated balls , and the xxmaj cauchy - xxmaj xxunk
#   kernel for holomorphic functions on the xxmaj lie ball .
#  ,xxbos a finite element approximation for the stochastic xxmaj maxwell -- xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert system xxmaj the stochastic xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert ( xxup llg ) equation coupled with the
#   xxmaj maxwell equations ( the so called stochastic xxup xxunk system ) describes the creation
#   of domain walls and vortices ( fundamental objects for the novel nanostructured
#   magnetic memories ) . xxmaj we first reformulate the stochastic xxup llg equation into an
#   equation with time - differentiable solutions . xxmaj we then propose a convergent
#   $ \ xxunk scheme to approximate the solutions of the reformulated system .
#   xxmaj as a consequence , we prove convergence of the approximate solutions , with no or
#   minor conditions on time and space steps ( depending on the value of $ \ theta$ ) .
#   xxmaj hence , we prove the existence of weak martingale solutions of the stochastic
#   xxup xxunk system . xxmaj numerical results are presented to show applicability of the
#   method .
#  ,xxbos xxmaj comparative study of xxmaj discrete xxmaj wavelet xxmaj transforms and xxmaj wavelet xxmaj tensor xxmaj train decomposition to feature extraction of xxup ftir data of medicinal plants xxmaj fourier - transform infra - red ( xxup ftir ) spectra of samples from 7 plant species
#   were used to explore the influence of preprocessing and feature extraction on
#   efficiency of machine learning algorithms . xxmaj wavelet xxmaj tensor xxmaj train ( xxup wtt ) and
#   xxmaj discrete xxmaj wavelet xxmaj transforms ( xxup dwt ) were compared as feature extraction
#   techniques for xxup ftir data of medicinal plants . xxmaj various combinations of signal
#   processing steps showed different behavior when applied to classification and
#   clustering tasks . xxmaj best results for xxup wtt and xxup dwt found through grid search were
#   similar , significantly improving quality of clustering as well as
#   classification accuracy for tuned logistic regression in comparison to original
#   spectra . xxmaj unlike xxup dwt , xxup wtt has only one parameter to be tuned ( rank ) , making it a
#   more versatile and easier to use as a data processing tool in various signal
#   processing applications .
#
# y: MultiCategoryList
# Computer Science,Computer Science,Mathematics,Mathematics,Computer Science;Statistics
# Path: .;
#
# Valid: LabelList (2097 items)
# x: TextList
# xxbos xxmaj dynamic xxmaj layer xxmaj normalization for xxmaj adaptive xxmaj neural xxmaj acoustic xxmaj modeling in xxmaj speech xxmaj recognition xxmaj layer normalization is a recently introduced technique for normalizing the
#   activities of neurons in deep neural networks to improve the training speed and
#   stability . xxmaj in this paper , we introduce a new layer normalization technique
#   called xxmaj dynamic xxmaj layer xxmaj normalization ( xxup xxunk ) for adaptive neural acoustic modeling
#   in speech recognition . xxmaj by dynamically generating the scaling and shifting
#   parameters in layer normalization , xxup xxunk adapts neural acoustic models to the
#   acoustic variability arising from various factors such as speakers , channel
#   noises , and environments . xxmaj unlike other adaptive acoustic models , our proposed
#   approach does not require additional adaptation data or speaker information
#   such as i - vectors . xxmaj moreover , the model size is fixed as it dynamically
#   generates adaptation parameters . xxmaj we apply our proposed xxup xxunk to deep
#   bidirectional xxup lstm acoustic models and evaluate them on two benchmark datasets
#   for large vocabulary xxup asr experiments : xxup xxunk and xxup ted - xxup xxunk release 2 . xxmaj the
#   experimental results show that our xxup xxunk improves neural acoustic models in terms
#   of transcription accuracy by dynamically adapting to various speakers and
#   environments .
#  ,xxbos xxmaj susceptibility xxmaj propagation by xxmaj using xxmaj diagonal xxmaj consistency a susceptibility propagation that is constructed by combining a belief
#   propagation and a linear response method is used for approximate computation
#   for xxmaj markov random fields . xxmaj herein , we formulate a new , improved susceptibility
#   propagation by using the concept of a diagonal matching method that is based on
#   mean - field approaches to inverse xxmaj ising problems . xxmaj the proposed susceptibility
#   propagation is robust for various network structures , and it is reduced to the
#   ordinary susceptibility propagation and to the adaptive
#   xxmaj thouless - xxmaj anderson - xxmaj palmer equation in special cases .
#  ,xxbos xxmaj the xxmaj robot xxmaj routing xxmaj problem for xxmaj collecting xxmaj aggregate xxmaj stochastic xxmaj rewards xxmaj we propose a new model for formalizing reward collection problems on graphs
#   with dynamically generated rewards which may appear and disappear based on a
#   stochastic model . xxmaj the * robot routing problem * is modeled as a graph whose nodes
#   are stochastic processes generating potential rewards over discrete time . xxmaj the
#   rewards are generated according to the stochastic process , but at each step , an
#   existing reward disappears with a given probability . xxmaj the edges in the graph
#   encode the ( unit - distance ) paths between the rewards ' locations . xxmaj on visiting a
#   node , the robot collects the accumulated reward at the node at that time , but
#   traveling between the nodes takes time . xxmaj the optimization question asks to
#   compute an optimal ( or epsilon - optimal ) path that maximizes the expected
#   collected rewards .
#   xxmaj we consider the finite and infinite - horizon robot routing problems . xxmaj for
#   finite - horizon , the goal is to maximize the total expected reward , while for
#   infinite horizon we consider limit - average objectives . xxmaj we study the
#   computational and strategy complexity of these problems , establish xxup np - lower
#   bounds and show that optimal strategies require memory in general . xxmaj we also
#   provide an algorithm for computing epsilon - optimal infinite paths for arbitrary
#   epsilon > 0 .
#  ,xxbos xxmaj probability , xxmaj statistics and xxmaj planet xxmaj earth , i : xxmaj xxunk covariances xxmaj the study of covariances ( or positive definite functions ) on the sphere ( the
#   xxmaj earth , in our motivation ) goes back to xxmaj bochner and xxmaj xxunk ( xxunk - xxunk ) and to
#   the first author ( 1969 , 1973 ) , among others . xxmaj extending to the xxunk case
#   ( sphere cross line , for position and time ) was for a long time an obstacle to
#   geostatistical modelling . xxmaj the characterisation question here was raised by the
#   authors and xxmaj xxunk in 2016 , and answered by xxmaj xxunk and xxmaj xxunk in 2017 .
#   xxmaj extensions to multiple products ( of spheres and lines ) follows similarly
#   ( xxmaj xxunk , xxmaj xxunk and xxmaj xxunk , 2016 ) . xxmaj we survey results of this type , and
#   related applications e.g. in numerical weather prediction .
#  ,xxbos xxmaj counting the number of metastable states in the modularity landscape : xxmaj algorithmic detectability limit of greedy algorithms in community detection xxmaj modularity maximization using greedy algorithms continues to be a popular
#   approach toward community detection in graphs , even after various better
#   forming algorithms have been proposed . xxmaj apart from its clear mechanism and ease
#   of implementation , this approach is persistently popular because , presumably ,
#   its risk of algorithmic failure is not well understood . xxmaj this xxmaj rapid
#   xxmaj communication provides insight into this issue by estimating the algorithmic
#   performance limit of modularity maximization . xxmaj this is achieved by counting the
#   number of metastable states under a local update rule . xxmaj our results offer a
#   quantitative insight into the level of sparsity at which a greedy algorithm
#   typically fails .
#
# y: MultiCategoryList
# Computer Science,Mathematics;Statistics,Computer Science;Mathematics,Physics;Statistics,Computer Science
# Path: .;
#
# Test: LabelList (8989 items)
# x: TextList
# xxbos xxmaj closed - form xxmaj marginal xxmaj likelihood in xxmaj gamma - xxmaj poisson xxmaj matrix xxmaj factorization xxmaj we present novel understandings of the xxmaj gamma - xxmaj poisson ( gap ) model , a
#   probabilistic matrix factorization model for count data . xxmaj we show that gap can
#   be rewritten free of the score / activation matrix . xxmaj this gives us new insights
#   about the estimation of the topic / dictionary matrix by maximum marginal
#   likelihood estimation . xxmaj in particular , this explains the robustness of this
#   estimator to over - specified values of the factorization rank , especially its
#   ability to automatically prune irrelevant dictionary columns , as empirically
#   observed in previous work . xxmaj the marginalization of the activation matrix leads
#   in turn to a new xxmaj monte xxmaj carlo xxmaj expectation - xxmaj maximization algorithm with favorable
#   properties .
#  ,xxbos xxmaj laboratory mid - xxup ir spectra of xxunk and xxunk meteorites . xxmaj searching for observables of planetesimal debris xxmaj meteorites contain minerals from xxmaj solar xxmaj system asteroids with different
#   properties ( like size , presence of water , core formation ) . xxmaj we provide new
#   mid - xxup ir transmission spectra of xxunk meteorites to obtain templates of how
#   mid - xxup ir spectra of asteroidal debris would look like . xxmaj this is essential for
#   interpreting mid - xxup ir spectra of past and future space observatories , like the
#   xxmaj james xxmaj webb xxmaj space xxmaj telescope . xxmaj we show that the transmission spectra of wet and
#   dry chondrites , carbonaceous and ordinary chondrites and xxunk and
#   xxunk meteorites are distinctly different in a way one can distinguish in
#   astronomical mid - xxup ir spectra . xxmaj the two observables that spectroscopically
#   separate the different meteorites groups ( and thus the different types of
#   parent bodies ) are the xxunk - olivine feature strength ratio and the peak
#   shift of the olivine spectral features due to an increase in the iron
#   concentration of the olivine .
#  ,xxbos xxmaj case xxmaj for xxmaj static xxup xxunk xxmaj aggregation in wlans xxmaj frame aggregation is a mechanism by which multiple frames are combined into a
#   single transmission unit over the air . xxmaj frames aggregated at the xxup xxunk level use
#   a common xxup crc check to enforce integrity . xxmaj for longer aggregated xxup xxunk frames ,
#   the packet error rate increases significantly for the same bit error rate .
#   xxmaj hence , multiple studies have proposed doing xxup xxunk aggregation adaptively based
#   on the error rate . xxmaj this study evaluates if there is a \ xxunk }
#   advantage in doing adaptive xxup xxunk aggregation based on the link bit error rate .
#   xxmaj evaluations on a model show that instead of implementing a complex adaptive
#   xxup xxunk frame aggregation mechanism which impact queuing and other implementation
#   aspects , it is easier to influence packet error rate with traditional
#   mechanisms while keeping the xxup xxunk aggregation logic simple .
#  ,xxbos xxmaj the $ xxunk xxmaj survey : the inner disk intermediate - age open cluster xxup ngc xxunk xxmaj milky xxmaj way open clusters are very diverse in terms of age , chemical
#   composition , and kinematic properties . xxmaj intermediate - age and old open clusters
#   are less common , and it is even harder to find them inside the solar
#   xxmaj galactocentric radius , due to the high mortality rate and strong extinction
#   inside this region . xxup ngc xxunk is one of the inner disk open clusters ( xxunk )
#   observed by the $ xxunk survey ( xxup xxunk ) . xxmaj this cluster is an important target
#   for calibrating the abundances derived in the survey due to the kinematic and
#   chemical homogeneity of the members in open clusters . xxmaj using the measurements
#   from $ xxunk internal data release 4 ( xxunk ) , we identify 95 main - sequence
#   dwarfs as cluster members from the xxup xxunk target list , and eight giants as
#   cluster members from the xxup uves target list . xxmaj the dwarf cluster members have a
#   median radial velocity of $ xxunk \ xxunk $ km s$^{-1}$ , while the giant cluster
#   members have a median radial velocity of $ 12.0 \ xxunk $ km s$^{-1}$ and a median
#   [ xxmaj fe / h ] of $ 0.10 \ pm0.02 $ dex . xxmaj the color - magnitude diagram of these cluster
#   members suggests an age of $ 0.9 \ xxunk $ xxmaj gyr , with $ ( m - xxup xxunk $ and
#   $ xxup e(b - xxup xxunk xxmaj we perform the first detailed chemical abundance analysis of xxup ngc
#   xxunk , including 27 elemental species . xxmaj to gain a more general picture about
#   xxunk , the measurements of xxup ngc xxunk are compared with those of other xxunk
#   previously studied by xxup xxunk , that is , xxup ngc xxunk , xxmaj xxunk 20 , xxup ngc xxunk , and
#   xxmaj berkeley 81 . xxup ngc xxunk shows similar c , n , xxmaj na , and xxmaj al abundances as other xxunk .
#   xxmaj these elements are compared with xxunk models as a function of
#   cluster turn - off mass . xxmaj the $ \ alpha$ , iron - peak , and neutron - capture elements
#   are also explored in a self - consistent way .
#  ,xxbos xxmaj witness - xxmaj functions versus xxmaj interpretation - xxmaj functions for xxmaj secrecy in xxmaj cryptographic xxmaj protocols : xxmaj what to xxmaj choose ? xxmaj proving that a cryptographic protocol is correct for secrecy is a hard task .
#   xxmaj one of the strongest strategies to reach this goal is to show that it is
#   increasing , which means that the security level of every single atomic message
#   exchanged in the protocol , safely evaluated , never xxunk . xxmaj recently , two
#   families of functions have been proposed to measure the security level of
#   atomic messages . xxmaj the first one is the family of interpretation - functions . xxmaj the
#   second is the family of witness - functions . xxmaj in this paper , we show that the
#   witness - functions are more efficient than interpretation - functions . xxmaj we give a
#   detailed analysis of an ad - hoc protocol on which the witness - functions succeed
#   in proving its correctness for secrecy while the interpretation - functions fail
#   to do so .
#
# y: EmptyLabelList
# ,,,,
# Path: ., model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(28720, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(28720, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1152, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1152, 1152, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1152, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=6, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of BCEWithLogitsLoss(), metrics=[functools.partial(<function accuracy_thresh at 0x7f73e35fbe18>, thresh=0.2), functools.partial(<function fbeta at 0x7f73e35fba60>, thresh=0.2, beta=1)], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[...], layer_groups=[Sequential(
#   (0): Embedding(28720, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(28720, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=6, bias=True)
#     )
#   )
# )], add_time=True, silent=False)
# alpha: 2.0
# beta: 1.0], layer_groups=[Sequential(
#   (0): Embedding(28720, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(28720, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=6, bias=True)
#     )
#   )
# )], add_time=True, silent=False)

# %%
learn_classifier.freeze_to(-3)

# %%
learn_classifier.fit_one_cycle(2, slice(5e-3/(2.6**4), 5e-3), moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.172983</td>
#       <td>0.179188</td>
#       <td>0.908202</td>
#       <td>0.830854</td>
#       <td>05:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.156373</td>
#       <td>0.171529</td>
#       <td>0.913368</td>
#       <td>0.843395</td>
#       <td>05:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_classifier.save('/content/drive/My Drive/Analytics Vidhya/models/third')
learn_classifier.load('/content/drive/My Drive/Analytics Vidhya/models/third')
# Out:
# RNNLearner(data=TextClasDataBunch;
#
# Train: LabelList (18875 items)
# x: TextList
# xxbos xxmaj reconstructing xxmaj subject - xxmaj specific xxmaj effect xxmaj maps xxmaj predictive models allow subject - specific inference when analyzing disease
#   related alterations in neuroimaging data . xxmaj given a subject 's data , inference can
#   be made at two levels : global , i.e. xxunk condition presence for the
#   subject , and local , i.e. detecting condition effect on each individual
#   measurement extracted from the subject 's data . xxmaj while global inference is widely
#   used , local inference , which can be used to form subject - specific effect maps ,
#   is rarely used because existing models often yield noisy detections composed of
#   dispersed isolated islands . xxmaj in this article , we propose a reconstruction
#   method , named xxup rsm , to improve subject - specific detections of predictive
#   modeling approaches and in particular , binary classifiers . xxup rsm specifically
#   aims to reduce noise due to sampling error associated with using a finite
#   sample of examples to train classifiers . xxmaj the proposed method is a wrapper - type
#   algorithm that can be used with different binary classifiers in a diagnostic
#   manner , i.e. without information on condition presence . xxmaj reconstruction is posed
#   as a xxmaj maximum - a - xxmaj posteriori problem with a prior model whose parameters are
#   estimated from training data in a classifier - specific fashion . xxmaj experimental
#   evaluation is performed on synthetically generated data and data from the
#   xxmaj alzheimer 's xxmaj disease xxmaj neuroimaging xxmaj initiative ( xxup adni ) database . xxmaj results on
#   synthetic data demonstrate that using xxup rsm yields higher detection accuracy
#   compared to using models directly or with bootstrap averaging . xxmaj analyses on the
#   xxup adni dataset show that xxup rsm can also improve correlation between
#   subject - specific detections in cortical thickness data and non - imaging markers
#   of xxmaj alzheimer 's xxmaj disease ( xxup ad ) , such as the xxmaj mini xxmaj mental xxmaj state xxmaj examination xxmaj score
#   and xxmaj xxunk xxmaj fluid xxunk \ beta$ levels . xxmaj further reliability studies on
#   the longitudinal xxup adni dataset show improvement on detection reliability when
#   xxup rsm is used .
#  ,xxbos xxmaj rotation xxmaj invariance xxmaj neural xxmaj network xxmaj rotation invariance and translation invariance have great values in image
#   recognition tasks . xxmaj in this paper , we bring a new architecture in convolutional
#   neural network ( xxup cnn ) named cyclic convolutional layer to achieve rotation
#   invariance in xxup 2-d symbol recognition . xxmaj we can also get the position and
#   orientation of the xxup 2-d symbol by the network to achieve detection purpose for
#   multiple non - overlap target . xxmaj last but not least , this architecture can achieve
#   one - shot learning in some cases using those invariance .
#  ,xxbos xxmaj spherical polyharmonics and xxmaj poisson kernels for polyharmonic functions xxmaj we introduce and develop the notion of spherical polyharmonics , which are a
#   natural generalisation of spherical harmonics . xxmaj in particular we study the
#   theory of zonal polyharmonics , which allows us , analogously to zonal harmonics ,
#   to construct xxmaj poisson kernels for polyharmonic functions on the union of rotated
#   balls . xxmaj we find the representation of xxmaj poisson kernels and zonal polyharmonics in
#   terms of the xxmaj gegenbauer polynomials . xxmaj we show the connection between the
#   classical xxmaj poisson kernel for harmonic functions on the ball , xxmaj poisson kernels
#   for polyharmonic functions on the union of rotated balls , and the xxmaj cauchy - xxmaj xxunk
#   kernel for holomorphic functions on the xxmaj lie ball .
#  ,xxbos a finite element approximation for the stochastic xxmaj maxwell -- xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert system xxmaj the stochastic xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert ( xxup llg ) equation coupled with the
#   xxmaj maxwell equations ( the so called stochastic xxup xxunk system ) describes the creation
#   of domain walls and vortices ( fundamental objects for the novel nanostructured
#   magnetic memories ) . xxmaj we first reformulate the stochastic xxup llg equation into an
#   equation with time - differentiable solutions . xxmaj we then propose a convergent
#   $ \ xxunk scheme to approximate the solutions of the reformulated system .
#   xxmaj as a consequence , we prove convergence of the approximate solutions , with no or
#   minor conditions on time and space steps ( depending on the value of $ \ theta$ ) .
#   xxmaj hence , we prove the existence of weak martingale solutions of the stochastic
#   xxup xxunk system . xxmaj numerical results are presented to show applicability of the
#   method .
#  ,xxbos xxmaj comparative study of xxmaj discrete xxmaj wavelet xxmaj transforms and xxmaj wavelet xxmaj tensor xxmaj train decomposition to feature extraction of xxup ftir data of medicinal plants xxmaj fourier - transform infra - red ( xxup ftir ) spectra of samples from 7 plant species
#   were used to explore the influence of preprocessing and feature extraction on
#   efficiency of machine learning algorithms . xxmaj wavelet xxmaj tensor xxmaj train ( xxup wtt ) and
#   xxmaj discrete xxmaj wavelet xxmaj transforms ( xxup dwt ) were compared as feature extraction
#   techniques for xxup ftir data of medicinal plants . xxmaj various combinations of signal
#   processing steps showed different behavior when applied to classification and
#   clustering tasks . xxmaj best results for xxup wtt and xxup dwt found through grid search were
#   similar , significantly improving quality of clustering as well as
#   classification accuracy for tuned logistic regression in comparison to original
#   spectra . xxmaj unlike xxup dwt , xxup wtt has only one parameter to be tuned ( rank ) , making it a
#   more versatile and easier to use as a data processing tool in various signal
#   processing applications .
#
# y: MultiCategoryList
# Computer Science,Computer Science,Mathematics,Mathematics,Computer Science;Statistics
# Path: .;
#
# Valid: LabelList (2097 items)
# x: TextList
# xxbos xxmaj dynamic xxmaj layer xxmaj normalization for xxmaj adaptive xxmaj neural xxmaj acoustic xxmaj modeling in xxmaj speech xxmaj recognition xxmaj layer normalization is a recently introduced technique for normalizing the
#   activities of neurons in deep neural networks to improve the training speed and
#   stability . xxmaj in this paper , we introduce a new layer normalization technique
#   called xxmaj dynamic xxmaj layer xxmaj normalization ( xxup xxunk ) for adaptive neural acoustic modeling
#   in speech recognition . xxmaj by dynamically generating the scaling and shifting
#   parameters in layer normalization , xxup xxunk adapts neural acoustic models to the
#   acoustic variability arising from various factors such as speakers , channel
#   noises , and environments . xxmaj unlike other adaptive acoustic models , our proposed
#   approach does not require additional adaptation data or speaker information
#   such as i - vectors . xxmaj moreover , the model size is fixed as it dynamically
#   generates adaptation parameters . xxmaj we apply our proposed xxup xxunk to deep
#   bidirectional xxup lstm acoustic models and evaluate them on two benchmark datasets
#   for large vocabulary xxup asr experiments : xxup xxunk and xxup ted - xxup xxunk release 2 . xxmaj the
#   experimental results show that our xxup xxunk improves neural acoustic models in terms
#   of transcription accuracy by dynamically adapting to various speakers and
#   environments .
#  ,xxbos xxmaj susceptibility xxmaj propagation by xxmaj using xxmaj diagonal xxmaj consistency a susceptibility propagation that is constructed by combining a belief
#   propagation and a linear response method is used for approximate computation
#   for xxmaj markov random fields . xxmaj herein , we formulate a new , improved susceptibility
#   propagation by using the concept of a diagonal matching method that is based on
#   mean - field approaches to inverse xxmaj ising problems . xxmaj the proposed susceptibility
#   propagation is robust for various network structures , and it is reduced to the
#   ordinary susceptibility propagation and to the adaptive
#   xxmaj thouless - xxmaj anderson - xxmaj palmer equation in special cases .
#  ,xxbos xxmaj the xxmaj robot xxmaj routing xxmaj problem for xxmaj collecting xxmaj aggregate xxmaj stochastic xxmaj rewards xxmaj we propose a new model for formalizing reward collection problems on graphs
#   with dynamically generated rewards which may appear and disappear based on a
#   stochastic model . xxmaj the * robot routing problem * is modeled as a graph whose nodes
#   are stochastic processes generating potential rewards over discrete time . xxmaj the
#   rewards are generated according to the stochastic process , but at each step , an
#   existing reward disappears with a given probability . xxmaj the edges in the graph
#   encode the ( unit - distance ) paths between the rewards ' locations . xxmaj on visiting a
#   node , the robot collects the accumulated reward at the node at that time , but
#   traveling between the nodes takes time . xxmaj the optimization question asks to
#   compute an optimal ( or epsilon - optimal ) path that maximizes the expected
#   collected rewards .
#   xxmaj we consider the finite and infinite - horizon robot routing problems . xxmaj for
#   finite - horizon , the goal is to maximize the total expected reward , while for
#   infinite horizon we consider limit - average objectives . xxmaj we study the
#   computational and strategy complexity of these problems , establish xxup np - lower
#   bounds and show that optimal strategies require memory in general . xxmaj we also
#   provide an algorithm for computing epsilon - optimal infinite paths for arbitrary
#   epsilon > 0 .
#  ,xxbos xxmaj probability , xxmaj statistics and xxmaj planet xxmaj earth , i : xxmaj xxunk covariances xxmaj the study of covariances ( or positive definite functions ) on the sphere ( the
#   xxmaj earth , in our motivation ) goes back to xxmaj bochner and xxmaj xxunk ( xxunk - xxunk ) and to
#   the first author ( 1969 , 1973 ) , among others . xxmaj extending to the xxunk case
#   ( sphere cross line , for position and time ) was for a long time an obstacle to
#   geostatistical modelling . xxmaj the characterisation question here was raised by the
#   authors and xxmaj xxunk in 2016 , and answered by xxmaj xxunk and xxmaj xxunk in 2017 .
#   xxmaj extensions to multiple products ( of spheres and lines ) follows similarly
#   ( xxmaj xxunk , xxmaj xxunk and xxmaj xxunk , 2016 ) . xxmaj we survey results of this type , and
#   related applications e.g. in numerical weather prediction .
#  ,xxbos xxmaj counting the number of metastable states in the modularity landscape : xxmaj algorithmic detectability limit of greedy algorithms in community detection xxmaj modularity maximization using greedy algorithms continues to be a popular
#   approach toward community detection in graphs , even after various better
#   forming algorithms have been proposed . xxmaj apart from its clear mechanism and ease
#   of implementation , this approach is persistently popular because , presumably ,
#   its risk of algorithmic failure is not well understood . xxmaj this xxmaj rapid
#   xxmaj communication provides insight into this issue by estimating the algorithmic
#   performance limit of modularity maximization . xxmaj this is achieved by counting the
#   number of metastable states under a local update rule . xxmaj our results offer a
#   quantitative insight into the level of sparsity at which a greedy algorithm
#   typically fails .
#
# y: MultiCategoryList
# Computer Science,Mathematics;Statistics,Computer Science;Mathematics,Physics;Statistics,Computer Science
# Path: .;
#
# Test: LabelList (8989 items)
# x: TextList
# xxbos xxmaj closed - form xxmaj marginal xxmaj likelihood in xxmaj gamma - xxmaj poisson xxmaj matrix xxmaj factorization xxmaj we present novel understandings of the xxmaj gamma - xxmaj poisson ( gap ) model , a
#   probabilistic matrix factorization model for count data . xxmaj we show that gap can
#   be rewritten free of the score / activation matrix . xxmaj this gives us new insights
#   about the estimation of the topic / dictionary matrix by maximum marginal
#   likelihood estimation . xxmaj in particular , this explains the robustness of this
#   estimator to over - specified values of the factorization rank , especially its
#   ability to automatically prune irrelevant dictionary columns , as empirically
#   observed in previous work . xxmaj the marginalization of the activation matrix leads
#   in turn to a new xxmaj monte xxmaj carlo xxmaj expectation - xxmaj maximization algorithm with favorable
#   properties .
#  ,xxbos xxmaj laboratory mid - xxup ir spectra of xxunk and xxunk meteorites . xxmaj searching for observables of planetesimal debris xxmaj meteorites contain minerals from xxmaj solar xxmaj system asteroids with different
#   properties ( like size , presence of water , core formation ) . xxmaj we provide new
#   mid - xxup ir transmission spectra of xxunk meteorites to obtain templates of how
#   mid - xxup ir spectra of asteroidal debris would look like . xxmaj this is essential for
#   interpreting mid - xxup ir spectra of past and future space observatories , like the
#   xxmaj james xxmaj webb xxmaj space xxmaj telescope . xxmaj we show that the transmission spectra of wet and
#   dry chondrites , carbonaceous and ordinary chondrites and xxunk and
#   xxunk meteorites are distinctly different in a way one can distinguish in
#   astronomical mid - xxup ir spectra . xxmaj the two observables that spectroscopically
#   separate the different meteorites groups ( and thus the different types of
#   parent bodies ) are the xxunk - olivine feature strength ratio and the peak
#   shift of the olivine spectral features due to an increase in the iron
#   concentration of the olivine .
#  ,xxbos xxmaj case xxmaj for xxmaj static xxup xxunk xxmaj aggregation in wlans xxmaj frame aggregation is a mechanism by which multiple frames are combined into a
#   single transmission unit over the air . xxmaj frames aggregated at the xxup xxunk level use
#   a common xxup crc check to enforce integrity . xxmaj for longer aggregated xxup xxunk frames ,
#   the packet error rate increases significantly for the same bit error rate .
#   xxmaj hence , multiple studies have proposed doing xxup xxunk aggregation adaptively based
#   on the error rate . xxmaj this study evaluates if there is a \ xxunk }
#   advantage in doing adaptive xxup xxunk aggregation based on the link bit error rate .
#   xxmaj evaluations on a model show that instead of implementing a complex adaptive
#   xxup xxunk frame aggregation mechanism which impact queuing and other implementation
#   aspects , it is easier to influence packet error rate with traditional
#   mechanisms while keeping the xxup xxunk aggregation logic simple .
#  ,xxbos xxmaj the $ xxunk xxmaj survey : the inner disk intermediate - age open cluster xxup ngc xxunk xxmaj milky xxmaj way open clusters are very diverse in terms of age , chemical
#   composition , and kinematic properties . xxmaj intermediate - age and old open clusters
#   are less common , and it is even harder to find them inside the solar
#   xxmaj galactocentric radius , due to the high mortality rate and strong extinction
#   inside this region . xxup ngc xxunk is one of the inner disk open clusters ( xxunk )
#   observed by the $ xxunk survey ( xxup xxunk ) . xxmaj this cluster is an important target
#   for calibrating the abundances derived in the survey due to the kinematic and
#   chemical homogeneity of the members in open clusters . xxmaj using the measurements
#   from $ xxunk internal data release 4 ( xxunk ) , we identify 95 main - sequence
#   dwarfs as cluster members from the xxup xxunk target list , and eight giants as
#   cluster members from the xxup uves target list . xxmaj the dwarf cluster members have a
#   median radial velocity of $ xxunk \ xxunk $ km s$^{-1}$ , while the giant cluster
#   members have a median radial velocity of $ 12.0 \ xxunk $ km s$^{-1}$ and a median
#   [ xxmaj fe / h ] of $ 0.10 \ pm0.02 $ dex . xxmaj the color - magnitude diagram of these cluster
#   members suggests an age of $ 0.9 \ xxunk $ xxmaj gyr , with $ ( m - xxup xxunk $ and
#   $ xxup e(b - xxup xxunk xxmaj we perform the first detailed chemical abundance analysis of xxup ngc
#   xxunk , including 27 elemental species . xxmaj to gain a more general picture about
#   xxunk , the measurements of xxup ngc xxunk are compared with those of other xxunk
#   previously studied by xxup xxunk , that is , xxup ngc xxunk , xxmaj xxunk 20 , xxup ngc xxunk , and
#   xxmaj berkeley 81 . xxup ngc xxunk shows similar c , n , xxmaj na , and xxmaj al abundances as other xxunk .
#   xxmaj these elements are compared with xxunk models as a function of
#   cluster turn - off mass . xxmaj the $ \ alpha$ , iron - peak , and neutron - capture elements
#   are also explored in a self - consistent way .
#  ,xxbos xxmaj witness - xxmaj functions versus xxmaj interpretation - xxmaj functions for xxmaj secrecy in xxmaj cryptographic xxmaj protocols : xxmaj what to xxmaj choose ? xxmaj proving that a cryptographic protocol is correct for secrecy is a hard task .
#   xxmaj one of the strongest strategies to reach this goal is to show that it is
#   increasing , which means that the security level of every single atomic message
#   exchanged in the protocol , safely evaluated , never xxunk . xxmaj recently , two
#   families of functions have been proposed to measure the security level of
#   atomic messages . xxmaj the first one is the family of interpretation - functions . xxmaj the
#   second is the family of witness - functions . xxmaj in this paper , we show that the
#   witness - functions are more efficient than interpretation - functions . xxmaj we give a
#   detailed analysis of an ad - hoc protocol on which the witness - functions succeed
#   in proving its correctness for secrecy while the interpretation - functions fail
#   to do so .
#
# y: EmptyLabelList
# ,,,,
# Path: ., model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(28720, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(28720, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1152, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1152, 1152, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1152, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=6, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of BCEWithLogitsLoss(), metrics=[functools.partial(<function accuracy_thresh at 0x7f73e35fbe18>, thresh=0.2), functools.partial(<function fbeta at 0x7f73e35fba60>, thresh=0.2, beta=1)], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[RNNTrainer
# learn: RNNLearner(data=TextClasDataBunch;
#
# Train: LabelList (18875 items)
# x: TextList
# xxbos xxmaj reconstructing xxmaj subject - xxmaj specific xxmaj effect xxmaj maps xxmaj predictive models allow subject - specific inference when analyzing disease
#   related alterations in neuroimaging data . xxmaj given a subject 's data , inference can
#   be made at two levels : global , i.e. xxunk condition presence for the
#   subject , and local , i.e. detecting condition effect on each individual
#   measurement extracted from the subject 's data . xxmaj while global inference is widely
#   used , local inference , which can be used to form subject - specific effect maps ,
#   is rarely used because existing models often yield noisy detections composed of
#   dispersed isolated islands . xxmaj in this article , we propose a reconstruction
#   method , named xxup rsm , to improve subject - specific detections of predictive
#   modeling approaches and in particular , binary classifiers . xxup rsm specifically
#   aims to reduce noise due to sampling error associated with using a finite
#   sample of examples to train classifiers . xxmaj the proposed method is a wrapper - type
#   algorithm that can be used with different binary classifiers in a diagnostic
#   manner , i.e. without information on condition presence . xxmaj reconstruction is posed
#   as a xxmaj maximum - a - xxmaj posteriori problem with a prior model whose parameters are
#   estimated from training data in a classifier - specific fashion . xxmaj experimental
#   evaluation is performed on synthetically generated data and data from the
#   xxmaj alzheimer 's xxmaj disease xxmaj neuroimaging xxmaj initiative ( xxup adni ) database . xxmaj results on
#   synthetic data demonstrate that using xxup rsm yields higher detection accuracy
#   compared to using models directly or with bootstrap averaging . xxmaj analyses on the
#   xxup adni dataset show that xxup rsm can also improve correlation between
#   subject - specific detections in cortical thickness data and non - imaging markers
#   of xxmaj alzheimer 's xxmaj disease ( xxup ad ) , such as the xxmaj mini xxmaj mental xxmaj state xxmaj examination xxmaj score
#   and xxmaj xxunk xxmaj fluid xxunk \ beta$ levels . xxmaj further reliability studies on
#   the longitudinal xxup adni dataset show improvement on detection reliability when
#   xxup rsm is used .
#  ,xxbos xxmaj rotation xxmaj invariance xxmaj neural xxmaj network xxmaj rotation invariance and translation invariance have great values in image
#   recognition tasks . xxmaj in this paper , we bring a new architecture in convolutional
#   neural network ( xxup cnn ) named cyclic convolutional layer to achieve rotation
#   invariance in xxup 2-d symbol recognition . xxmaj we can also get the position and
#   orientation of the xxup 2-d symbol by the network to achieve detection purpose for
#   multiple non - overlap target . xxmaj last but not least , this architecture can achieve
#   one - shot learning in some cases using those invariance .
#  ,xxbos xxmaj spherical polyharmonics and xxmaj poisson kernels for polyharmonic functions xxmaj we introduce and develop the notion of spherical polyharmonics , which are a
#   natural generalisation of spherical harmonics . xxmaj in particular we study the
#   theory of zonal polyharmonics , which allows us , analogously to zonal harmonics ,
#   to construct xxmaj poisson kernels for polyharmonic functions on the union of rotated
#   balls . xxmaj we find the representation of xxmaj poisson kernels and zonal polyharmonics in
#   terms of the xxmaj gegenbauer polynomials . xxmaj we show the connection between the
#   classical xxmaj poisson kernel for harmonic functions on the ball , xxmaj poisson kernels
#   for polyharmonic functions on the union of rotated balls , and the xxmaj cauchy - xxmaj xxunk
#   kernel for holomorphic functions on the xxmaj lie ball .
#  ,xxbos a finite element approximation for the stochastic xxmaj maxwell -- xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert system xxmaj the stochastic xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert ( xxup llg ) equation coupled with the
#   xxmaj maxwell equations ( the so called stochastic xxup xxunk system ) describes the creation
#   of domain walls and vortices ( fundamental objects for the novel nanostructured
#   magnetic memories ) . xxmaj we first reformulate the stochastic xxup llg equation into an
#   equation with time - differentiable solutions . xxmaj we then propose a convergent
#   $ \ xxunk scheme to approximate the solutions of the reformulated system .
#   xxmaj as a consequence , we prove convergence of the approximate solutions , with no or
#   minor conditions on time and space steps ( depending on the value of $ \ theta$ ) .
#   xxmaj hence , we prove the existence of weak martingale solutions of the stochastic
#   xxup xxunk system . xxmaj numerical results are presented to show applicability of the
#   method .
#  ,xxbos xxmaj comparative study of xxmaj discrete xxmaj wavelet xxmaj transforms and xxmaj wavelet xxmaj tensor xxmaj train decomposition to feature extraction of xxup ftir data of medicinal plants xxmaj fourier - transform infra - red ( xxup ftir ) spectra of samples from 7 plant species
#   were used to explore the influence of preprocessing and feature extraction on
#   efficiency of machine learning algorithms . xxmaj wavelet xxmaj tensor xxmaj train ( xxup wtt ) and
#   xxmaj discrete xxmaj wavelet xxmaj transforms ( xxup dwt ) were compared as feature extraction
#   techniques for xxup ftir data of medicinal plants . xxmaj various combinations of signal
#   processing steps showed different behavior when applied to classification and
#   clustering tasks . xxmaj best results for xxup wtt and xxup dwt found through grid search were
#   similar , significantly improving quality of clustering as well as
#   classification accuracy for tuned logistic regression in comparison to original
#   spectra . xxmaj unlike xxup dwt , xxup wtt has only one parameter to be tuned ( rank ) , making it a
#   more versatile and easier to use as a data processing tool in various signal
#   processing applications .
#
# y: MultiCategoryList
# Computer Science,Computer Science,Mathematics,Mathematics,Computer Science;Statistics
# Path: .;
#
# Valid: LabelList (2097 items)
# x: TextList
# xxbos xxmaj dynamic xxmaj layer xxmaj normalization for xxmaj adaptive xxmaj neural xxmaj acoustic xxmaj modeling in xxmaj speech xxmaj recognition xxmaj layer normalization is a recently introduced technique for normalizing the
#   activities of neurons in deep neural networks to improve the training speed and
#   stability . xxmaj in this paper , we introduce a new layer normalization technique
#   called xxmaj dynamic xxmaj layer xxmaj normalization ( xxup xxunk ) for adaptive neural acoustic modeling
#   in speech recognition . xxmaj by dynamically generating the scaling and shifting
#   parameters in layer normalization , xxup xxunk adapts neural acoustic models to the
#   acoustic variability arising from various factors such as speakers , channel
#   noises , and environments . xxmaj unlike other adaptive acoustic models , our proposed
#   approach does not require additional adaptation data or speaker information
#   such as i - vectors . xxmaj moreover , the model size is fixed as it dynamically
#   generates adaptation parameters . xxmaj we apply our proposed xxup xxunk to deep
#   bidirectional xxup lstm acoustic models and evaluate them on two benchmark datasets
#   for large vocabulary xxup asr experiments : xxup xxunk and xxup ted - xxup xxunk release 2 . xxmaj the
#   experimental results show that our xxup xxunk improves neural acoustic models in terms
#   of transcription accuracy by dynamically adapting to various speakers and
#   environments .
#  ,xxbos xxmaj susceptibility xxmaj propagation by xxmaj using xxmaj diagonal xxmaj consistency a susceptibility propagation that is constructed by combining a belief
#   propagation and a linear response method is used for approximate computation
#   for xxmaj markov random fields . xxmaj herein , we formulate a new , improved susceptibility
#   propagation by using the concept of a diagonal matching method that is based on
#   mean - field approaches to inverse xxmaj ising problems . xxmaj the proposed susceptibility
#   propagation is robust for various network structures , and it is reduced to the
#   ordinary susceptibility propagation and to the adaptive
#   xxmaj thouless - xxmaj anderson - xxmaj palmer equation in special cases .
#  ,xxbos xxmaj the xxmaj robot xxmaj routing xxmaj problem for xxmaj collecting xxmaj aggregate xxmaj stochastic xxmaj rewards xxmaj we propose a new model for formalizing reward collection problems on graphs
#   with dynamically generated rewards which may appear and disappear based on a
#   stochastic model . xxmaj the * robot routing problem * is modeled as a graph whose nodes
#   are stochastic processes generating potential rewards over discrete time . xxmaj the
#   rewards are generated according to the stochastic process , but at each step , an
#   existing reward disappears with a given probability . xxmaj the edges in the graph
#   encode the ( unit - distance ) paths between the rewards ' locations . xxmaj on visiting a
#   node , the robot collects the accumulated reward at the node at that time , but
#   traveling between the nodes takes time . xxmaj the optimization question asks to
#   compute an optimal ( or epsilon - optimal ) path that maximizes the expected
#   collected rewards .
#   xxmaj we consider the finite and infinite - horizon robot routing problems . xxmaj for
#   finite - horizon , the goal is to maximize the total expected reward , while for
#   infinite horizon we consider limit - average objectives . xxmaj we study the
#   computational and strategy complexity of these problems , establish xxup np - lower
#   bounds and show that optimal strategies require memory in general . xxmaj we also
#   provide an algorithm for computing epsilon - optimal infinite paths for arbitrary
#   epsilon > 0 .
#  ,xxbos xxmaj probability , xxmaj statistics and xxmaj planet xxmaj earth , i : xxmaj xxunk covariances xxmaj the study of covariances ( or positive definite functions ) on the sphere ( the
#   xxmaj earth , in our motivation ) goes back to xxmaj bochner and xxmaj xxunk ( xxunk - xxunk ) and to
#   the first author ( 1969 , 1973 ) , among others . xxmaj extending to the xxunk case
#   ( sphere cross line , for position and time ) was for a long time an obstacle to
#   geostatistical modelling . xxmaj the characterisation question here was raised by the
#   authors and xxmaj xxunk in 2016 , and answered by xxmaj xxunk and xxmaj xxunk in 2017 .
#   xxmaj extensions to multiple products ( of spheres and lines ) follows similarly
#   ( xxmaj xxunk , xxmaj xxunk and xxmaj xxunk , 2016 ) . xxmaj we survey results of this type , and
#   related applications e.g. in numerical weather prediction .
#  ,xxbos xxmaj counting the number of metastable states in the modularity landscape : xxmaj algorithmic detectability limit of greedy algorithms in community detection xxmaj modularity maximization using greedy algorithms continues to be a popular
#   approach toward community detection in graphs , even after various better
#   forming algorithms have been proposed . xxmaj apart from its clear mechanism and ease
#   of implementation , this approach is persistently popular because , presumably ,
#   its risk of algorithmic failure is not well understood . xxmaj this xxmaj rapid
#   xxmaj communication provides insight into this issue by estimating the algorithmic
#   performance limit of modularity maximization . xxmaj this is achieved by counting the
#   number of metastable states under a local update rule . xxmaj our results offer a
#   quantitative insight into the level of sparsity at which a greedy algorithm
#   typically fails .
#
# y: MultiCategoryList
# Computer Science,Mathematics;Statistics,Computer Science;Mathematics,Physics;Statistics,Computer Science
# Path: .;
#
# Test: LabelList (8989 items)
# x: TextList
# xxbos xxmaj closed - form xxmaj marginal xxmaj likelihood in xxmaj gamma - xxmaj poisson xxmaj matrix xxmaj factorization xxmaj we present novel understandings of the xxmaj gamma - xxmaj poisson ( gap ) model , a
#   probabilistic matrix factorization model for count data . xxmaj we show that gap can
#   be rewritten free of the score / activation matrix . xxmaj this gives us new insights
#   about the estimation of the topic / dictionary matrix by maximum marginal
#   likelihood estimation . xxmaj in particular , this explains the robustness of this
#   estimator to over - specified values of the factorization rank , especially its
#   ability to automatically prune irrelevant dictionary columns , as empirically
#   observed in previous work . xxmaj the marginalization of the activation matrix leads
#   in turn to a new xxmaj monte xxmaj carlo xxmaj expectation - xxmaj maximization algorithm with favorable
#   properties .
#  ,xxbos xxmaj laboratory mid - xxup ir spectra of xxunk and xxunk meteorites . xxmaj searching for observables of planetesimal debris xxmaj meteorites contain minerals from xxmaj solar xxmaj system asteroids with different
#   properties ( like size , presence of water , core formation ) . xxmaj we provide new
#   mid - xxup ir transmission spectra of xxunk meteorites to obtain templates of how
#   mid - xxup ir spectra of asteroidal debris would look like . xxmaj this is essential for
#   interpreting mid - xxup ir spectra of past and future space observatories , like the
#   xxmaj james xxmaj webb xxmaj space xxmaj telescope . xxmaj we show that the transmission spectra of wet and
#   dry chondrites , carbonaceous and ordinary chondrites and xxunk and
#   xxunk meteorites are distinctly different in a way one can distinguish in
#   astronomical mid - xxup ir spectra . xxmaj the two observables that spectroscopically
#   separate the different meteorites groups ( and thus the different types of
#   parent bodies ) are the xxunk - olivine feature strength ratio and the peak
#   shift of the olivine spectral features due to an increase in the iron
#   concentration of the olivine .
#  ,xxbos xxmaj case xxmaj for xxmaj static xxup xxunk xxmaj aggregation in wlans xxmaj frame aggregation is a mechanism by which multiple frames are combined into a
#   single transmission unit over the air . xxmaj frames aggregated at the xxup xxunk level use
#   a common xxup crc check to enforce integrity . xxmaj for longer aggregated xxup xxunk frames ,
#   the packet error rate increases significantly for the same bit error rate .
#   xxmaj hence , multiple studies have proposed doing xxup xxunk aggregation adaptively based
#   on the error rate . xxmaj this study evaluates if there is a \ xxunk }
#   advantage in doing adaptive xxup xxunk aggregation based on the link bit error rate .
#   xxmaj evaluations on a model show that instead of implementing a complex adaptive
#   xxup xxunk frame aggregation mechanism which impact queuing and other implementation
#   aspects , it is easier to influence packet error rate with traditional
#   mechanisms while keeping the xxup xxunk aggregation logic simple .
#  ,xxbos xxmaj the $ xxunk xxmaj survey : the inner disk intermediate - age open cluster xxup ngc xxunk xxmaj milky xxmaj way open clusters are very diverse in terms of age , chemical
#   composition , and kinematic properties . xxmaj intermediate - age and old open clusters
#   are less common , and it is even harder to find them inside the solar
#   xxmaj galactocentric radius , due to the high mortality rate and strong extinction
#   inside this region . xxup ngc xxunk is one of the inner disk open clusters ( xxunk )
#   observed by the $ xxunk survey ( xxup xxunk ) . xxmaj this cluster is an important target
#   for calibrating the abundances derived in the survey due to the kinematic and
#   chemical homogeneity of the members in open clusters . xxmaj using the measurements
#   from $ xxunk internal data release 4 ( xxunk ) , we identify 95 main - sequence
#   dwarfs as cluster members from the xxup xxunk target list , and eight giants as
#   cluster members from the xxup uves target list . xxmaj the dwarf cluster members have a
#   median radial velocity of $ xxunk \ xxunk $ km s$^{-1}$ , while the giant cluster
#   members have a median radial velocity of $ 12.0 \ xxunk $ km s$^{-1}$ and a median
#   [ xxmaj fe / h ] of $ 0.10 \ pm0.02 $ dex . xxmaj the color - magnitude diagram of these cluster
#   members suggests an age of $ 0.9 \ xxunk $ xxmaj gyr , with $ ( m - xxup xxunk $ and
#   $ xxup e(b - xxup xxunk xxmaj we perform the first detailed chemical abundance analysis of xxup ngc
#   xxunk , including 27 elemental species . xxmaj to gain a more general picture about
#   xxunk , the measurements of xxup ngc xxunk are compared with those of other xxunk
#   previously studied by xxup xxunk , that is , xxup ngc xxunk , xxmaj xxunk 20 , xxup ngc xxunk , and
#   xxmaj berkeley 81 . xxup ngc xxunk shows similar c , n , xxmaj na , and xxmaj al abundances as other xxunk .
#   xxmaj these elements are compared with xxunk models as a function of
#   cluster turn - off mass . xxmaj the $ \ alpha$ , iron - peak , and neutron - capture elements
#   are also explored in a self - consistent way .
#  ,xxbos xxmaj witness - xxmaj functions versus xxmaj interpretation - xxmaj functions for xxmaj secrecy in xxmaj cryptographic xxmaj protocols : xxmaj what to xxmaj choose ? xxmaj proving that a cryptographic protocol is correct for secrecy is a hard task .
#   xxmaj one of the strongest strategies to reach this goal is to show that it is
#   increasing , which means that the security level of every single atomic message
#   exchanged in the protocol , safely evaluated , never xxunk . xxmaj recently , two
#   families of functions have been proposed to measure the security level of
#   atomic messages . xxmaj the first one is the family of interpretation - functions . xxmaj the
#   second is the family of witness - functions . xxmaj in this paper , we show that the
#   witness - functions are more efficient than interpretation - functions . xxmaj we give a
#   detailed analysis of an ad - hoc protocol on which the witness - functions succeed
#   in proving its correctness for secrecy while the interpretation - functions fail
#   to do so .
#
# y: EmptyLabelList
# ,,,,
# Path: ., model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(28720, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(28720, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1152, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1152, 1152, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1152, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=6, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of BCEWithLogitsLoss(), metrics=[functools.partial(<function accuracy_thresh at 0x7f73e35fbe18>, thresh=0.2), functools.partial(<function fbeta at 0x7f73e35fba60>, thresh=0.2, beta=1)], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[...], layer_groups=[Sequential(
#   (0): Embedding(28720, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(28720, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=6, bias=True)
#     )
#   )
# )], add_time=True, silent=False)
# alpha: 2.0
# beta: 1.0], layer_groups=[Sequential(
#   (0): Embedding(28720, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(28720, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=6, bias=True)
#     )
#   )
# )], add_time=True, silent=False)

# %%
learn_classifier.unfreeze()

# %%
learn_classifier.fit_one_cycle(3, slice(1e-3/(2.6**4), 1e-3), moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.149096</td>
#       <td>0.171310</td>
#       <td>0.914878</td>
#       <td>0.844890</td>
#       <td>06:55</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.145889</td>
#       <td>0.171962</td>
#       <td>0.915832</td>
#       <td>0.844174</td>
#       <td>06:26</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.140586</td>
#       <td>0.174215</td>
#       <td>0.918375</td>
#       <td>0.846368</td>
#       <td>07:12</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_classifier.save('/content/drive/My Drive/Analytics Vidhya/models/fourth')
learn_classifier.load('/content/drive/My Drive/Analytics Vidhya/models/fourth')
# Out:
# RNNLearner(data=TextClasDataBunch;
#
# Train: LabelList (18875 items)
# x: TextList
# xxbos xxmaj reconstructing xxmaj subject - xxmaj specific xxmaj effect xxmaj maps xxmaj predictive models allow subject - specific inference when analyzing disease
#   related alterations in neuroimaging data . xxmaj given a subject 's data , inference can
#   be made at two levels : global , i.e. xxunk condition presence for the
#   subject , and local , i.e. detecting condition effect on each individual
#   measurement extracted from the subject 's data . xxmaj while global inference is widely
#   used , local inference , which can be used to form subject - specific effect maps ,
#   is rarely used because existing models often yield noisy detections composed of
#   dispersed isolated islands . xxmaj in this article , we propose a reconstruction
#   method , named xxup rsm , to improve subject - specific detections of predictive
#   modeling approaches and in particular , binary classifiers . xxup rsm specifically
#   aims to reduce noise due to sampling error associated with using a finite
#   sample of examples to train classifiers . xxmaj the proposed method is a wrapper - type
#   algorithm that can be used with different binary classifiers in a diagnostic
#   manner , i.e. without information on condition presence . xxmaj reconstruction is posed
#   as a xxmaj maximum - a - xxmaj posteriori problem with a prior model whose parameters are
#   estimated from training data in a classifier - specific fashion . xxmaj experimental
#   evaluation is performed on synthetically generated data and data from the
#   xxmaj alzheimer 's xxmaj disease xxmaj neuroimaging xxmaj initiative ( xxup adni ) database . xxmaj results on
#   synthetic data demonstrate that using xxup rsm yields higher detection accuracy
#   compared to using models directly or with bootstrap averaging . xxmaj analyses on the
#   xxup adni dataset show that xxup rsm can also improve correlation between
#   subject - specific detections in cortical thickness data and non - imaging markers
#   of xxmaj alzheimer 's xxmaj disease ( xxup ad ) , such as the xxmaj mini xxmaj mental xxmaj state xxmaj examination xxmaj score
#   and xxmaj xxunk xxmaj fluid xxunk \ beta$ levels . xxmaj further reliability studies on
#   the longitudinal xxup adni dataset show improvement on detection reliability when
#   xxup rsm is used .
#  ,xxbos xxmaj rotation xxmaj invariance xxmaj neural xxmaj network xxmaj rotation invariance and translation invariance have great values in image
#   recognition tasks . xxmaj in this paper , we bring a new architecture in convolutional
#   neural network ( xxup cnn ) named cyclic convolutional layer to achieve rotation
#   invariance in xxup 2-d symbol recognition . xxmaj we can also get the position and
#   orientation of the xxup 2-d symbol by the network to achieve detection purpose for
#   multiple non - overlap target . xxmaj last but not least , this architecture can achieve
#   one - shot learning in some cases using those invariance .
#  ,xxbos xxmaj spherical polyharmonics and xxmaj poisson kernels for polyharmonic functions xxmaj we introduce and develop the notion of spherical polyharmonics , which are a
#   natural generalisation of spherical harmonics . xxmaj in particular we study the
#   theory of zonal polyharmonics , which allows us , analogously to zonal harmonics ,
#   to construct xxmaj poisson kernels for polyharmonic functions on the union of rotated
#   balls . xxmaj we find the representation of xxmaj poisson kernels and zonal polyharmonics in
#   terms of the xxmaj gegenbauer polynomials . xxmaj we show the connection between the
#   classical xxmaj poisson kernel for harmonic functions on the ball , xxmaj poisson kernels
#   for polyharmonic functions on the union of rotated balls , and the xxmaj cauchy - xxmaj xxunk
#   kernel for holomorphic functions on the xxmaj lie ball .
#  ,xxbos a finite element approximation for the stochastic xxmaj maxwell -- xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert system xxmaj the stochastic xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert ( xxup llg ) equation coupled with the
#   xxmaj maxwell equations ( the so called stochastic xxup xxunk system ) describes the creation
#   of domain walls and vortices ( fundamental objects for the novel nanostructured
#   magnetic memories ) . xxmaj we first reformulate the stochastic xxup llg equation into an
#   equation with time - differentiable solutions . xxmaj we then propose a convergent
#   $ \ xxunk scheme to approximate the solutions of the reformulated system .
#   xxmaj as a consequence , we prove convergence of the approximate solutions , with no or
#   minor conditions on time and space steps ( depending on the value of $ \ theta$ ) .
#   xxmaj hence , we prove the existence of weak martingale solutions of the stochastic
#   xxup xxunk system . xxmaj numerical results are presented to show applicability of the
#   method .
#  ,xxbos xxmaj comparative study of xxmaj discrete xxmaj wavelet xxmaj transforms and xxmaj wavelet xxmaj tensor xxmaj train decomposition to feature extraction of xxup ftir data of medicinal plants xxmaj fourier - transform infra - red ( xxup ftir ) spectra of samples from 7 plant species
#   were used to explore the influence of preprocessing and feature extraction on
#   efficiency of machine learning algorithms . xxmaj wavelet xxmaj tensor xxmaj train ( xxup wtt ) and
#   xxmaj discrete xxmaj wavelet xxmaj transforms ( xxup dwt ) were compared as feature extraction
#   techniques for xxup ftir data of medicinal plants . xxmaj various combinations of signal
#   processing steps showed different behavior when applied to classification and
#   clustering tasks . xxmaj best results for xxup wtt and xxup dwt found through grid search were
#   similar , significantly improving quality of clustering as well as
#   classification accuracy for tuned logistic regression in comparison to original
#   spectra . xxmaj unlike xxup dwt , xxup wtt has only one parameter to be tuned ( rank ) , making it a
#   more versatile and easier to use as a data processing tool in various signal
#   processing applications .
#
# y: MultiCategoryList
# Computer Science,Computer Science,Mathematics,Mathematics,Computer Science;Statistics
# Path: .;
#
# Valid: LabelList (2097 items)
# x: TextList
# xxbos xxmaj dynamic xxmaj layer xxmaj normalization for xxmaj adaptive xxmaj neural xxmaj acoustic xxmaj modeling in xxmaj speech xxmaj recognition xxmaj layer normalization is a recently introduced technique for normalizing the
#   activities of neurons in deep neural networks to improve the training speed and
#   stability . xxmaj in this paper , we introduce a new layer normalization technique
#   called xxmaj dynamic xxmaj layer xxmaj normalization ( xxup xxunk ) for adaptive neural acoustic modeling
#   in speech recognition . xxmaj by dynamically generating the scaling and shifting
#   parameters in layer normalization , xxup xxunk adapts neural acoustic models to the
#   acoustic variability arising from various factors such as speakers , channel
#   noises , and environments . xxmaj unlike other adaptive acoustic models , our proposed
#   approach does not require additional adaptation data or speaker information
#   such as i - vectors . xxmaj moreover , the model size is fixed as it dynamically
#   generates adaptation parameters . xxmaj we apply our proposed xxup xxunk to deep
#   bidirectional xxup lstm acoustic models and evaluate them on two benchmark datasets
#   for large vocabulary xxup asr experiments : xxup xxunk and xxup ted - xxup xxunk release 2 . xxmaj the
#   experimental results show that our xxup xxunk improves neural acoustic models in terms
#   of transcription accuracy by dynamically adapting to various speakers and
#   environments .
#  ,xxbos xxmaj susceptibility xxmaj propagation by xxmaj using xxmaj diagonal xxmaj consistency a susceptibility propagation that is constructed by combining a belief
#   propagation and a linear response method is used for approximate computation
#   for xxmaj markov random fields . xxmaj herein , we formulate a new , improved susceptibility
#   propagation by using the concept of a diagonal matching method that is based on
#   mean - field approaches to inverse xxmaj ising problems . xxmaj the proposed susceptibility
#   propagation is robust for various network structures , and it is reduced to the
#   ordinary susceptibility propagation and to the adaptive
#   xxmaj thouless - xxmaj anderson - xxmaj palmer equation in special cases .
#  ,xxbos xxmaj the xxmaj robot xxmaj routing xxmaj problem for xxmaj collecting xxmaj aggregate xxmaj stochastic xxmaj rewards xxmaj we propose a new model for formalizing reward collection problems on graphs
#   with dynamically generated rewards which may appear and disappear based on a
#   stochastic model . xxmaj the * robot routing problem * is modeled as a graph whose nodes
#   are stochastic processes generating potential rewards over discrete time . xxmaj the
#   rewards are generated according to the stochastic process , but at each step , an
#   existing reward disappears with a given probability . xxmaj the edges in the graph
#   encode the ( unit - distance ) paths between the rewards ' locations . xxmaj on visiting a
#   node , the robot collects the accumulated reward at the node at that time , but
#   traveling between the nodes takes time . xxmaj the optimization question asks to
#   compute an optimal ( or epsilon - optimal ) path that maximizes the expected
#   collected rewards .
#   xxmaj we consider the finite and infinite - horizon robot routing problems . xxmaj for
#   finite - horizon , the goal is to maximize the total expected reward , while for
#   infinite horizon we consider limit - average objectives . xxmaj we study the
#   computational and strategy complexity of these problems , establish xxup np - lower
#   bounds and show that optimal strategies require memory in general . xxmaj we also
#   provide an algorithm for computing epsilon - optimal infinite paths for arbitrary
#   epsilon > 0 .
#  ,xxbos xxmaj probability , xxmaj statistics and xxmaj planet xxmaj earth , i : xxmaj xxunk covariances xxmaj the study of covariances ( or positive definite functions ) on the sphere ( the
#   xxmaj earth , in our motivation ) goes back to xxmaj bochner and xxmaj xxunk ( xxunk - xxunk ) and to
#   the first author ( 1969 , 1973 ) , among others . xxmaj extending to the xxunk case
#   ( sphere cross line , for position and time ) was for a long time an obstacle to
#   geostatistical modelling . xxmaj the characterisation question here was raised by the
#   authors and xxmaj xxunk in 2016 , and answered by xxmaj xxunk and xxmaj xxunk in 2017 .
#   xxmaj extensions to multiple products ( of spheres and lines ) follows similarly
#   ( xxmaj xxunk , xxmaj xxunk and xxmaj xxunk , 2016 ) . xxmaj we survey results of this type , and
#   related applications e.g. in numerical weather prediction .
#  ,xxbos xxmaj counting the number of metastable states in the modularity landscape : xxmaj algorithmic detectability limit of greedy algorithms in community detection xxmaj modularity maximization using greedy algorithms continues to be a popular
#   approach toward community detection in graphs , even after various better
#   forming algorithms have been proposed . xxmaj apart from its clear mechanism and ease
#   of implementation , this approach is persistently popular because , presumably ,
#   its risk of algorithmic failure is not well understood . xxmaj this xxmaj rapid
#   xxmaj communication provides insight into this issue by estimating the algorithmic
#   performance limit of modularity maximization . xxmaj this is achieved by counting the
#   number of metastable states under a local update rule . xxmaj our results offer a
#   quantitative insight into the level of sparsity at which a greedy algorithm
#   typically fails .
#
# y: MultiCategoryList
# Computer Science,Mathematics;Statistics,Computer Science;Mathematics,Physics;Statistics,Computer Science
# Path: .;
#
# Test: LabelList (8989 items)
# x: TextList
# xxbos xxmaj closed - form xxmaj marginal xxmaj likelihood in xxmaj gamma - xxmaj poisson xxmaj matrix xxmaj factorization xxmaj we present novel understandings of the xxmaj gamma - xxmaj poisson ( gap ) model , a
#   probabilistic matrix factorization model for count data . xxmaj we show that gap can
#   be rewritten free of the score / activation matrix . xxmaj this gives us new insights
#   about the estimation of the topic / dictionary matrix by maximum marginal
#   likelihood estimation . xxmaj in particular , this explains the robustness of this
#   estimator to over - specified values of the factorization rank , especially its
#   ability to automatically prune irrelevant dictionary columns , as empirically
#   observed in previous work . xxmaj the marginalization of the activation matrix leads
#   in turn to a new xxmaj monte xxmaj carlo xxmaj expectation - xxmaj maximization algorithm with favorable
#   properties .
#  ,xxbos xxmaj laboratory mid - xxup ir spectra of xxunk and xxunk meteorites . xxmaj searching for observables of planetesimal debris xxmaj meteorites contain minerals from xxmaj solar xxmaj system asteroids with different
#   properties ( like size , presence of water , core formation ) . xxmaj we provide new
#   mid - xxup ir transmission spectra of xxunk meteorites to obtain templates of how
#   mid - xxup ir spectra of asteroidal debris would look like . xxmaj this is essential for
#   interpreting mid - xxup ir spectra of past and future space observatories , like the
#   xxmaj james xxmaj webb xxmaj space xxmaj telescope . xxmaj we show that the transmission spectra of wet and
#   dry chondrites , carbonaceous and ordinary chondrites and xxunk and
#   xxunk meteorites are distinctly different in a way one can distinguish in
#   astronomical mid - xxup ir spectra . xxmaj the two observables that spectroscopically
#   separate the different meteorites groups ( and thus the different types of
#   parent bodies ) are the xxunk - olivine feature strength ratio and the peak
#   shift of the olivine spectral features due to an increase in the iron
#   concentration of the olivine .
#  ,xxbos xxmaj case xxmaj for xxmaj static xxup xxunk xxmaj aggregation in wlans xxmaj frame aggregation is a mechanism by which multiple frames are combined into a
#   single transmission unit over the air . xxmaj frames aggregated at the xxup xxunk level use
#   a common xxup crc check to enforce integrity . xxmaj for longer aggregated xxup xxunk frames ,
#   the packet error rate increases significantly for the same bit error rate .
#   xxmaj hence , multiple studies have proposed doing xxup xxunk aggregation adaptively based
#   on the error rate . xxmaj this study evaluates if there is a \ xxunk }
#   advantage in doing adaptive xxup xxunk aggregation based on the link bit error rate .
#   xxmaj evaluations on a model show that instead of implementing a complex adaptive
#   xxup xxunk frame aggregation mechanism which impact queuing and other implementation
#   aspects , it is easier to influence packet error rate with traditional
#   mechanisms while keeping the xxup xxunk aggregation logic simple .
#  ,xxbos xxmaj the $ xxunk xxmaj survey : the inner disk intermediate - age open cluster xxup ngc xxunk xxmaj milky xxmaj way open clusters are very diverse in terms of age , chemical
#   composition , and kinematic properties . xxmaj intermediate - age and old open clusters
#   are less common , and it is even harder to find them inside the solar
#   xxmaj galactocentric radius , due to the high mortality rate and strong extinction
#   inside this region . xxup ngc xxunk is one of the inner disk open clusters ( xxunk )
#   observed by the $ xxunk survey ( xxup xxunk ) . xxmaj this cluster is an important target
#   for calibrating the abundances derived in the survey due to the kinematic and
#   chemical homogeneity of the members in open clusters . xxmaj using the measurements
#   from $ xxunk internal data release 4 ( xxunk ) , we identify 95 main - sequence
#   dwarfs as cluster members from the xxup xxunk target list , and eight giants as
#   cluster members from the xxup uves target list . xxmaj the dwarf cluster members have a
#   median radial velocity of $ xxunk \ xxunk $ km s$^{-1}$ , while the giant cluster
#   members have a median radial velocity of $ 12.0 \ xxunk $ km s$^{-1}$ and a median
#   [ xxmaj fe / h ] of $ 0.10 \ pm0.02 $ dex . xxmaj the color - magnitude diagram of these cluster
#   members suggests an age of $ 0.9 \ xxunk $ xxmaj gyr , with $ ( m - xxup xxunk $ and
#   $ xxup e(b - xxup xxunk xxmaj we perform the first detailed chemical abundance analysis of xxup ngc
#   xxunk , including 27 elemental species . xxmaj to gain a more general picture about
#   xxunk , the measurements of xxup ngc xxunk are compared with those of other xxunk
#   previously studied by xxup xxunk , that is , xxup ngc xxunk , xxmaj xxunk 20 , xxup ngc xxunk , and
#   xxmaj berkeley 81 . xxup ngc xxunk shows similar c , n , xxmaj na , and xxmaj al abundances as other xxunk .
#   xxmaj these elements are compared with xxunk models as a function of
#   cluster turn - off mass . xxmaj the $ \ alpha$ , iron - peak , and neutron - capture elements
#   are also explored in a self - consistent way .
#  ,xxbos xxmaj witness - xxmaj functions versus xxmaj interpretation - xxmaj functions for xxmaj secrecy in xxmaj cryptographic xxmaj protocols : xxmaj what to xxmaj choose ? xxmaj proving that a cryptographic protocol is correct for secrecy is a hard task .
#   xxmaj one of the strongest strategies to reach this goal is to show that it is
#   increasing , which means that the security level of every single atomic message
#   exchanged in the protocol , safely evaluated , never xxunk . xxmaj recently , two
#   families of functions have been proposed to measure the security level of
#   atomic messages . xxmaj the first one is the family of interpretation - functions . xxmaj the
#   second is the family of witness - functions . xxmaj in this paper , we show that the
#   witness - functions are more efficient than interpretation - functions . xxmaj we give a
#   detailed analysis of an ad - hoc protocol on which the witness - functions succeed
#   in proving its correctness for secrecy while the interpretation - functions fail
#   to do so .
#
# y: EmptyLabelList
# ,,,,
# Path: ., model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(28720, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(28720, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1152, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1152, 1152, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1152, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=6, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of BCEWithLogitsLoss(), metrics=[functools.partial(<function accuracy_thresh at 0x7f73e35fbe18>, thresh=0.2), functools.partial(<function fbeta at 0x7f73e35fba60>, thresh=0.2, beta=1)], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[RNNTrainer
# learn: RNNLearner(data=TextClasDataBunch;
#
# Train: LabelList (18875 items)
# x: TextList
# xxbos xxmaj reconstructing xxmaj subject - xxmaj specific xxmaj effect xxmaj maps xxmaj predictive models allow subject - specific inference when analyzing disease
#   related alterations in neuroimaging data . xxmaj given a subject 's data , inference can
#   be made at two levels : global , i.e. xxunk condition presence for the
#   subject , and local , i.e. detecting condition effect on each individual
#   measurement extracted from the subject 's data . xxmaj while global inference is widely
#   used , local inference , which can be used to form subject - specific effect maps ,
#   is rarely used because existing models often yield noisy detections composed of
#   dispersed isolated islands . xxmaj in this article , we propose a reconstruction
#   method , named xxup rsm , to improve subject - specific detections of predictive
#   modeling approaches and in particular , binary classifiers . xxup rsm specifically
#   aims to reduce noise due to sampling error associated with using a finite
#   sample of examples to train classifiers . xxmaj the proposed method is a wrapper - type
#   algorithm that can be used with different binary classifiers in a diagnostic
#   manner , i.e. without information on condition presence . xxmaj reconstruction is posed
#   as a xxmaj maximum - a - xxmaj posteriori problem with a prior model whose parameters are
#   estimated from training data in a classifier - specific fashion . xxmaj experimental
#   evaluation is performed on synthetically generated data and data from the
#   xxmaj alzheimer 's xxmaj disease xxmaj neuroimaging xxmaj initiative ( xxup adni ) database . xxmaj results on
#   synthetic data demonstrate that using xxup rsm yields higher detection accuracy
#   compared to using models directly or with bootstrap averaging . xxmaj analyses on the
#   xxup adni dataset show that xxup rsm can also improve correlation between
#   subject - specific detections in cortical thickness data and non - imaging markers
#   of xxmaj alzheimer 's xxmaj disease ( xxup ad ) , such as the xxmaj mini xxmaj mental xxmaj state xxmaj examination xxmaj score
#   and xxmaj xxunk xxmaj fluid xxunk \ beta$ levels . xxmaj further reliability studies on
#   the longitudinal xxup adni dataset show improvement on detection reliability when
#   xxup rsm is used .
#  ,xxbos xxmaj rotation xxmaj invariance xxmaj neural xxmaj network xxmaj rotation invariance and translation invariance have great values in image
#   recognition tasks . xxmaj in this paper , we bring a new architecture in convolutional
#   neural network ( xxup cnn ) named cyclic convolutional layer to achieve rotation
#   invariance in xxup 2-d symbol recognition . xxmaj we can also get the position and
#   orientation of the xxup 2-d symbol by the network to achieve detection purpose for
#   multiple non - overlap target . xxmaj last but not least , this architecture can achieve
#   one - shot learning in some cases using those invariance .
#  ,xxbos xxmaj spherical polyharmonics and xxmaj poisson kernels for polyharmonic functions xxmaj we introduce and develop the notion of spherical polyharmonics , which are a
#   natural generalisation of spherical harmonics . xxmaj in particular we study the
#   theory of zonal polyharmonics , which allows us , analogously to zonal harmonics ,
#   to construct xxmaj poisson kernels for polyharmonic functions on the union of rotated
#   balls . xxmaj we find the representation of xxmaj poisson kernels and zonal polyharmonics in
#   terms of the xxmaj gegenbauer polynomials . xxmaj we show the connection between the
#   classical xxmaj poisson kernel for harmonic functions on the ball , xxmaj poisson kernels
#   for polyharmonic functions on the union of rotated balls , and the xxmaj cauchy - xxmaj xxunk
#   kernel for holomorphic functions on the xxmaj lie ball .
#  ,xxbos a finite element approximation for the stochastic xxmaj maxwell -- xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert system xxmaj the stochastic xxmaj landau -- xxmaj lifshitz -- xxmaj gilbert ( xxup llg ) equation coupled with the
#   xxmaj maxwell equations ( the so called stochastic xxup xxunk system ) describes the creation
#   of domain walls and vortices ( fundamental objects for the novel nanostructured
#   magnetic memories ) . xxmaj we first reformulate the stochastic xxup llg equation into an
#   equation with time - differentiable solutions . xxmaj we then propose a convergent
#   $ \ xxunk scheme to approximate the solutions of the reformulated system .
#   xxmaj as a consequence , we prove convergence of the approximate solutions , with no or
#   minor conditions on time and space steps ( depending on the value of $ \ theta$ ) .
#   xxmaj hence , we prove the existence of weak martingale solutions of the stochastic
#   xxup xxunk system . xxmaj numerical results are presented to show applicability of the
#   method .
#  ,xxbos xxmaj comparative study of xxmaj discrete xxmaj wavelet xxmaj transforms and xxmaj wavelet xxmaj tensor xxmaj train decomposition to feature extraction of xxup ftir data of medicinal plants xxmaj fourier - transform infra - red ( xxup ftir ) spectra of samples from 7 plant species
#   were used to explore the influence of preprocessing and feature extraction on
#   efficiency of machine learning algorithms . xxmaj wavelet xxmaj tensor xxmaj train ( xxup wtt ) and
#   xxmaj discrete xxmaj wavelet xxmaj transforms ( xxup dwt ) were compared as feature extraction
#   techniques for xxup ftir data of medicinal plants . xxmaj various combinations of signal
#   processing steps showed different behavior when applied to classification and
#   clustering tasks . xxmaj best results for xxup wtt and xxup dwt found through grid search were
#   similar , significantly improving quality of clustering as well as
#   classification accuracy for tuned logistic regression in comparison to original
#   spectra . xxmaj unlike xxup dwt , xxup wtt has only one parameter to be tuned ( rank ) , making it a
#   more versatile and easier to use as a data processing tool in various signal
#   processing applications .
#
# y: MultiCategoryList
# Computer Science,Computer Science,Mathematics,Mathematics,Computer Science;Statistics
# Path: .;
#
# Valid: LabelList (2097 items)
# x: TextList
# xxbos xxmaj dynamic xxmaj layer xxmaj normalization for xxmaj adaptive xxmaj neural xxmaj acoustic xxmaj modeling in xxmaj speech xxmaj recognition xxmaj layer normalization is a recently introduced technique for normalizing the
#   activities of neurons in deep neural networks to improve the training speed and
#   stability . xxmaj in this paper , we introduce a new layer normalization technique
#   called xxmaj dynamic xxmaj layer xxmaj normalization ( xxup xxunk ) for adaptive neural acoustic modeling
#   in speech recognition . xxmaj by dynamically generating the scaling and shifting
#   parameters in layer normalization , xxup xxunk adapts neural acoustic models to the
#   acoustic variability arising from various factors such as speakers , channel
#   noises , and environments . xxmaj unlike other adaptive acoustic models , our proposed
#   approach does not require additional adaptation data or speaker information
#   such as i - vectors . xxmaj moreover , the model size is fixed as it dynamically
#   generates adaptation parameters . xxmaj we apply our proposed xxup xxunk to deep
#   bidirectional xxup lstm acoustic models and evaluate them on two benchmark datasets
#   for large vocabulary xxup asr experiments : xxup xxunk and xxup ted - xxup xxunk release 2 . xxmaj the
#   experimental results show that our xxup xxunk improves neural acoustic models in terms
#   of transcription accuracy by dynamically adapting to various speakers and
#   environments .
#  ,xxbos xxmaj susceptibility xxmaj propagation by xxmaj using xxmaj diagonal xxmaj consistency a susceptibility propagation that is constructed by combining a belief
#   propagation and a linear response method is used for approximate computation
#   for xxmaj markov random fields . xxmaj herein , we formulate a new , improved susceptibility
#   propagation by using the concept of a diagonal matching method that is based on
#   mean - field approaches to inverse xxmaj ising problems . xxmaj the proposed susceptibility
#   propagation is robust for various network structures , and it is reduced to the
#   ordinary susceptibility propagation and to the adaptive
#   xxmaj thouless - xxmaj anderson - xxmaj palmer equation in special cases .
#  ,xxbos xxmaj the xxmaj robot xxmaj routing xxmaj problem for xxmaj collecting xxmaj aggregate xxmaj stochastic xxmaj rewards xxmaj we propose a new model for formalizing reward collection problems on graphs
#   with dynamically generated rewards which may appear and disappear based on a
#   stochastic model . xxmaj the * robot routing problem * is modeled as a graph whose nodes
#   are stochastic processes generating potential rewards over discrete time . xxmaj the
#   rewards are generated according to the stochastic process , but at each step , an
#   existing reward disappears with a given probability . xxmaj the edges in the graph
#   encode the ( unit - distance ) paths between the rewards ' locations . xxmaj on visiting a
#   node , the robot collects the accumulated reward at the node at that time , but
#   traveling between the nodes takes time . xxmaj the optimization question asks to
#   compute an optimal ( or epsilon - optimal ) path that maximizes the expected
#   collected rewards .
#   xxmaj we consider the finite and infinite - horizon robot routing problems . xxmaj for
#   finite - horizon , the goal is to maximize the total expected reward , while for
#   infinite horizon we consider limit - average objectives . xxmaj we study the
#   computational and strategy complexity of these problems , establish xxup np - lower
#   bounds and show that optimal strategies require memory in general . xxmaj we also
#   provide an algorithm for computing epsilon - optimal infinite paths for arbitrary
#   epsilon > 0 .
#  ,xxbos xxmaj probability , xxmaj statistics and xxmaj planet xxmaj earth , i : xxmaj xxunk covariances xxmaj the study of covariances ( or positive definite functions ) on the sphere ( the
#   xxmaj earth , in our motivation ) goes back to xxmaj bochner and xxmaj xxunk ( xxunk - xxunk ) and to
#   the first author ( 1969 , 1973 ) , among others . xxmaj extending to the xxunk case
#   ( sphere cross line , for position and time ) was for a long time an obstacle to
#   geostatistical modelling . xxmaj the characterisation question here was raised by the
#   authors and xxmaj xxunk in 2016 , and answered by xxmaj xxunk and xxmaj xxunk in 2017 .
#   xxmaj extensions to multiple products ( of spheres and lines ) follows similarly
#   ( xxmaj xxunk , xxmaj xxunk and xxmaj xxunk , 2016 ) . xxmaj we survey results of this type , and
#   related applications e.g. in numerical weather prediction .
#  ,xxbos xxmaj counting the number of metastable states in the modularity landscape : xxmaj algorithmic detectability limit of greedy algorithms in community detection xxmaj modularity maximization using greedy algorithms continues to be a popular
#   approach toward community detection in graphs , even after various better
#   forming algorithms have been proposed . xxmaj apart from its clear mechanism and ease
#   of implementation , this approach is persistently popular because , presumably ,
#   its risk of algorithmic failure is not well understood . xxmaj this xxmaj rapid
#   xxmaj communication provides insight into this issue by estimating the algorithmic
#   performance limit of modularity maximization . xxmaj this is achieved by counting the
#   number of metastable states under a local update rule . xxmaj our results offer a
#   quantitative insight into the level of sparsity at which a greedy algorithm
#   typically fails .
#
# y: MultiCategoryList
# Computer Science,Mathematics;Statistics,Computer Science;Mathematics,Physics;Statistics,Computer Science
# Path: .;
#
# Test: LabelList (8989 items)
# x: TextList
# xxbos xxmaj closed - form xxmaj marginal xxmaj likelihood in xxmaj gamma - xxmaj poisson xxmaj matrix xxmaj factorization xxmaj we present novel understandings of the xxmaj gamma - xxmaj poisson ( gap ) model , a
#   probabilistic matrix factorization model for count data . xxmaj we show that gap can
#   be rewritten free of the score / activation matrix . xxmaj this gives us new insights
#   about the estimation of the topic / dictionary matrix by maximum marginal
#   likelihood estimation . xxmaj in particular , this explains the robustness of this
#   estimator to over - specified values of the factorization rank , especially its
#   ability to automatically prune irrelevant dictionary columns , as empirically
#   observed in previous work . xxmaj the marginalization of the activation matrix leads
#   in turn to a new xxmaj monte xxmaj carlo xxmaj expectation - xxmaj maximization algorithm with favorable
#   properties .
#  ,xxbos xxmaj laboratory mid - xxup ir spectra of xxunk and xxunk meteorites . xxmaj searching for observables of planetesimal debris xxmaj meteorites contain minerals from xxmaj solar xxmaj system asteroids with different
#   properties ( like size , presence of water , core formation ) . xxmaj we provide new
#   mid - xxup ir transmission spectra of xxunk meteorites to obtain templates of how
#   mid - xxup ir spectra of asteroidal debris would look like . xxmaj this is essential for
#   interpreting mid - xxup ir spectra of past and future space observatories , like the
#   xxmaj james xxmaj webb xxmaj space xxmaj telescope . xxmaj we show that the transmission spectra of wet and
#   dry chondrites , carbonaceous and ordinary chondrites and xxunk and
#   xxunk meteorites are distinctly different in a way one can distinguish in
#   astronomical mid - xxup ir spectra . xxmaj the two observables that spectroscopically
#   separate the different meteorites groups ( and thus the different types of
#   parent bodies ) are the xxunk - olivine feature strength ratio and the peak
#   shift of the olivine spectral features due to an increase in the iron
#   concentration of the olivine .
#  ,xxbos xxmaj case xxmaj for xxmaj static xxup xxunk xxmaj aggregation in wlans xxmaj frame aggregation is a mechanism by which multiple frames are combined into a
#   single transmission unit over the air . xxmaj frames aggregated at the xxup xxunk level use
#   a common xxup crc check to enforce integrity . xxmaj for longer aggregated xxup xxunk frames ,
#   the packet error rate increases significantly for the same bit error rate .
#   xxmaj hence , multiple studies have proposed doing xxup xxunk aggregation adaptively based
#   on the error rate . xxmaj this study evaluates if there is a \ xxunk }
#   advantage in doing adaptive xxup xxunk aggregation based on the link bit error rate .
#   xxmaj evaluations on a model show that instead of implementing a complex adaptive
#   xxup xxunk frame aggregation mechanism which impact queuing and other implementation
#   aspects , it is easier to influence packet error rate with traditional
#   mechanisms while keeping the xxup xxunk aggregation logic simple .
#  ,xxbos xxmaj the $ xxunk xxmaj survey : the inner disk intermediate - age open cluster xxup ngc xxunk xxmaj milky xxmaj way open clusters are very diverse in terms of age , chemical
#   composition , and kinematic properties . xxmaj intermediate - age and old open clusters
#   are less common , and it is even harder to find them inside the solar
#   xxmaj galactocentric radius , due to the high mortality rate and strong extinction
#   inside this region . xxup ngc xxunk is one of the inner disk open clusters ( xxunk )
#   observed by the $ xxunk survey ( xxup xxunk ) . xxmaj this cluster is an important target
#   for calibrating the abundances derived in the survey due to the kinematic and
#   chemical homogeneity of the members in open clusters . xxmaj using the measurements
#   from $ xxunk internal data release 4 ( xxunk ) , we identify 95 main - sequence
#   dwarfs as cluster members from the xxup xxunk target list , and eight giants as
#   cluster members from the xxup uves target list . xxmaj the dwarf cluster members have a
#   median radial velocity of $ xxunk \ xxunk $ km s$^{-1}$ , while the giant cluster
#   members have a median radial velocity of $ 12.0 \ xxunk $ km s$^{-1}$ and a median
#   [ xxmaj fe / h ] of $ 0.10 \ pm0.02 $ dex . xxmaj the color - magnitude diagram of these cluster
#   members suggests an age of $ 0.9 \ xxunk $ xxmaj gyr , with $ ( m - xxup xxunk $ and
#   $ xxup e(b - xxup xxunk xxmaj we perform the first detailed chemical abundance analysis of xxup ngc
#   xxunk , including 27 elemental species . xxmaj to gain a more general picture about
#   xxunk , the measurements of xxup ngc xxunk are compared with those of other xxunk
#   previously studied by xxup xxunk , that is , xxup ngc xxunk , xxmaj xxunk 20 , xxup ngc xxunk , and
#   xxmaj berkeley 81 . xxup ngc xxunk shows similar c , n , xxmaj na , and xxmaj al abundances as other xxunk .
#   xxmaj these elements are compared with xxunk models as a function of
#   cluster turn - off mass . xxmaj the $ \ alpha$ , iron - peak , and neutron - capture elements
#   are also explored in a self - consistent way .
#  ,xxbos xxmaj witness - xxmaj functions versus xxmaj interpretation - xxmaj functions for xxmaj secrecy in xxmaj cryptographic xxmaj protocols : xxmaj what to xxmaj choose ? xxmaj proving that a cryptographic protocol is correct for secrecy is a hard task .
#   xxmaj one of the strongest strategies to reach this goal is to show that it is
#   increasing , which means that the security level of every single atomic message
#   exchanged in the protocol , safely evaluated , never xxunk . xxmaj recently , two
#   families of functions have been proposed to measure the security level of
#   atomic messages . xxmaj the first one is the family of interpretation - functions . xxmaj the
#   second is the family of witness - functions . xxmaj in this paper , we show that the
#   witness - functions are more efficient than interpretation - functions . xxmaj we give a
#   detailed analysis of an ad - hoc protocol on which the witness - functions succeed
#   in proving its correctness for secrecy while the interpretation - functions fail
#   to do so .
#
# y: EmptyLabelList
# ,,,,
# Path: ., model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(28720, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(28720, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1152, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1152, 1152, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1152, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=6, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of BCEWithLogitsLoss(), metrics=[functools.partial(<function accuracy_thresh at 0x7f73e35fbe18>, thresh=0.2), functools.partial(<function fbeta at 0x7f73e35fba60>, thresh=0.2, beta=1)], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[...], layer_groups=[Sequential(
#   (0): Embedding(28720, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(28720, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=6, bias=True)
#     )
#   )
# )], add_time=True, silent=False)
# alpha: 2.0
# beta: 1.0], layer_groups=[Sequential(
#   (0): Embedding(28720, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(28720, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=6, bias=True)
#     )
#   )
# )], add_time=True, silent=False)

# %%
learn_classifier.show_results()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#       <th>prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxmaj stable and unstable vortex knots in a trapped xxmaj bose - xxmaj einstein condensate xxmaj the dynamics of a quantum vortex torus knot $ { \ cal xxup xxunk , xxup q}$ and similar \n  knots in an atomic xxmaj bose - xxmaj einstein condensate at zero temperature in the \n  xxmaj thomas - xxmaj fermi regime has been considered in the hydrodynamic approximation . xxmaj</td>
#       <td>Physics</td>
#       <td>Physics</td>
#     </tr>
#     <tr>
#       <td>xxbos q - analogues of the xxmaj xxunk - xxmaj stirling numbers xxmaj let $ xxmaj f_n$ denote the $ n^{th}$ xxmaj fibonacci number relative to the initial \n  conditions $ xxup xxunk $ and $ xxup xxunk xxmaj xxunk , xxmaj xxunk , and xxmaj xxunk introduced xxmaj fibonacci \n  analogues of the xxmaj stirling numbers called xxmaj xxunk - xxmaj stirling numbers of the first and</td>
#       <td>Mathematics</td>
#       <td>Mathematics</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj xxunk - xxunk : an optical to near - infrared survey of emission - line galaxies at $ \ bf xxunk - 4.7 $ xxmaj we present a sample of $ \ sim 1000 $ emission line galaxies at $ xxunk - 4.7 $ from \n  the $ \ xxunk $ xxmaj high-$z$ xxmaj emission xxmaj line xxmaj survey ( xxunk ) in the xxmaj xxunk \n</td>
#       <td>Physics</td>
#       <td>Physics</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj relative xxmaj error xxmaj tensor xxmaj low xxmaj rank xxmaj approximation xxmaj we consider relative error low rank approximation of $ xxunk with respect \n  to the xxmaj frobenius norm : given an xxunk tensor $ a \ in \n  \ xxunk { \ xxunk xxunk , output a rank-$k$ tensor $ xxup b$ for which \n  $ \ xxup |a - b \ xxup</td>
#       <td>Computer Science</td>
#       <td>Computer Science;Statistics</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj clarifying the xxmaj hubble constant tension with a xxmaj bayesian hierarchical model of the local distance ladder xxmaj estimates of the xxmaj hubble constant , $ xxup h_0 $ , from the distance ladder and the \n  cosmic microwave background ( xxup cmb ) differ at the $ \ xxunk \ sigma$ level , \n  indicating a potential issue with the standard $ \ lambda$cdm cosmology</td>
#       <td>Physics</td>
#       <td>Physics</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Predict

# %%
preds, target = learn_classifier.get_preds(DatasetType.Test, ordered=True)
labels = preds.numpy()

submission = pd.DataFrame({'ID': test_id})
submission = pd.concat([submission, pd.DataFrame(preds.numpy(), columns = label_cols)], axis=1)

submission.to_csv('/content/drive/My Drive/Analytics Vidhya/output/ulm_proba.csv', index=False)
submission.head()
# Out:
#       ID  Computer Science  ...  Quantitative Biology  Quantitative Finance
# 0  20973          0.319749  ...          1.589267e-03              0.004184
# 1  20974          0.000007  ...          3.685447e-07              0.000006
# 2  20975          0.980287  ...          7.086441e-05              0.000016
# 3  20976          0.000260  ...          8.597167e-06              0.000013
# 4  20977          0.999607  ...          7.424675e-07              0.000001
#
# [5 rows x 7 columns]
